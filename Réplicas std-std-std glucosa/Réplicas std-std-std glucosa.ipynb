# %%
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.interpolate import UnivariateSpline

# %%
cfp1=np.fromfile('CFPA3', sep=',')
rfp1=np.fromfile('RFPA3', sep=',')
yfp1=np.fromfile('YFPA3', sep=',')
od1=np.fromfile('ODA3', sep=',')
cfp2=np.fromfile('CFPA4', sep=',')
rfp2=np.fromfile('RFPA4', sep=',')
yfp2=np.fromfile('YFPA4', sep=',')
od2=np.fromfile('ODA4', sep=',')
cfp3=np.fromfile('CFPA5', sep=',')
rfp3=np.fromfile('RFPA5', sep=',')
yfp3=np.fromfile('YFPA5', sep=',')
od3=np.fromfile('ODA5', sep=',')
cfp4=np.fromfile('CFPA6', sep=',')
rfp4=np.fromfile('RFPA6', sep=',')
yfp4=np.fromfile('YFPA6', sep=',')
od4=np.fromfile('ODA6', sep=',')
cfp5=np.fromfile('CFPA7', sep=',')
rfp5=np.fromfile('RFPA7', sep=',')
yfp5=np.fromfile('YFPA7', sep=',')
od5=np.fromfile('ODA7', sep=',')
cfp6=np.fromfile('CFPB3', sep=',')
rfp6=np.fromfile('RFPB3', sep=',')
yfp6=np.fromfile('YFPB3', sep=',')
od6=np.fromfile('ODB3', sep=',')
cfp7=np.fromfile('CFPB4', sep=',')
rfp7=np.fromfile('RFPB4', sep=',')
yfp7=np.fromfile('YFPB4', sep=',')
od7=np.fromfile('ODB4', sep=',')
cfp8=np.fromfile('CFPB5', sep=',')
rfp8=np.fromfile('RFPB5', sep=',')
yfp8=np.fromfile('YFPB5', sep=',')
od8=np.fromfile('ODB5', sep=',')
cfp9=np.fromfile('CFPB6', sep=',')
rfp9=np.fromfile('RFPB6', sep=',')
yfp9=np.fromfile('YFPB6', sep=',')
od9=np.fromfile('ODB6', sep=',')
cfp10=np.fromfile('CFPB7', sep=',')
rfp10=np.fromfile('RFPB7', sep=',')
yfp10=np.fromfile('YFPB7', sep=',')
od10=np.fromfile('ODB7', sep=',')
cfpp=np.fromfile('psssgCFP', sep=',')
rfpp=np.fromfile('psssgRFP', sep=',')
yfpp=np.fromfile('psssgYFP', sep=',')
odp=np.fromfile('psssgOD', sep=',')
t=np.fromfile('t', sep=',')

CFPS=[cfp1,cfp2,cfp3,cfp4,cfp5,cfp6,cfp7,cfp8,cfp9,cfp10]
RFPS=[rfp1,rfp2,rfp3,rfp4,rfp5,rfp6,rfp7,rfp8,rfp9,rfp10]
YFPS=[yfp1,yfp2,yfp3,yfp4,yfp5,yfp6,yfp7,yfp8,yfp9,yfp10]
ODS=[od1,od2,od3,od4,od5,od6,od7,od8,od9,od10]

# %%
#diffs
#Promedios
td=np.diff(t)    
dodp=np.diff(odp)
cfpdp=np.diff(cfpp)
rfpdp=np.diff(rfpp)
yfpdp=np.diff(yfpp)
cp=(cfpdp/td)
rp=(rfpdp/td)
yp=(yfpdp/td)  
grp=(1/odp[:-1])*(dodp/td)
kcp=(1/odp[:-1])*cp
krp=(1/odp[:-1])*rp
kyp=(1/odp[:-1])*yp

#A3
dod1=np.diff(od1)
cfpd1=np.diff(cfp1)
rfpd1=np.diff(rfp1)
yfpd1=np.diff(yfp1)
c1=(cfpd1/td)
r1=(rfpd1/td)
y1=(yfpd1/td)  
gr1=(1/od1[:-1])*(dod1/td)
kc1=(1/od1[:-1])*c1
kr1=(1/od1[:-1])*r1
ky1=(1/od1[:-1])*y1 
#A4
dod2=np.diff(od2)
cfpd2=np.diff(cfp2)
rfpd2=np.diff(rfp2)
yfpd2=np.diff(yfp2)
c2=(cfpd2/td)
r2=(rfpd2/td)
y2=(yfpd2/td)  
gr2=(1/od2[:-1])*(dod2/td)
kc2=(1/od2[:-1])*c2
kr2=(1/od2[:-1])*r2
ky2=(1/od2[:-1])*y2
#A5
dod3=np.diff(od3)
cfpd3=np.diff(cfp3)
rfpd3=np.diff(rfp3)
yfpd3=np.diff(yfp3)
c3=(cfpd3/td)
r3=(rfpd3/td)
y3=(yfpd3/td)  
gr3=(1/od3[:-1])*(dod3/td)
kc3=(1/od3[:-1])*c3
kr3=(1/od3[:-1])*r3
ky3=(1/od3[:-1])*y3 
#A6
dod4=np.diff(od4)
cfpd4=np.diff(cfp4)
rfpd4=np.diff(rfp4)
yfpd4=np.diff(yfp4)
c4=(cfpd4/td)
r4=(rfpd4/td)
y4=(yfpd4/td)  
gr4=(1/od4[:-1])*(dod4/td)
kc4=(1/od4[:-1])*c4
kr4=(1/od4[:-1])*r4
ky4=(1/od4[:-1])*y4
#A7
dod5=np.diff(od5)
cfpd5=np.diff(cfp5)
rfpd5=np.diff(rfp5)
yfpd5=np.diff(yfp5)
c5=(cfpd5/td)
r5=(rfpd5/td)
y5=(yfpd5/td)  
gr5=(1/od5[:-1])*(dod5/td)
kc5=(1/od5[:-1])*c5
kr5=(1/od5[:-1])*r5
ky5=(1/od5[:-1])*y5
#B3
dod6=np.diff(od6)
cfpd6=np.diff(cfp6)
rfpd6=np.diff(rfp6)
yfpd6=np.diff(yfp6)
c6=(cfpd6/td)
r6=(rfpd6/td)
y6=(yfpd6/td)  
gr6=(1/od6[:-1])*(dod6/td)
kc6=(1/od6[:-1])*c6
kr6=(1/od6[:-1])*r6
ky6=(1/od6[:-1])*y6
#B4
dod7=np.diff(od7)
cfpd7=np.diff(cfp7)
rfpd7=np.diff(rfp7)
yfpd7=np.diff(yfp7)
c7=(cfpd7/td)
r7=(rfpd7/td)
y7=(yfpd7/td)  
gr7=(1/od7[:-1])*(dod7/td)
kc7=(1/od7[:-1])*c7
kr7=(1/od7[:-1])*r7
ky7=(1/od7[:-1])*y7
#B5
dod8=np.diff(od8)
cfpd8=np.diff(cfp8)
rfpd8=np.diff(rfp8)
yfpd8=np.diff(yfp8)
c8=(cfpd8/td)
r8=(rfpd8/td)
y8=(yfpd8/td)  
gr8=(1/od8[:-1])*(dod8/td)
kc8=(1/od8[:-1])*c8
kr8=(1/od8[:-1])*r8
ky8=(1/od8[:-1])*y8
#B6
dod9=np.diff(od9)
cfpd9=np.diff(cfp9)
rfpd9=np.diff(rfp9)
yfpd9=np.diff(yfp9)
c9=(cfpd9/td)
r9=(rfpd9/td)
y9=(yfpd9/td)  
gr9=(1/od9[:-1])*(dod9/td)
kc9=(1/od9[:-1])*c9
kr9=(1/od9[:-1])*r9
ky9=(1/od9[:-1])*y9
#B7
dod10=np.diff(od10)
cfpd10=np.diff(cfp10)
rfpd10=np.diff(rfp10)
yfpd10=np.diff(yfp10)
c10=(cfpd10/td)
r10=(rfpd10/td)
y10=(yfpd10/td)  
gr10=(1/od10[:-1])*(dod10/td)
kc10=(1/od10[:-1])*c10
kr10=(1/od10[:-1])*r10
ky10=(1/od10[:-1])*y10

# %%
#derivadas
#Promedio
splcp=UnivariateSpline(t,cfpp)
splcp.set_smoothing_factor(1e6)
dcdtp=splcp.derivative(1)(t)
splrp=UnivariateSpline(t,rfpp)
splrp.set_smoothing_factor(1e7)
drdtp=splrp.derivative(1)(t)
splyp=UnivariateSpline(t,yfpp)
splyp.set_smoothing_factor(1e8)
dydtp=splyp.derivative(1)(t)
splop=UnivariateSpline(t,odp)
splop.set_smoothing_factor(1e-2)
dodtp=splop.derivative(1)(t)

grp2=(1/odp)*dodtp
kcp2=(1/odp)*dcdtp
krp2=(1/odp)*drdtp
kyp2=(1/odp)*dydtp
plt.figure()
plt.title('OD promedio')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,odp,'.')
plt.plot(t,splop(t))

#A3
splc1=UnivariateSpline(t,cfp1)
splc1.set_smoothing_factor(1e6)
dcdt1=splc1.derivative(1)(t)
splr1=UnivariateSpline(t,rfp1)
splr1.set_smoothing_factor(1e7)
drdt1=splr1.derivative(1)(t)
sply1=UnivariateSpline(t,yfp1)
sply1.set_smoothing_factor(1e8)
dydt1=sply1.derivative(1)(t)
splo1=UnivariateSpline(t,od1)
splo1.set_smoothing_factor(1e-2)
dodt1=splo1.derivative(1)(t)

gr12=(1/od1)*dodt1
kc12=(1/od1)*dcdt1
kr12=(1/od1)*drdt1
ky12=(1/od1)*dydt1
plt.figure()
plt.title('OD A3')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,od1,'.')
plt.plot(t,splo1(t))

#A4
splc2=UnivariateSpline(t,cfp2)
splc2.set_smoothing_factor(1e6)
dcdt2=splc2.derivative(1)(t)
splr2=UnivariateSpline(t,rfp2)
splr2.set_smoothing_factor(1e7)
drdt2=splr2.derivative(1)(t)
sply2=UnivariateSpline(t,yfp2)
sply2.set_smoothing_factor(1e8)
dydt2=sply2.derivative(1)(t)
splo2=UnivariateSpline(t,od2)
splo2.set_smoothing_factor(1e-2)
dodt2=splo2.derivative(1)(t)

gr22=(1/od2)*dodt2
kc22=(1/od2)*dcdt2
kr22=(1/od2)*drdt2
ky22=(1/od2)*dydt2
plt.figure()
plt.title('OD A4')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,od2,'.')
plt.plot(t,splo2(t))

#A5
splc3=UnivariateSpline(t,cfp3)
splc3.set_smoothing_factor(1e6)
dcdt3=splc3.derivative(1)(t)
splr3=UnivariateSpline(t,rfp3)
splr3.set_smoothing_factor(1e7)
drdt3=splr3.derivative(1)(t)
sply3=UnivariateSpline(t,yfp3)
sply3.set_smoothing_factor(1e8)
dydt3=sply3.derivative(1)(t)
splo3=UnivariateSpline(t,od3)
splo3.set_smoothing_factor(1e-2)
dodt3=splo3.derivative(1)(t)

gr32=(1/od3)*dodt3
kc32=(1/od3)*dcdt3
kr32=(1/od3)*drdt3
ky32=(1/od3)*dydt3
plt.figure()
plt.title('OD A5')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,od3,'.')
plt.plot(t,splo3(t))

#A6
splc4=UnivariateSpline(t,cfp4)
splc4.set_smoothing_factor(1e6)
dcdt4=splc4.derivative(1)(t)
splr4=UnivariateSpline(t,rfp4)
splr4.set_smoothing_factor(1e7)
drdt4=splr4.derivative(1)(t)
sply4=UnivariateSpline(t,yfp4)
sply4.set_smoothing_factor(1e8)
dydt4=sply4.derivative(1)(t)
splo4=UnivariateSpline(t,od4)
splo4.set_smoothing_factor(1e-2)
dodt4=splo4.derivative(1)(t)

gr42=(1/od4)*dodt4
kc42=(1/od4)*dcdt4
kr42=(1/od4)*drdt4
ky42=(1/od4)*dydt4
plt.figure()
plt.title('OD A6')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,od4,'.')
plt.plot(t,splo4(t))

#A7
splc5=UnivariateSpline(t,cfp5)
splc5.set_smoothing_factor(1e6)
dcdt5=splc5.derivative(1)(t)
splr5=UnivariateSpline(t,rfp5)
splr5.set_smoothing_factor(1e7)
drdt5=splr5.derivative(1)(t)
sply5=UnivariateSpline(t,yfp5)
sply5.set_smoothing_factor(1e8)
dydt5=sply5.derivative(1)(t)
splo5=UnivariateSpline(t,od5)
splo5.set_smoothing_factor(1e-2)
dodt5=splo5.derivative(1)(t)

gr52=(1/od5)*dodt5
kc52=(1/od5)*dcdt5
kr52=(1/od5)*drdt5
ky52=(1/od5)*dydt5
plt.figure()
plt.title('OD A7')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,od5,'.')
plt.plot(t,splo5(t))


#B3
splc6=UnivariateSpline(t,cfp6)
splc6.set_smoothing_factor(1e6)
dcdt6=splc6.derivative(1)(t)
splr6=UnivariateSpline(t,rfp6)
splr6.set_smoothing_factor(1e7)
drdt6=splr6.derivative(1)(t)
sply6=UnivariateSpline(t,yfp6)
sply6.set_smoothing_factor(1e8)
dydt6=sply6.derivative(1)(t)
splo6=UnivariateSpline(t,od6)
splo6.set_smoothing_factor(1e-2)
dodt6=splo6.derivative(1)(t)

gr62=(1/od6)*dodt6
kc62=(1/od6)*dcdt6
kr62=(1/od6)*drdt6
ky62=(1/od6)*dydt6
plt.figure()
plt.title('OD B3')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,od6,'.')
plt.plot(t,splo6(t))

#B4
splc7=UnivariateSpline(t,cfp7)
splc7.set_smoothing_factor(1e6)
dcdt7=splc7.derivative(1)(t)
splr7=UnivariateSpline(t,rfp7)
splr7.set_smoothing_factor(1e7)
drdt7=splr7.derivative(1)(t)
sply7=UnivariateSpline(t,yfp7)
sply7.set_smoothing_factor(1e8)
dydt7=sply7.derivative(1)(t)
splo7=UnivariateSpline(t,od7)
splo7.set_smoothing_factor(1e-2)
dodt7=splo7.derivative(1)(t)

gr72=(1/od7)*dodt7
kc72=(1/od7)*dcdt7
kr72=(1/od7)*drdt7
ky72=(1/od7)*dydt7
plt.figure()
plt.title('OD B4')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,od7,'.')
plt.plot(t,splo7(t))

#B5
splc8=UnivariateSpline(t,cfp8)
splc8.set_smoothing_factor(1e6)
dcdt8=splc8.derivative(1)(t)
splr8=UnivariateSpline(t,rfp8)
splr8.set_smoothing_factor(1e7)
drdt8=splr8.derivative(1)(t)
sply8=UnivariateSpline(t,yfp8)
sply8.set_smoothing_factor(1e8)
dydt8=sply8.derivative(1)(t)
splo8=UnivariateSpline(t,od8)
splo8.set_smoothing_factor(1e-2)
dodt8=splo8.derivative(1)(t)

gr82=(1/od8)*dodt8
kc82=(1/od8)*dcdt8
kr82=(1/od8)*drdt8
ky82=(1/od8)*dydt8
plt.figure()
plt.title('OD B5')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,od8,'.')
plt.plot(t,splo8(t))

#B6
splc9=UnivariateSpline(t,cfp9)
splc9.set_smoothing_factor(1e6)
dcdt9=splc9.derivative(1)(t)
splr9=UnivariateSpline(t,rfp9)
splr9.set_smoothing_factor(1e7)
drdt9=splr9.derivative(1)(t)
sply9=UnivariateSpline(t,yfp9)
sply9.set_smoothing_factor(1e8)
dydt9=sply9.derivative(1)(t)
splo9=UnivariateSpline(t,od9)
splo9.set_smoothing_factor(1e-2)
dodt9=splo9.derivative(1)(t)

gr92=(1/od9)*dodt9
kc92=(1/od9)*dcdt9
kr92=(1/od9)*drdt9
ky92=(1/od9)*dydt9
plt.figure()
plt.title('OD B6')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,od9,'.')
plt.plot(t,splo9(t))

#B7
splc10=UnivariateSpline(t,cfp10)
splc10.set_smoothing_factor(1e6)
dcdt10=splc10.derivative(1)(t)
splr10=UnivariateSpline(t,rfp10)
splr10.set_smoothing_factor(1e7)
drdt10=splr10.derivative(1)(t)
sply10=UnivariateSpline(t,yfp10)
sply10.set_smoothing_factor(1e8)
dydt10=sply10.derivative(1)(t)
splo10=UnivariateSpline(t,od10)
splo10.set_smoothing_factor(1e-2)
dodt10=splo10.derivative(1)(t)

gr102=(1/od10)*dodt10
kc102=(1/od10)*dcdt10
kr102=(1/od10)*drdt10
ky102=(1/od10)*dydt10
plt.figure()
plt.title('OD B7')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,od10,'.')
plt.plot(t,splo10(t))
# Out:
# C:\Users\maca\Anaconda3\envs\BIO399E\lib\site-packages\scipy\interpolate\fitpack2.py:222: UserWarning:
# A theoretically impossible result was found during the iteration
# proces for finding a smoothing spline with fp = s: s too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\maca\Anaconda3\envs\BIO399E\lib\site-packages\scipy\interpolate\fitpack2.py:222: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)

# %%
#gráficos correlación entre FPs
plt.figure()
plt.title('YFP/CFP')
plt.ylabel('YFP(AU)')
plt.xlabel('CFP(AU)')
plt.plot(cfp1,yfp1,label='A3')
plt.plot(cfp2,yfp2,label='A4')
plt.plot(cfp3,yfp3,label='A5')
plt.plot(cfp4,yfp4,label='A6')
plt.plot(cfp5,yfp5,label='A7')
plt.plot(cfp6,yfp6,label='B3')
plt.plot(cfp7,yfp7,label='B4')
plt.plot(cfp8,yfp8,label='B5')
plt.plot(cfp9,yfp9,label='B6')
plt.plot(cfp10,yfp10,label='B7')
plt.plot(cfpp,yfpp,label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('RFP/CFP')
plt.ylabel('RFP(AU)')
plt.xlabel('CFP(AU)')
plt.plot(cfp1,rfp1,label='A3')
plt.plot(cfp2,rfp2,label='A4')
plt.plot(cfp3,rfp3,label='A5')
plt.plot(cfp4,rfp4,label='A6')
plt.plot(cfp5,rfp5,label='A7')
plt.plot(cfp6,rfp6,label='B3')
plt.plot(cfp7,rfp7,label='B4')
plt.plot(cfp8,rfp8,label='B5')
plt.plot(cfp9,rfp9,label='B6')
plt.plot(cfp10,rfp10,label='B7')
plt.plot(cfpp,rfpp,label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('RFP/YFP')
plt.ylabel('RFP(AU)')
plt.xlabel('YFP(AU)')
plt.plot(yfp1,rfp1,label='A3')
plt.plot(yfp2,rfp2,label='A4')
plt.plot(yfp3,rfp3,label='A5')
plt.plot(yfp4,rfp4,label='A6')
plt.plot(yfp5,rfp5,label='A7')
plt.plot(yfp6,rfp6,label='B3')
plt.plot(yfp7,rfp7,label='B4')
plt.plot(yfp8,rfp8,label='B5')
plt.plot(yfp9,rfp9,label='B6')
plt.plot(yfp10,rfp10,label='B7')
plt.plot(yfpp,rfpp,label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('CFP/YFP')
plt.ylabel('CFP(AU)')
plt.xlabel('YFP(AU)')
plt.plot(yfp1,cfp1,label='A3')
plt.plot(yfp2,cfp2,label='A4')
plt.plot(yfp3,cfp3,label='A5')
plt.plot(yfp4,cfp4,label='A6')
plt.plot(yfp5,cfp5,label='A7')
plt.plot(yfp6,cfp6,label='B3')
plt.plot(yfp7,cfp7,label='B4')
plt.plot(yfp8,cfp8,label='B5')
plt.plot(yfp9,cfp9,label='B6')
plt.plot(yfp10,cfp10,label='B7')
plt.plot(yfpp,cfpp,label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('CFP/RFP')
plt.ylabel('CFP(AU)')
plt.xlabel('RFP(AU)')
plt.plot(rfp1,cfp1,label='A3')
plt.plot(rfp2,cfp2,label='A4')
plt.plot(rfp3,cfp3,label='A5')
plt.plot(rfp4,cfp4,label='A6')
plt.plot(rfp5,cfp5,label='A7')
plt.plot(rfp6,cfp6,label='B3')
plt.plot(rfp7,cfp7,label='B4')
plt.plot(rfp8,cfp8,label='B5')
plt.plot(rfp9,cfp9,label='B6')
plt.plot(rfp10,cfp10,label='B7')
plt.plot(rfpp,cfpp,label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('YFP/RFP')
plt.ylabel('YFP(AU)')
plt.xlabel('RFP(AU)')
plt.plot(rfp1,yfp1,label='A3')
plt.plot(rfp2,yfp2,label='A4')
plt.plot(rfp3,yfp3,label='A5')
plt.plot(rfp4,yfp4,label='A6')
plt.plot(rfp5,yfp5,label='A7')
plt.plot(rfp6,yfp6,label='B3')
plt.plot(rfp7,yfp7,label='B4')
plt.plot(rfp8,yfp8,label='B5')
plt.plot(rfp9,yfp9,label='B6')
plt.plot(rfp10,yfp10,label='B7')
plt.plot(rfpp,yfpp,label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

# %%
#k diffs contra tiempo y gr, gr contra tiempo
plt.figure()
plt.title('Tasa de expresión diff CFP')
plt.xlabel('Tiempo')
plt.ylabel('Kc')
plt.plot(t[:-1],kc1,'.',label='A3')
plt.plot(t[:-1],kc2,'.',label='A4')
plt.plot(t[:-1],kc3,'.',label='A5')
plt.plot(t[:-1],kc4,'.',label='A6')
plt.plot(t[:-1],kc5,'.',label='A7')
plt.plot(t[:-1],kc6,'.',label='B3')
plt.plot(t[:-1],kc7,'.',label='B4')
plt.plot(t[:-1],kc8,'.',label='B5')
plt.plot(t[:-1],kc9,'.',label='B6')
plt.plot(t[:-1],kc10,'.',label='B7')
plt.plot(t[:-1],kcp,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('Tasa de expresión diff RFP')
plt.xlabel('tiempo')
plt.ylabel('Kr')
plt.plot(t[:-1],kr1,'.',label='A3')
plt.plot(t[:-1],kr2,'.',label='A4')
plt.plot(t[:-1],kr3,'.',label='A5')
plt.plot(t[:-1],kr4,'.',label='A6')
plt.plot(t[:-1],kr5,'.',label='A7')
plt.plot(t[:-1],kr6,'.',label='B3')
plt.plot(t[:-1],kr7,'.',label='B4')
plt.plot(t[:-1],kr8,'.',label='B5')
plt.plot(t[:-1],kr9,'.',label='B6')
plt.plot(t[:-1],kr10,'.',label='B7')
plt.plot(t[:-1],krp,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('Tasa de expresión diff YFP')
plt.xlabel('t')
plt.ylabel('Ky')
plt.plot(t[:-1],ky1,'.',label='A3')
plt.plot(t[:-1],ky2,'.',label='A4')
plt.plot(t[:-1],ky3,'.',label='A5')
plt.plot(t[:-1],ky4,'.',label='A6')
plt.plot(t[:-1],ky5,'.',label='A7')
plt.plot(t[:-1],ky6,'.',label='B3')
plt.plot(t[:-1],ky7,'.',label='B4')
plt.plot(t[:-1],ky8,'.',label='B5')
plt.plot(t[:-1],ky9,'.',label='B6')
plt.plot(t[:-1],ky10,'.',label='B7')
plt.plot(t[:-1],kyp,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

#vs GR
plt.figure()
plt.title('Tasa de expresión diff CFP')
plt.xlabel('Growth rate')
plt.ylabel('Kc')
plt.plot(gr1,kc1,'.',label='A3')
plt.plot(gr2,kc2,'.',label='A4')
plt.plot(gr3,kc3,'.',label='A5')
plt.plot(gr4,kc4,'.',label='A6')
plt.plot(gr5,kc5,'.',label='A7')
plt.plot(gr6,kc6,'.',label='B3')
plt.plot(gr7,kc7,'.',label='B4')
plt.plot(gr8,kc8,'.',label='B5')
plt.plot(gr9,kc9,'.',label='B6')
plt.plot(gr10,kc10,'.',label='B7')
plt.plot(grp,kcp,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('Tasa de expresión diff RFP')
plt.xlabel('Growth rate')
plt.ylabel('Kr')
plt.plot(gr1,kr1,'.',label='A3')
plt.plot(gr2,kr2,'.',label='A4')
plt.plot(gr3,kr3,'.',label='A5')
plt.plot(gr4,kr4,'.',label='A6')
plt.plot(gr5,kr5,'.',label='A7')
plt.plot(gr6,kr6,'.',label='B3')
plt.plot(gr7,kr7,'.',label='B4')
plt.plot(gr8,kr8,'.',label='B5')
plt.plot(gr9,kr9,'.',label='B6')
plt.plot(gr10,kr10,'.',label='B7')
plt.plot(grp,krp,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('Tasa de expresión diff YFP')
plt.xlabel('Growth rate')
plt.ylabel('Ky')
plt.plot(gr1,ky1,'.',label='A3')
plt.plot(gr2,ky2,'.',label='A4')
plt.plot(gr3,ky3,'.',label='A5')
plt.plot(gr4,ky4,'.',label='A6')
plt.plot(gr5,ky5,'.',label='A7')
plt.plot(gr6,ky6,'.',label='B3')
plt.plot(gr7,ky7,'.',label='B4')
plt.plot(gr8,ky8,'.',label='B5')
plt.plot(gr9,ky9,'.',label='B6')
plt.plot(gr10,ky10,'.',label='B7')
plt.plot(grp,kyp,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('GRs')
plt.xlabel('Tiempo')
plt.ylabel('GR')
plt.plot(t[:-1],gr1,label='A3')
plt.plot(t[:-1],gr2,label='A4')
plt.plot(t[:-1],gr3,label='A5')
plt.plot(t[:-1],gr4,label='A6')
plt.plot(t[:-1],gr5,label='A7')
plt.plot(t[:-1],gr6,label='B3')
plt.plot(t[:-1],gr7,label='B4')
plt.plot(t[:-1],gr8,label='B5')
plt.plot(t[:-1],gr9,label='B6')
plt.plot(t[:-1],gr10,label='B7')
plt.plot(t[:-1],grp,label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

# %%
#k derv contra tiempo y gr, gr contra tiempo
plt.figure()
plt.title('Tasa de expresión CFP')
plt.xlabel('Tiempo')
plt.ylabel('Kc')
plt.plot(t,kc12,'.',label='A3')
plt.plot(t,kc22,'.',label='A4')
plt.plot(t,kc32,'.',label='A5')
plt.plot(t,kc42,'.',label='A6')
plt.plot(t,kc52,'.',label='A7')
plt.plot(t,kc62,'.',label='B3')
plt.plot(t,kc72,'.',label='B4')
plt.plot(t,kc82,'.',label='B5')
plt.plot(t,kc92,'.',label='B6')
plt.plot(t,kc102,'.',label='B7')
plt.plot(t,kcp2,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('Tasa de expresión RFP')
plt.xlabel('tiempo')
plt.ylabel('Kr')
plt.plot(t,kr12,'.',label='A3')
plt.plot(t,kr22,'.',label='A4')
plt.plot(t,kr32,'.',label='A5')
plt.plot(t,kr42,'.',label='A6')
plt.plot(t,kr52,'.',label='A7')
plt.plot(t,kr62,'.',label='B3')
plt.plot(t,kr72,'.',label='B4')
plt.plot(t,kr82,'.',label='B5')
plt.plot(t,kr92,'.',label='B6')
plt.plot(t,kr102,'.',label='B7')
plt.plot(t,krp2,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('Tasa de expresión YFP')
plt.xlabel('t')
plt.ylabel('Ky')
plt.plot(t,ky12,'.',label='A3')
plt.plot(t,ky22,'.',label='A4')
plt.plot(t,ky32,'.',label='A5')
plt.plot(t,ky42,'.',label='A6')
plt.plot(t,ky52,'.',label='A7')
plt.plot(t,ky62,'.',label='B3')
plt.plot(t,ky72,'.',label='B4')
plt.plot(t,ky82,'.',label='B5')
plt.plot(t,ky92,'.',label='B6')
plt.plot(t,ky102,'.',label='B7')
plt.plot(t,kyp2,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

#vs GR
plt.figure()
plt.title('Tasa de expresión CFP')
plt.ylabel('Kc')
plt.xlabel('Growth rate')
plt.plot(gr12,kc12,'.',label='A3')
plt.plot(gr22,kc22,'.',label='A4')
plt.plot(gr32,kc32,'.',label='A5')
plt.plot(gr42,kc42,'.',label='A6')
plt.plot(gr52,kc52,'.',label='A7')
plt.plot(gr62,kc62,'.',label='B3')
plt.plot(gr72,kc72,'.',label='B4')
plt.plot(gr82,kc82,'.',label='B5')
plt.plot(gr92,kc92,'.',label='B6')
plt.plot(gr102,kc102,'.',label='B7')
plt.plot(grp2,kcp2,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('Tasa de expresión RFP')
plt.ylabel('Kr')
plt.xlabel('Growth rate')
plt.plot(gr12,kr12,'.',label='A3')
plt.plot(gr22,kr22,'.',label='A4')
plt.plot(gr32,kr32,'.',label='A5')
plt.plot(gr42,kr42,'.',label='A6')
plt.plot(gr52,kr52,'.',label='A7')
plt.plot(gr62,kr62,'.',label='B3')
plt.plot(gr72,kr72,'.',label='B4')
plt.plot(gr82,kr82,'.',label='B5')
plt.plot(gr92,kr92,'.',label='B6')
plt.plot(gr102,kr102,'.',label='B7')
plt.plot(grp2,krp2,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('Tasa de expresión YFP')
plt.ylabel('Ky')
plt.xlabel('Growth rate')
plt.plot(gr12,ky12,'.',label='A3')
plt.plot(gr22,ky22,'.',label='A4')
plt.plot(gr32,ky32,'.',label='A5')
plt.plot(gr42,ky42,'.',label='A6')
plt.plot(gr52,ky52,'.',label='A7')
plt.plot(gr62,ky62,'.',label='B3')
plt.plot(gr72,ky72,'.',label='B4')
plt.plot(gr82,ky82,'.',label='B5')
plt.plot(gr92,ky92,'.',label='B6')
plt.plot(gr102,ky102,'.',label='B7')
plt.plot(grp2,kyp2,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('GR')
plt.ylabel('Growth rate')
plt.xlabel('t')
plt.plot(t,gr12,label='A3')
plt.plot(t,gr22,label='A4')
plt.plot(t,gr32,label='A5')
plt.plot(t,gr42,label='A6')
plt.plot(t,gr52,label='A7')
plt.plot(t,gr62,label='B3')
plt.plot(t,gr72,label='B4')
plt.plot(t,gr82,label='B5')
plt.plot(t,gr92,label='B6')
plt.plot(t,gr102,label='B7')
plt.plot(t,grp2,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

# %%
#Promedio
logodp=np.log(odp)
splop=UnivariateSpline(t,logodp)
splop.set_smoothing_factor(1e-2)
dlodtp=splop.derivative(1)(t)
plt.figure()
plt.title('logOD Promedio')
plt.ylabel('OD600(Abs)')
plt.xlabel('Tiempo(min)')
plt.plot(t,logodp,'.')
plt.plot(t,splop(t))

#A3
logod1=np.log(od1)
splo1=UnivariateSpline(t,logod1)
splo1.set_smoothing_factor(1e-2)
dlodt1=splo1.derivative(1)(t)
#A4
logod2=np.log(od2)
splo2=UnivariateSpline(t,logod2)
splo2.set_smoothing_factor(1e-2)
dlodt2=splo2.derivative(1)(t)
#A5
logod3=np.log(od3)
splo3=UnivariateSpline(t,logod3)
splo3.set_smoothing_factor(1e-2)
dlodt3=splo3.derivative(1)(t)
#A6
logod4=np.log(od4)
splo4=UnivariateSpline(t,logod4)
splo4.set_smoothing_factor(1e-2)
dlodt4=splo1.derivative(1)(t)
#A7
logod5=np.log(od5)
splo5=UnivariateSpline(t,logod5)
splo5.set_smoothing_factor(1e-2)
dlodt5=splo5.derivative(1)(t)
#B3
logod6=np.log(od6)
splo6=UnivariateSpline(t,logod6)
splo6.set_smoothing_factor(1e-2)
dlodt6=splo6.derivative(1)(t)
#B4
logod7=np.log(od7)
splo7=UnivariateSpline(t,logod7)
splo7.set_smoothing_factor(1e-2)
dlodt7=splo7.derivative(1)(t)
#B5
logod8=np.log(od8)
splo8=UnivariateSpline(t,logod8)
splo8.set_smoothing_factor(1e-2)
dlodt8=splo8.derivative(1)(t)
#B6
logod9=np.log(od9)
splo9=UnivariateSpline(t,logod9)
splo9.set_smoothing_factor(1e-2)
dlodt9=splo9.derivative(1)(t)
#B7
logod10=np.log(od10)
splo10=UnivariateSpline(t,logod10)
splo10.set_smoothing_factor(1e-2)
dlodt10=splo10.derivative(1)(t)

# %%
#GRlog en t
plt.figure()
plt.title('Tasas de crecimiento')
plt.xlabel('tiempo(min)')
plt.ylabel('GRlog')
plt.plot(t,dlodt1,label='A3')
plt.plot(t,dlodt2,label='A4')
plt.plot(t,dlodt3,label='A5')
plt.plot(t,dlodt4,label='A6')
plt.plot(t,dlodt5,label='A7')
plt.plot(t,dlodt6,label='B3')
plt.plot(t,dlodt7,label='B4')
plt.plot(t,dlodt8,label='B5')
plt.plot(t,dlodt9,label='B6')
plt.plot(t,dlodt10,label='B7')
plt.plot(t,dlodtp,label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

#K vs GRlog
plt.figure()
plt.title('Tasa expresión CFP')
plt.xlabel('Growth rate')
plt.ylabel('Kc')
plt.plot(dlodt1,kc12,'.',label='A3')
plt.plot(dlodt1,kc22,'.',label='A4')
plt.plot(dlodt1,kc32,'.',label='A5')
plt.plot(dlodt1,kc42,'.',label='A6')
plt.plot(dlodt1,kc52,'.',label='A7')
plt.plot(dlodt1,kc62,'.',label='B3')
plt.plot(dlodt1,kc72,'.',label='B4')
plt.plot(dlodt1,kc82,'.',label='B5')
plt.plot(dlodt1,kc92,'.',label='B6')
plt.plot(dlodt1,kc102,'.',label='B7')
plt.plot(dlodtp,kcp2,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))


plt.figure()
plt.title('Tasa expresión RFP')
plt.xlabel('Growth rate')
plt.ylabel('Kr')
plt.plot(dlodt1,kr12,'.',label='A3')
plt.plot(dlodt1,kr22,'.',label='A4')
plt.plot(dlodt1,kr32,'.',label='A5')
plt.plot(dlodt1,kr42,'.',label='A6')
plt.plot(dlodt1,kr52,'.',label='A7')
plt.plot(dlodt1,kr62,'.',label='B3')
plt.plot(dlodt1,kr72,'.',label='B4')
plt.plot(dlodt1,kr82,'.',label='B5')
plt.plot(dlodt1,kr92,'.',label='B6')
plt.plot(dlodt1,kr102,'.',label='B7')
plt.plot(dlodtp,krp2,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.figure()
plt.title('Tasa expresión YFP')
plt.xlabel('Growth rate')
plt.ylabel('Ky')
plt.plot(dlodt1,ky12,'.',label='A3')
plt.plot(dlodt1,ky22,'.',label='A4')
plt.plot(dlodt1,ky32,'.',label='A5')
plt.plot(dlodt1,ky42,'.',label='A6')
plt.plot(dlodt1,ky52,'.',label='A7')
plt.plot(dlodt1,ky62,'.',label='B3')
plt.plot(dlodt1,ky72,'.',label='B4')
plt.plot(dlodt1,ky82,'.',label='B5')
plt.plot(dlodt1,ky92,'.',label='B6')
plt.plot(dlodt1,ky102,'.',label='B7')
plt.plot(dlodtp,kyp2,'.',label='Promedio')
plt.legend(bbox_to_anchor=(1.05, 1.05))
