# %%
import flapjack
from flapjack import registry as reg
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
registry = reg.Registry(database_name='data', username='carli', password='1335')

# %%
sss = registry.get_plasmid('std:RFP/std:YFP/std:CFP')
lts = registry.get_plasmid('pLux76:RFP/pTet:YFP/std:CFP')
lss = registry.get_plasmid('pLux76:RFP/std:YFP/std:CFP')
lis = registry.get_plasmid('pLux76:RFP/pLacI:YFP/std:CFP')

#print np.unique(sss['samples_experiment_id'].values)  #command to get sample id values

# %%
# Experiment 1
sss_ex1_glu = sss[(sss.samples_experiment_id==1)&(sss.samples_media=='M9-glucosa')]
sss_ex1_gli = sss[(sss.samples_experiment_id==1)&(sss.samples_media=='M9-glicerol')]
lts_ex1_glu = lts[(lts.samples_experiment_id==1)&(lts.samples_media=='M9-glucosa')]
lts_ex1_gli = lts[(lts.samples_experiment_id==1)&(lts.samples_media=='M9-glicerol')]
lss_ex1_glu = lss[(lss.samples_experiment_id==1)&(lss.samples_media=='M9-glucosa')]
lss_ex1_gli = lss[(lss.samples_experiment_id==1)&(lss.samples_media=='M9-glicerol')]
lis_ex1_glu = lis[(lis.samples_experiment_id==1)&(lis.samples_media=='M9-glucosa')]
lis_ex1_gli = lis[(lis.samples_experiment_id==1)&(lis.samples_media=='M9-glicerol')]

# Experiment 2
sss_ex2_glu = sss[(sss.samples_experiment_id==34)&(sss.samples_media=='M9-glucosa')]
sss_ex2_gli = sss[(sss.samples_experiment_id==34)&(sss.samples_media=='M9-glicerol')]
lts_ex2_glu = lts[(lts.samples_experiment_id==34)&(lts.samples_media=='M9-glucosa')]
lts_ex2_gli = lts[(lts.samples_experiment_id==34)&(lts.samples_media=='M9-glicerol')]
lss_ex2_glu = lss[(lss.samples_experiment_id==34)&(lss.samples_media=='M9-glucosa')]
lss_ex2_gli = lss[(lss.samples_experiment_id==34)&(lss.samples_media=='M9-glicerol')]
lis_ex2_glu = lis[(lis.samples_experiment_id==34)&(lis.samples_media=='M9-glucosa')]
lis_ex2_gli = lis[(lis.samples_experiment_id==34)&(lis.samples_media=='M9-glicerol')]

# Experiment 3
sss_ex3_glu = sss[(sss.samples_experiment_id==35)&(sss.samples_media=='M9-glucosa')]
sss_ex3_gli = sss[(sss.samples_experiment_id==35)&(sss.samples_media=='M9-glicerol')]
lts_ex3_glu = lts[(lts.samples_experiment_id==35)&(lts.samples_media=='M9-glucosa')]
lts_ex3_gli = lts[(lts.samples_experiment_id==35)&(lts.samples_media=='M9-glicerol')]
lss_ex3_glu = lss[(lss.samples_experiment_id==35)&(lss.samples_media=='M9-glucosa')]
lss_ex3_gli = lss[(lss.samples_experiment_id==35)&(lss.samples_media=='M9-glicerol')]
lis_ex3_glu = lis[(lis.samples_experiment_id==35)&(lis.samples_media=='M9-glucosa')]
lis_ex3_gli = lis[(lis.samples_experiment_id==35)&(lis.samples_media=='M9-glicerol')]

# %%
#Experiment 1 Glucosa

r_sss_ex1_glu = sss_ex1_glu[(sss_ex1_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_sss_ex1_glu = sss_ex1_glu[(sss_ex1_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_sss_ex1_glu = sss_ex1_glu[(sss_ex1_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_sss_ex1_glu = sss_ex1_glu[(sss_ex1_glu.measurements_name=='OD600:600')]['measurements_value'].values

r_lts_ex1_glu = lts_ex1_glu[(lts_ex1_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lts_ex1_glu = lts_ex1_glu[(lts_ex1_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lts_ex1_glu = lts_ex1_glu[(lts_ex1_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lts_ex1_glu = lts_ex1_glu[(lts_ex1_glu.measurements_name=='OD600:600')]['measurements_value'].values

r_lss_ex1_glu = lss_ex1_glu[(lss_ex1_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lss_ex1_glu = lss_ex1_glu[(lss_ex1_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lss_ex1_glu = lss_ex1_glu[(lss_ex1_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lss_ex1_glu = lss_ex1_glu[(lss_ex1_glu.measurements_name=='OD600:600')]['measurements_value'].values

r_lis_ex1_glu = lis_ex1_glu[(lis_ex1_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lis_ex1_glu = lis_ex1_glu[(lis_ex1_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lis_ex1_glu = lis_ex1_glu[(lis_ex1_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lis_ex1_glu = lis_ex1_glu[(lis_ex1_glu.measurements_name=='OD600:600')]['measurements_value'].values

plt.figure(figsize=(12, 4))

plt.subplot(1,2,1)
plt.title ('Experiment 1 Glucose')
plt.plot(c_sss_ex1_glu, r_sss_ex1_glu,'r.')
plt.plot(c_lts_ex1_glu, r_lts_ex1_glu,'c.')
plt.plot(c_lss_ex1_glu, r_lss_ex1_glu,'g.')
plt.plot(c_lis_ex1_glu, r_lis_ex1_glu,'m.')
plt.xlabel('CFP')
plt.ylabel('RFP')

plt.subplot(1,2,2)
plt.title ('Experiment 1 Glucose')
plt.plot(c_sss_ex1_glu, y_sss_ex1_glu,'r.')
plt.plot(c_lts_ex1_glu, y_lts_ex1_glu,'c.')
plt.plot(c_lss_ex1_glu, y_lss_ex1_glu,'g.')
plt.plot(c_lis_ex1_glu, y_lis_ex1_glu,'m.')
plt.xlabel('CFP')
plt.ylabel('YFP')

plt.tight_layout()
plt.show()

# %%
#Experiment 1 Glicerol

r_sss_ex1_gli = sss_ex1_gli[(sss_ex1_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_sss_ex1_gli = sss_ex1_gli[(sss_ex1_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_sss_ex1_gli = sss_ex1_gli[(sss_ex1_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_sss_ex1_gli = sss_ex1_gli[(sss_ex1_gli.measurements_name=='OD600:600')]['measurements_value'].values

r_lts_ex1_gli = lts_ex1_gli[(lts_ex1_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lts_ex1_gli = lts_ex1_gli[(lts_ex1_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lts_ex1_gli = lts_ex1_gli[(lts_ex1_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lts_ex1_gli = lts_ex1_gli[(lts_ex1_gli.measurements_name=='OD600:600')]['measurements_value'].values

r_lss_ex1_gli = lss_ex1_gli[(lss_ex1_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lss_ex1_gli = lss_ex1_gli[(lss_ex1_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lss_ex1_gli = lss_ex1_gli[(lss_ex1_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lss_ex1_gli = lss_ex1_gli[(lss_ex1_gli.measurements_name=='OD600:600')]['measurements_value'].values

r_lis_ex1_gli = lis_ex1_gli[(lis_ex1_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lis_ex1_gli = lis_ex1_gli[(lis_ex1_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lis_ex1_gli = lis_ex1_gli[(lis_ex1_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lis_ex1_gli = lis_ex1_gli[(lis_ex1_gli.measurements_name=='OD600:600')]['measurements_value'].values


plt.figure(figsize=(12, 4))

plt.subplot(1,2,1)
plt.title ('Experiment 1 Glicerol')
plt.plot(c_sss_ex1_gli, r_sss_ex1_gli,'r.')
plt.plot(c_lts_ex1_gli, r_lts_ex1_gli,'c.')
plt.plot(c_lss_ex1_gli, r_lss_ex1_gli,'g.')
plt.plot(c_lis_ex1_gli, r_lis_ex1_gli,'m.')
plt.xlabel('CFP')
plt.ylabel('RFP')

plt.subplot(1,2,2)
plt.title ('Experiment 1 Glicerol')
plt.plot(c_sss_ex1_gli, y_sss_ex1_gli,'r.')
plt.plot(c_lts_ex1_gli, y_lts_ex1_gli,'c.')
plt.plot(c_lss_ex1_gli, y_lss_ex1_gli,'g.')
plt.plot(c_lis_ex1_gli, y_lis_ex1_gli,'m.')
plt.xlabel('CFP')
plt.ylabel('YFP')

plt.tight_layout()
plt.show()

# %%
#Experiment 2 Glucosa

r_sss_ex2_glu = sss_ex2_glu[(sss_ex2_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_sss_ex2_glu = sss_ex2_glu[(sss_ex2_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_sss_ex2_glu = sss_ex2_glu[(sss_ex2_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_sss_ex2_glu = sss_ex2_glu[(sss_ex2_glu.measurements_name=='OD600:600')]['measurements_value'].values

r_lts_ex2_glu = lts_ex2_glu[(lts_ex2_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lts_ex2_glu = lts_ex2_glu[(lts_ex2_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lts_ex2_glu = lts_ex2_glu[(lts_ex2_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lts_ex2_glu = lts_ex2_glu[(lts_ex2_glu.measurements_name=='OD600:600')]['measurements_value'].values

r_lss_ex2_glu = lss_ex2_glu[(lss_ex2_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lss_ex2_glu = lss_ex2_glu[(lss_ex2_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lss_ex2_glu = lss_ex2_glu[(lss_ex2_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lss_ex2_glu = lss_ex2_glu[(lss_ex2_glu.measurements_name=='OD600:600')]['measurements_value'].values

r_lis_ex2_glu = lis_ex2_glu[(lis_ex2_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lis_ex2_glu = lis_ex2_glu[(lis_ex2_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lis_ex2_glu = lis_ex2_glu[(lis_ex2_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lis_ex2_glu = lis_ex2_glu[(lis_ex2_glu.measurements_name=='OD600:600')]['measurements_value'].values

plt.figure(figsize=(12, 4))

plt.subplot(1,2,1)
plt.title ('Experiment 2 Glucose')
plt.plot(c_sss_ex2_glu, r_sss_ex2_glu,'r.')
plt.plot(c_lts_ex2_glu, r_lts_ex2_glu,'c.')
plt.plot(c_lss_ex2_glu, r_lss_ex2_glu,'g.')
plt.plot(c_lis_ex2_glu, r_lis_ex2_glu,'m.')
plt.xlabel('CFP')
plt.ylabel('RFP')

plt.subplot(1,2,2)
plt.title ('Experiment 2 Glucose')
plt.plot(c_sss_ex2_glu, y_sss_ex2_glu,'r.')
plt.plot(c_lts_ex2_glu, y_lts_ex2_glu,'c.')
plt.plot(c_lss_ex2_glu, y_lss_ex2_glu,'g.')
plt.plot(c_lis_ex2_glu, y_lis_ex2_glu,'m.')
plt.xlabel('CFP')
plt.ylabel('YFP')

plt.tight_layout()
plt.show()

# %%
#Experiment 2 Glicerol

r_sss_ex2_gli = sss_ex2_gli[(sss_ex2_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_sss_ex2_gli = sss_ex2_gli[(sss_ex2_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_sss_ex2_gli = sss_ex2_gli[(sss_ex2_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_sss_ex2_gli = sss_ex2_gli[(sss_ex2_gli.measurements_name=='OD600:600')]['measurements_value'].values

r_lts_ex2_gli = lts_ex2_gli[(lts_ex2_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lts_ex2_gli = lts_ex2_gli[(lts_ex2_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lts_ex2_gli = lts_ex2_gli[(lts_ex2_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lts_ex2_gli = lts_ex2_gli[(lts_ex2_gli.measurements_name=='OD600:600')]['measurements_value'].values

r_lss_ex2_gli = lss_ex2_gli[(lss_ex2_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lss_ex2_gli = lss_ex2_gli[(lss_ex2_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lss_ex2_gli = lss_ex2_gli[(lss_ex2_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lss_ex2_gli = lss_ex2_gli[(lss_ex2_gli.measurements_name=='OD600:600')]['measurements_value'].values

r_lis_ex2_gli = lis_ex2_gli[(lis_ex2_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lis_ex2_gli = lis_ex2_gli[(lis_ex2_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lis_ex2_gli = lis_ex2_gli[(lis_ex2_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lis_ex2_gli = lis_ex2_gli[(lis_ex2_gli.measurements_name=='OD600:600')]['measurements_value'].values


plt.figure(figsize=(12, 4))

plt.subplot(1,2,1)
plt.title ('Experiment 2 Glicerol')
plt.plot(c_sss_ex2_gli, r_sss_ex2_gli,'r.')
plt.plot(c_lts_ex2_gli, r_lts_ex2_gli,'c.')
plt.plot(c_lss_ex2_gli, r_lss_ex2_gli,'g.')
plt.plot(c_lis_ex2_gli, r_lis_ex2_gli,'m.')
plt.xlabel('CFP')
plt.ylabel('RFP')

plt.subplot(1,2,2)
plt.title ('Experiment 2 Glicerol')
plt.plot(c_sss_ex2_gli, y_sss_ex2_gli,'r.')
plt.plot(c_lts_ex2_gli, y_lts_ex2_gli,'c.')
plt.plot(c_lss_ex2_gli, y_lss_ex2_gli,'g.')
plt.plot(c_lis_ex2_gli, y_lis_ex2_gli,'m.')
plt.xlabel('CFP')
plt.ylabel('YFP')

plt.tight_layout()
plt.show()

# %%
#Experiment 3 Glucosa

r_sss_ex3_glu = sss_ex3_glu[(sss_ex3_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_sss_ex3_glu = sss_ex3_glu[(sss_ex3_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_sss_ex3_glu = sss_ex3_glu[(sss_ex3_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_sss_ex3_glu = sss_ex3_glu[(sss_ex3_glu.measurements_name=='OD600:600')]['measurements_value'].values

r_lts_ex3_glu = lts_ex3_glu[(lts_ex3_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lts_ex3_glu = lts_ex3_glu[(lts_ex3_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lts_ex3_glu = lts_ex3_glu[(lts_ex3_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lts_ex3_glu = lts_ex3_glu[(lts_ex3_glu.measurements_name=='OD600:600')]['measurements_value'].values

r_lss_ex3_glu = lss_ex3_glu[(lss_ex3_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lss_ex3_glu = lss_ex3_glu[(lss_ex3_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lss_ex3_glu = lss_ex3_glu[(lss_ex3_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lss_ex3_glu = lss_ex3_glu[(lss_ex3_glu.measurements_name=='OD600:600')]['measurements_value'].values

r_lis_ex3_glu = lis_ex3_glu[(lis_ex3_glu.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lis_ex3_glu = lis_ex3_glu[(lis_ex3_glu.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lis_ex3_glu = lis_ex3_glu[(lis_ex3_glu.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lis_ex3_glu = lis_ex3_glu[(lis_ex3_glu.measurements_name=='OD600:600')]['measurements_value'].values

plt.figure(figsize=(12, 4))

plt.subplot(1,2,1)
plt.title ('Experiment 3 Glucose')
plt.plot(c_sss_ex3_glu, r_sss_ex3_glu,'r.')
plt.plot(c_lts_ex3_glu, r_lts_ex3_glu,'c.')
plt.plot(c_lss_ex3_glu, r_lss_ex3_glu,'g.')
plt.plot(c_lis_ex3_glu, r_lis_ex3_glu,'m.')
plt.xlabel('CFP')
plt.ylabel('RFP')

plt.subplot(1,2,2)
plt.title ('Experiment 3 Glucose')
plt.plot(c_sss_ex3_glu, y_sss_ex3_glu,'r.')
plt.plot(c_lts_ex3_glu, y_lts_ex3_glu,'c.')
plt.plot(c_lss_ex3_glu, y_lss_ex3_glu,'g.')
plt.plot(c_lis_ex3_glu, y_lis_ex3_glu,'m.')
plt.xlabel('CFP')
plt.ylabel('YFP')

plt.tight_layout()
plt.show()

# %%
#Experiment 3 Glicerol

r_sss_ex3_gli = sss_ex3_gli[(sss_ex3_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_sss_ex3_gli = sss_ex3_gli[(sss_ex3_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_sss_ex3_gli = sss_ex3_gli[(sss_ex3_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_sss_ex3_gli = sss_ex3_gli[(sss_ex3_gli.measurements_name=='OD600:600')]['measurements_value'].values

r_lts_ex3_gli = lts_ex3_gli[(lts_ex3_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lts_ex3_gli = lts_ex3_gli[(lts_ex3_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lts_ex3_gli = lts_ex3_gli[(lts_ex3_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lts_ex3_gli = lts_ex3_gli[(lts_ex3_gli.measurements_name=='OD600:600')]['measurements_value'].values

r_lss_ex3_gli = lss_ex3_gli[(lss_ex3_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lss_ex3_gli = lss_ex3_gli[(lss_ex3_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lss_ex3_gli = lss_ex3_gli[(lss_ex3_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lss_ex3_gli = lss_ex3_gli[(lss_ex3_gli.measurements_name=='OD600:600')]['measurements_value'].values

r_lis_ex3_gli = lis_ex3_gli[(lis_ex3_gli.measurements_name=='RFP-YFP:585/10,620/15')]['measurements_value'].values
y_lis_ex3_gli = lis_ex3_gli[(lis_ex3_gli.measurements_name=='RFP-YFP:500/27,540/25')]['measurements_value'].values
c_lis_ex3_gli = lis_ex3_gli[(lis_ex3_gli.measurements_name=='CFP:420/50,485/20')]['measurements_value'].values
o_lis_ex3_gli = lis_ex3_gli[(lis_ex3_gli.measurements_name=='OD600:600')]['measurements_value'].values

plt.figure(figsize=(12, 4))

plt.subplot(1,2,1)
plt.title ('Experiment 3 Glicerol')
plt.plot(c_sss_ex3_gli, r_sss_ex3_gli,'r.')
plt.plot(c_lts_ex3_gli, r_lts_ex3_gli,'c.')
plt.plot(c_lss_ex3_gli, r_lss_ex3_gli,'g.')
plt.plot(c_lis_ex3_gli, r_lis_ex3_gli,'m.')
plt.xlabel('CFP')
plt.ylabel('RFP')

plt.subplot(1,2,2)
plt.title ('Experiment 3 Glicerol')
plt.plot(c_sss_ex3_gli, y_sss_ex3_gli,'r.')
plt.plot(c_lts_ex3_gli, y_lts_ex3_gli,'c.')
plt.plot(c_lss_ex3_gli, y_lss_ex3_gli,'g.')
plt.plot(c_lis_ex3_gli, y_lis_ex3_gli,'m.')
plt.xlabel('CFP')
plt.ylabel('YFP')

plt.tight_layout()
plt.show()

# %%
### Other stuff

plt.figure(figsize=(12,12))

plt.title ('Experiment 1,2,3 Glucose')

plt.plot(c_sss_ex1_glu, r_sss_ex1_glu,'r.')
plt.plot(c_sss_ex2_glu, r_sss_ex2_glu,'r+')
plt.plot(c_sss_ex3_glu, r_sss_ex3_glu,'r-')

plt.xlabel('CFP')
plt.ylabel('RFP')
plt.twinx()
plt.ylabel('OD')

plt.plot(c_sss_ex1_glu, o_sss_ex1_glu,'k.')
plt.plot(c_sss_ex2_glu, o_sss_ex2_glu,'k+')
plt.plot(c_sss_ex3_glu, o_sss_ex3_glu,'k-')

# %% [markdown]
# From here on colors are different

# %%
plt.figure(figsize=(12,12))

plt.title ('Experiment 1,2,3 Glucose')

plt.plot(c_sss_ex1_glu/o_sss_ex1_glu, r_sss_ex1_glu/o_sss_ex1_glu,'g.')
plt.plot(c_sss_ex2_glu/o_sss_ex2_glu, r_sss_ex2_glu/o_sss_ex2_glu,'c.')
plt.plot(c_sss_ex3_glu/o_sss_ex3_glu, r_sss_ex3_glu/o_sss_ex3_glu,'r.')

plt.xlabel('CFP/OD')
plt.ylabel('RFP/OD')

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title ('All exp. std-std-std glucose')
plt.plot(r_sss_ex1_glu/c_sss_ex1_glu,'g.')
plt.plot(r_sss_ex2_glu/c_sss_ex2_glu,'c.')
plt.plot(r_sss_ex3_glu/c_sss_ex3_glu,'r.')
plt.xlabel('')
plt.ylabel('RFP/CFP')

plt.subplot(1,2,2)
plt.title ('All exp. std-std-std glucose')
plt.plot(y_sss_ex1_glu/c_sss_ex1_glu,'g.')
plt.plot(y_sss_ex2_glu/c_sss_ex2_glu,'c.')
plt.plot(y_sss_ex3_glu/c_sss_ex3_glu,'r.')
plt.xlabel('')
plt.ylabel('YFP/CFP')

plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title ('All exp. std-std-std glucose')
plt.plot(np.log(o_sss_ex1_glu),'g.')
plt.plot(np.log(o_sss_ex2_glu),'c.')
plt.plot(np.log(o_sss_ex3_glu),'r.')
plt.xlabel('')
plt.ylabel('RFP/CFP')

plt.subplot(1,2,2)
plt.title ('All exp. std-std-std glucose')
plt.plot(y_sss_ex1_glu,'g.')
plt.plot(y_sss_ex2_glu,'c.')
plt.plot(y_sss_ex3_glu,'r.')
plt.xlabel('')
plt.ylabel('YFP/CFP')

#plt.figure(figsize=(12,6))
#
#plt.subplot(1,2,1)
#plt.title ('ALL exp. plux-ptet-std glucose')
#plt.plot(r_lts_ex1_glu/c_lts_ex1_glu,'g.')
#plt.plot(r_lts_ex2_glu/c_lts_ex2_glu,'c.')
#plt.plot(r_lts_ex3_glu/c_lts_ex3_glu,'r.')
#plt.xlabel('')
#plt.ylabel('RFP/CFP')
#
#plt.subplot(1,2,2)
#plt.title ('ALL exp. plux-ptet-std glucose')
#plt.plot(y_lts_ex1_glu/c_lts_ex1_glu,'g.')
#plt.plot(y_lts_ex2_glu/c_lts_ex2_glu,'c.')
#plt.plot(y_lts_ex3_glu/c_lts_ex3_glu,'r.')
#plt.xlabel('')
#plt.ylabel('YFP/CFP')
#
#plt.figure(figsize=(12,6))
#
#plt.subplot(1,2,1)
#plt.title ('All exp. plux-std-std glucose')
#plt.plot(r_lss_ex1_glu/c_lss_ex1_glu,'g.')
#plt.plot(r_lss_ex2_glu/c_lss_ex2_glu,'c.')
#plt.plot(r_lss_ex3_glu/c_lss_ex3_glu,'r.')
#plt.xlabel('')
#plt.ylabel('RFP/CFP')
#
#plt.subplot(1,2,2)
#plt.title ('All exp. plux-std-std glucose')
#plt.plot(y_lss_ex1_glu/c_lss_ex1_glu,'g.')
#plt.plot(y_lss_ex2_glu/c_lss_ex2_glu,'c.')
#plt.plot(y_lss_ex3_glu/c_lss_ex3_glu,'r.')
#plt.xlabel('')
#plt.ylabel('YFP/CFP')
#
#plt.figure(figsize=(12,6))
#
#plt.subplot(1,2,1)
#plt.title ('All exp. plux-plac-std glucose')
#plt.plot(r_lis_ex1_glu/c_lis_ex1_glu,'g.')
#plt.plot(r_lis_ex2_glu/c_lis_ex2_glu,'c.')
#plt.plot(r_lis_ex3_glu/c_lis_ex3_glu,'r.')
#plt.xlabel('')
#plt.ylabel('RFP/CFP')
#
#plt.subplot(1,2,2)
#plt.title ('All exp. plux-plac-std glucose')
#plt.plot(y_lis_ex1_glu/c_lis_ex1_glu,'g.')
#plt.plot(y_lis_ex2_glu/c_lis_ex2_glu,'c.')
#plt.plot(y_lis_ex3_glu/c_lis_ex3_glu,'r.')
#plt.xlabel('')
#plt.ylabel('YFP/CFP')
