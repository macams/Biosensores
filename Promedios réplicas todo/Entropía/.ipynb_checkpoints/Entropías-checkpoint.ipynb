# %%
import flapjack
from flapjack import registry as reg
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline
from matplotlib import colors

# %%
HYglu=[[3.6868265,0,0,0,0],[3.32463,0,3.6999002,2.611618,0],[3.324984,3.4138663,0,3.2261755,3.276247],[3.0426457,3.3926775,0,2.8373368,2.5653386],[3.6274819,3.3818765,0,3.4130273,3.2408483]]

xlabel=['J23101:YFP','J23107:YFP','pTet:YFP','pLacI:YFP','pLas81:YFP']
ylabel=['J23101:RFP','pLux76:RFP','pLux76:RFP','pTet:RFP','J23106:RFP']

plt.figure()
plt.title('H(dY) Glucosa 0,4%')
sns.heatmap(HYglu,cmap='viridis',xticklabels=xlabel,yticklabels=ylabel)
#plt.savefig(filename='rho-r2 glucosa.png', dpi=300, facecolor='w', edgecolor='w',bbox_inches='tight',pad_inches=1.0)

HYgli=[[2.9523029,0,0,0,0],[3.0725625,0,2.5636001,3.1162422,0],[3.0725625,3.5538678,0,3.1159847,3.3280439],[2.2455781,2.2579639,0,2.5135345,2.8198614],[3.2848525,3.8566346,0,3.7915909,3.6169441]]

plt.figure()
plt.title('H(dY) Glicerol 0,2%')
sns.heatmap(HYgli,cmap='viridis',xticklabels=xlabel,yticklabels=ylabel)
#plt.savefig(filename='rho-r2 glucosa.png', dpi=300, facecolor='w', edgecolor='w',bbox_inches='tight',pad_inches=1.0)

# %%
#H(dY|dlogOD)
HYOglu=[[2.2272449,0,0,0,0],[2.3952298,0,3.0430126,2.1665039,0],[2.8734679,2.1400399,0,2.5272441,2.8029795],[2.1400664,2.3827207,0,2.3317425,1.8640571],[2.5340986,2.6222324,0,2.6281948,2.4999402]]

plt.figure()
plt.title('H(dY|dlogOD) Glucosa 0,4%')
sns.heatmap(HYOglu,cmap='viridis',xticklabels=xlabel,yticklabels=ylabel)
#plt.savefig(filename='rho-r2 glucosa.png', dpi=300, facecolor='w', edgecolor='w',bbox_inches='tight',pad_inches=1.0)

HYOgli=[[2.1128271,0,0,0,0],[2.0611622,0,2.1859004,2.4417675,0],[2.6842577,2.4107509,0,2.0361428,2.148396],[1.4097252,1.2113509,0,2.0905225,1.6784286],[2.1532497,2.987288,0,2.5545907,2.9508595]]

plt.figure()
plt.title('H(dY|dlogOD) Glicerol 0,2%')
sns.heatmap(HYOgli,cmap='viridis',xticklabels=xlabel,yticklabels=ylabel)
#plt.savefig(filename='rho-r2 glucosa.png', dpi=300, facecolor='w', edgecolor='w',bbox_inches='tight',pad_inches=1.0)
