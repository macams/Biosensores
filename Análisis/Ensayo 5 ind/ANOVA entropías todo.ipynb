# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import pandas.io.sql as psql
import numpy as np
import scipy
from scipy.optimize import curve_fit
from matplotlib import colors
import seaborn as sns

# %%
vrfp=[51.28,5.58,11.36,31.78]
factores=['Plásmido','Medio','Inductor','Otro']
colores=['royalblue','dimgray','teal','limegreen']
factac = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(factores, vrfp)]

plt.figure(figsize=(6,6))
plt.title('RFP',loc=('left'),fontsize=30)
patches, texts = plt.pie(vrfp, colors=colores, pctdistance=0.6,labeldistance=1.1,radius=1.,startangle=90)
plt.axis('equal')
plt.legend(patches,factac,loc=(1.01,0.7))
plt.savefig(filename='anova rfp entropia.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
vyfp=[23.51,3.53,20.19,52.77]
factores=['Plásmido','Medio','Inductor','Otro']
factac = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(factores, vyfp)]

plt.figure(figsize=(6,6))
plt.title('YFP',loc=('left'),fontsize=30)
patches, texts = plt.pie(vyfp, colors=colores, pctdistance=0.6,labeldistance=1.1,radius=1.,startangle=90)
plt.axis('equal')
plt.legend(patches,factac,loc=(1.01,0.7))
plt.savefig(filename='anova yfp entropia.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
vcfp=[55.70,18.71,8.71,16.88]
factores=['Plásmido','Medio','Inductor','Otro']
factac = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(factores, vcfp)]

plt.figure(figsize=(6,6))
plt.title('CFP',loc=('left'),fontsize=30)
patches, texts = plt.pie(vcfp, colors=colores, pctdistance=0.6,labeldistance=1.1,radius=1.,startangle=90)
plt.axis('equal')
plt.legend(patches,factac,loc=(1.01,0.7))
plt.savefig(filename='anova cfp entropia.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)
