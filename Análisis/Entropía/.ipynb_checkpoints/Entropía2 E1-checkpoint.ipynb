# %%
import flapjack
from flapjack import registry as reg
from flapjack import analysis as analysis
from flapjack import tables as tables
import matplotlib.pyplot as plt
import pandas as pd
import pandas.io.sql as psql
import numpy as np
import scipy
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
registry = reg.Registry(database_name='data', username='maca', password='macata125')

# %%
# First we make a query to the database by applying filters 
qall = registry.queryAll()
qexp= qall.filter((tables.samples.experiment_id==5)|(tables.samples.experiment_id==6)|(tables.samples.experiment_id==7))


qsss = qexp.filter(tables.plasmids.name=='std:RFP/std:YFP/std:CFP')
qpss = qexp.filter(tables.plasmids.name=='pLux76:RFP/std:YFP/std:CFP')
qpts = qexp.filter(tables.plasmids.name=='pLux76:RFP/pTet:YFP/std:CFP')
qpls = qexp.filter(tables.plasmids.name=='pLux76:RFP/pLacI:YFP/std:CFP')

dfexp=psql.read_sql_query(qexp.selectable, registry.engine)
dfsss = psql.read_sql_query(qsss.selectable, registry.engine)
dfsss.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           111747         OD600:600
# 1                        0.0        Layout           111748         OD600:600
# 2                        0.0        Layout           111749         OD600:600
# 3                        0.0        Layout           111750         OD600:600
# 4                        0.0        Layout           111751         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.083           0.194444                     387         387
# 1               0.082           0.194444                     388         388
# 2               0.082           0.194444                     389         389
# 3               0.082           0.194444                     390         390
# 4               0.083           0.194444                     391         391
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                      5            1            3    M9-glucosa            4
# 1                      5            1            4    M9-glucosa            4
# 2                      5            1            5    M9-glucosa            4
# 3                      5            1            6    M9-glucosa            4
# 4                      5            1            7    M9-glucosa            4
#
#              plasmids_name cells_strain  experiments_id  \
# 0  std:RFP/std:YFP/std:CFP        Top10               5
# 1  std:RFP/std:YFP/std:CFP        Top10               5
# 2  std:RFP/std:YFP/std:CFP        Top10               5
# 3  std:RFP/std:YFP/std:CFP        Top10               5
# 4  std:RFP/std:YFP/std:CFP        Top10               5
#
#                  experiments_name  experiments_machine
# 0  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 1  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 2  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 3  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 4  Cinetica 1 rep 1 base de datos  Synergy HTX15070916

# %%
dfpss = psql.read_sql_query(qpss.selectable, registry.engine)
dfpss.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           111752         OD600:600
# 1                        0.0        Layout           111753         OD600:600
# 2                        0.0        Layout           111754         OD600:600
# 3                        0.0        Layout           111755         OD600:600
# 4                        0.0        Layout           111756         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.083           0.194444                     392         392
# 1               0.084           0.194444                     393         393
# 2               0.083           0.194444                     394         394
# 3               0.083           0.194444                     395         395
# 4               0.082           0.194444                     396         396
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                      5            1            8    M9-glucosa            5
# 1                      5            1            9    M9-glucosa            5
# 2                      5            1           10    M9-glucosa            5
# 3                      5            1           11    M9-glucosa            5
# 4                      5            1           12    M9-glucosa            5
#
#                 plasmids_name cells_strain  experiments_id  \
# 0  pLux76:RFP/std:YFP/std:CFP        Top10               5
# 1  pLux76:RFP/std:YFP/std:CFP        Top10               5
# 2  pLux76:RFP/std:YFP/std:CFP        Top10               5
# 3  pLux76:RFP/std:YFP/std:CFP        Top10               5
# 4  pLux76:RFP/std:YFP/std:CFP        Top10               5
#
#                  experiments_name  experiments_machine
# 0  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 1  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 2  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 3  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 4  Cinetica 1 rep 1 base de datos  Synergy HTX15070916

# %%
dfpts = psql.read_sql_query(qpts.selectable, registry.engine)
dfpts.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           111771         OD600:600
# 1                        0.0        Layout           111772         OD600:600
# 2                        0.0        Layout           111773         OD600:600
# 3                        0.0        Layout           111774         OD600:600
# 4                        0.0        Layout           111775         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.085           0.194444                     411         411
# 1               0.083           0.194444                     412         412
# 2               0.082           0.194444                     413         413
# 3               0.083           0.194444                     414         414
# 4               0.082           0.194444                     415         415
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                      5            3            3    M9-glucosa            6
# 1                      5            3            4    M9-glucosa            6
# 2                      5            3            5    M9-glucosa            6
# 3                      5            3            6    M9-glucosa            6
# 4                      5            3            7    M9-glucosa            6
#
#                  plasmids_name cells_strain  experiments_id  \
# 0  pLux76:RFP/pTet:YFP/std:CFP        Top10               5
# 1  pLux76:RFP/pTet:YFP/std:CFP        Top10               5
# 2  pLux76:RFP/pTet:YFP/std:CFP        Top10               5
# 3  pLux76:RFP/pTet:YFP/std:CFP        Top10               5
# 4  pLux76:RFP/pTet:YFP/std:CFP        Top10               5
#
#                  experiments_name  experiments_machine
# 0  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 1  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 2  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 3  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 4  Cinetica 1 rep 1 base de datos  Synergy HTX15070916

# %%
dfpls = psql.read_sql_query(qpls.selectable, registry.engine)
dfpls.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           111776         OD600:600
# 1                        0.0        Layout           111777         OD600:600
# 2                        0.0        Layout           111778         OD600:600
# 3                        0.0        Layout           111779         OD600:600
# 4                        0.0        Layout           111780         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.083           0.194444                     416         416
# 1               0.084           0.194444                     417         417
# 2               0.084           0.194444                     418         418
# 3               0.083           0.194444                     419         419
# 4               0.083           0.194444                     420         420
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                      5            3            8    M9-glucosa            7
# 1                      5            3            9    M9-glucosa            7
# 2                      5            3           10    M9-glucosa            7
# 3                      5            3           11    M9-glucosa            7
# 4                      5            3           12    M9-glucosa            7
#
#                   plasmids_name cells_strain  experiments_id  \
# 0  pLux76:RFP/pLacI:YFP/std:CFP        Top10               5
# 1  pLux76:RFP/pLacI:YFP/std:CFP        Top10               5
# 2  pLux76:RFP/pLacI:YFP/std:CFP        Top10               5
# 3  pLux76:RFP/pLacI:YFP/std:CFP        Top10               5
# 4  pLux76:RFP/pLacI:YFP/std:CFP        Top10               5
#
#                  experiments_name  experiments_machine
# 0  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 1  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 2  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 3  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 4  Cinetica 1 rep 1 base de datos  Synergy HTX15070916

# %%
# Here are the unique measurement names in our dataframe
pnames = dfexp['plasmids_name'].unique()
mnames = dfexp['measurements_name'].unique()
mednames = dfexp['samples_media'].unique()

print pnames
print mnames
print mednames
# Out:
# [u'std:RFP/std:YFP/std:CFP' u'pLux76:RFP/std:YFP/std:CFP'
#  u'pLux76:RFP/pTet:YFP/std:CFP' u'pLux76:RFP/pLacI:YFP/std:CFP']
# [u'OD600:600' u'CFP:420/50,485/20' u'RFP-YFP:585/10,620/15'
#  u'RFP-YFP:500/27,540/25']
# [u'M9-glucosa' u'M9-glicerol']

# %%
#max mediciones(no diff)
qexp= qall.filter((tables.samples.experiment_id==5)|(tables.samples.experiment_id==6)|(tables.samples.experiment_id==7))
dfexp = psql.read_sql_query(qexp.selectable, registry.engine)

odmax = np.max(dfexp[dfexp.measurements_name=='OD600:600']['measurements_value'].values)
print odmax
yfpmax = np.max(dfexp[dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'].values)
print yfpmax
rfpmax = np.max(dfexp[dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'].values)
print rfpmax
cfpmax = np.max(dfexp[dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'].values)
print cfpmax
# Out:
# 1.174
# 1137316.0
# 551860.0
# 100165.0

# %%
measmax = {}
for e in mednames:
    for m in mnames:
        measmax[e,m] = np.max(dfexp[dfexp.measurements_name==m][dfexp.samples_media==e]['measurements_value'].values)
        print [e,m],measmax[e,m]
        print '---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# [u'M9-glucosa', u'OD600:600'] 1.085
# ---
# [u'M9-glucosa', u'CFP:420/50,485/20'] 85467.0
# ---
# [u'M9-glucosa', u'RFP-YFP:585/10,620/15'] 425702.0
# ---
# [u'M9-glucosa', u'RFP-YFP:500/27,540/25'] 741305.0
# ---
# [u'M9-glicerol', u'OD600:600'] 1.174
# ---
# [u'M9-glicerol', u'CFP:420/50,485/20'] 100165.0
# ---
# [u'M9-glicerol', u'RFP-YFP:585/10,620/15'] 551860.0
# ---
# [u'M9-glicerol', u'RFP-YFP:500/27,540/25'] 1137316.0
# ---

# %%
ddif={}
for p in pnames:
    for m in mnames:
        for e in mednames:
            dfe=dfexp[dfexp.measurements_name==m][dfexp.samples_media==e][dfexp.plasmids_name==p]
            ddif[p,m,e]=analysis.compute_measurement_diff(dfe,m)
            print [p,m,e],ddif[p,m,e]
            print'---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# [u'std:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glucosa'] [ 0.     0.     0.001 ..., -0.003 -0.001 -0.002]
# ---
# [u'std:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glicerol'] [ 0.     0.     0.001 ..., -0.003  0.001 -0.003]
# ---
# [u'std:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'] [   0.    0. -134. ...,  161.   81.   80.]
# ---
# [u'std:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'] [   0.    0. -181. ...,  -11.   43.   -6.]
# ---
# [u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'] [    0.     0.    32. ...,   218.  1095.  -119.]
# ---
# [u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'] [   0.    0.  -88. ...,  -85.  924.  757.]
# ---
# [u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'] [    0.     0.   153. ...,  -165.  1593.  2385.]
# ---
# [u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'] [    0.     0.   -21. ...,   -25.   745.  1566.]
# ---
# [u'pLux76:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glucosa'] [ 0.     0.     0.    ...,  0.     0.005  0.001]
# ---
# [u'pLux76:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glicerol'] [ 0.     0.     0.    ..., -0.002  0.007 -0.001]
# ---
# [u'pLux76:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'] [   0.    0. -129. ...,  260.  432.  388.]
# ---
# [u'pLux76:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'] [   0.    0. -160. ...,   61.   36.  -35.]
# ---
# [u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'] [    0.     0.    43. ...,  2999.  3495.  2505.]
# ---
# [u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'] [    0.     0.   -88. ...,  2523.  2677.  1332.]
# ---
# [u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'] [    0.     0.   159. ...,  3170.  4024.  4378.]
# ---
# [u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'] [    0.     0.   -36. ...,  -404.  1828.   988.]
# ---
# [u'pLux76:RFP/pTet:YFP/std:CFP', u'OD600:600', u'M9-glucosa'] [ 0.     0.     0.001 ..., -0.001  0.001  0.   ]
# ---
# [u'pLux76:RFP/pTet:YFP/std:CFP', u'OD600:600', u'M9-glicerol'] [ 0.     0.     0.    ...,  0.     0.001 -0.001]
# ---
# [u'pLux76:RFP/pTet:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'] [   0.    0. -164. ...,  180.   70.  157.]
# ---
# [u'pLux76:RFP/pTet:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'] [   0.    0. -177. ...,   46.  -38.  170.]
# ---
# [u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'] [    0.     0.   109. ...,   518.  1520.   616.]
# ---
# [u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'] [    0.     0.   -20. ...,   178.  1417.   239.]
# ---
# [u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'] [    0.     0.   530. ...,  1824.  1403.  1916.]
# ---
# [u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'] [    0.     0.    93. ...,  3044.  1713.  3106.]
# ---
# [u'pLux76:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glucosa'] [ 0.     0.    -0.001 ...,  0.008  0.01   0.   ]
# ---
# [u'pLux76:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glicerol'] [ 0.     0.     0.    ..., -0.002  0.001 -0.007]
# ---
# [u'pLux76:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'] [   0.    0. -122. ...,  526.  724.  705.]
# ---
# [u'pLux76:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'] [   0.    0. -169. ...,  149.  112.   79.]
# ---
# [u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'] [    0.     0.    69. ...,  1237.  2432.  1002.]
# ---
# [u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'] [    0.     0.   -81. ...,   515.  1396.   703.]
# ---
# [u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'] [    0.     0.   -26. ...,  3084.  4848.  4455.]
# ---
# [u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'] [    0.     0.    12. ...,   683.  4074.  2491.]
# ---

# %%
measdiffsss = {}

print pnames[0]
for m in mnames:
    for e in mednames:
        measdiffsss[e,m] =analysis.compute_measurement_diff(dfsss[dfsss.measurements_name==m][dfsss.samples_media==e],m)
        print [e,m],measdiffsss[e,m]
        
sssdiff=measdiffsss

print'----'
print pnames[1]
measdiffpss = {}

for e in mednames:
    for m in mnames:
        measdiffpss[e,m] =analysis.compute_measurement_diff(dfpss[dfpss.measurements_name==m][dfpss.samples_media==e],m)
        print [e,m],measdiffpss[e,m]  
#print measdiffpss
pssdiff=measdiffpss

print'----'
print pnames[2]
measdiffpts = {}

for e in mednames:
    for m in mnames:
        measdiffpts[e,m] =analysis.compute_measurement_diff(dfpts[dfpts.measurements_name==m][dfpts.samples_media==e],m)
        print [e,m],measdiffpts[e,m]
        
ptsdiff=measdiffpts

print'----'
print pnames[3]
measdiffpls = {}

for e in mednames:
    for m in mnames:
        measdiffpls[e,m] =analysis.compute_measurement_diff(dfpls[dfpls.measurements_name==m][dfpls.samples_media==e],m)
        print [e,m],measdiffpls[e,m]   
    
#print measdiffpls
plsdiff=measdiffpls

diffs=[measdiffsss,measdiffpss,measdiffpts,measdiffpls]
# Out:
# std:RFP/std:YFP/std:CFP
# [u'M9-glucosa', u'OD600:600']
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#  [ 0.     0.     0.001 ..., -0.003 -0.001 -0.002]
# [u'M9-glicerol', u'OD600:600'] [ 0.     0.     0.001 ..., -0.003  0.001 -0.003]
# [u'M9-glucosa', u'CFP:420/50,485/20'] [   0.    0. -134. ...,  161.   81.   80.]
# [u'M9-glicerol', u'CFP:420/50,485/20'] [   0.    0. -181. ...,  -11.   43.   -6.]
# [u'M9-glucosa', u'RFP-YFP:585/10,620/15'] [    0.     0.    32. ...,   218.  1095.  -119.]
# [u'M9-glicerol', u'RFP-YFP:585/10,620/15'] [   0.    0.  -88. ...,  -85.  924.  757.]
# [u'M9-glucosa', u'RFP-YFP:500/27,540/25'] [    0.     0.   153. ...,  -165.  1593.  2385.]
# [u'M9-glicerol', u'RFP-YFP:500/27,540/25'] [    0.     0.   -21. ...,   -25.   745.  1566.]
# ----
# pLux76:RFP/std:YFP/std:CFP
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# [u'M9-glucosa', u'OD600:600'] [ 0.     0.     0.    ...,  0.     0.005  0.001]
# [u'M9-glucosa', u'CFP:420/50,485/20'] [   0.    0. -129. ...,  260.  432.  388.]
# [u'M9-glucosa', u'RFP-YFP:585/10,620/15'] [    0.     0.    43. ...,  2999.  3495.  2505.]
# [u'M9-glucosa', u'RFP-YFP:500/27,540/25'] [    0.     0.   159. ...,  3170.  4024.  4378.]
# [u'M9-glicerol', u'OD600:600'] [ 0.     0.     0.    ..., -0.002  0.007 -0.001]
# [u'M9-glicerol', u'CFP:420/50,485/20'] [   0.    0. -160. ...,   61.   36.  -35.]
# [u'M9-glicerol', u'RFP-YFP:585/10,620/15'] [    0.     0.   -88. ...,  2523.  2677.  1332.]
# [u'M9-glicerol', u'RFP-YFP:500/27,540/25'] [    0.     0.   -36. ...,  -404.  1828.   988.]
# ----
# pLux76:RFP/pTet:YFP/std:CFP
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# [u'M9-glucosa', u'OD600:600'] [ 0.     0.     0.001 ..., -0.001  0.001  0.   ]
# [u'M9-glucosa', u'CFP:420/50,485/20'] [   0.    0. -164. ...,  180.   70.  157.]
# [u'M9-glucosa', u'RFP-YFP:585/10,620/15'] [    0.     0.   109. ...,   518.  1520.   616.]
# [u'M9-glucosa', u'RFP-YFP:500/27,540/25'] [    0.     0.   530. ...,  1824.  1403.  1916.]
# [u'M9-glicerol', u'OD600:600'] [ 0.     0.     0.    ...,  0.     0.001 -0.001]
# [u'M9-glicerol', u'CFP:420/50,485/20'] [   0.    0. -177. ...,   46.  -38.  170.]
# [u'M9-glicerol', u'RFP-YFP:585/10,620/15'] [    0.     0.   -20. ...,   178.  1417.   239.]
# [u'M9-glicerol', u'RFP-YFP:500/27,540/25'] [    0.     0.    93. ...,  3044.  1713.  3106.]
# ----
# pLux76:RFP/pLacI:YFP/std:CFP
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# [u'M9-glucosa', u'OD600:600'] [ 0.     0.    -0.001 ...,  0.008  0.01   0.   ]
# [u'M9-glucosa', u'CFP:420/50,485/20'] [   0.    0. -122. ...,  526.  724.  705.]
# [u'M9-glucosa', u'RFP-YFP:585/10,620/15'] [    0.     0.    69. ...,  1237.  2432.  1002.]
# [u'M9-glucosa', u'RFP-YFP:500/27,540/25'] [    0.     0.   -26. ...,  3084.  4848.  4455.]
# [u'M9-glicerol', u'OD600:600'] [ 0.     0.     0.    ..., -0.002  0.001 -0.007]
# [u'M9-glicerol', u'CFP:420/50,485/20'] [   0.    0. -169. ...,  149.  112.   79.]
# [u'M9-glicerol', u'RFP-YFP:585/10,620/15'] [    0.     0.   -81. ...,   515.  1396.   703.]
# [u'M9-glicerol', u'RFP-YFP:500/27,540/25'] [    0.     0.    12. ...,   683.  4074.  2491.]

# %%
#max de diffs para rangos de H(x)
diffod={}
maxod={}
for e in mednames:
    for m in mnames:
        diffod[e,m] =analysis.compute_measurement_diff(dfexp[dfexp.measurements_name==m][dfexp.samples_media==e],m)
        maxod[e,m]=np.max(diffod[e,m])
        print [e,m],maxod[e,m]
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# [u'M9-glucosa', u'OD600:600'] 0.139
# [u'M9-glucosa', u'CFP:420/50,485/20'] 3013.0
# [u'M9-glucosa', u'RFP-YFP:585/10,620/15'] 14076.0
# [u'M9-glucosa', u'RFP-YFP:500/27,540/25'] 31717.0
# [u'M9-glicerol', u'OD600:600'] 0.09
# [u'M9-glicerol', u'CFP:420/50,485/20'] 3680.0
# [u'M9-glicerol', u'RFP-YFP:585/10,620/15'] 30898.0
# [u'M9-glicerol', u'RFP-YFP:500/27,540/25'] 79048.0

# %%
#max de diffs para rangos de H(x)
diffod={}
maxod={}
for m in mednames:
    diffod[m] =analysis.compute_measurement_diff(dfexp[dfexp.samples_media==m],'OD600:600')
    maxod[m]=np.max(diffod[m])
    
print maxod

diffrfp={}
maxrfp={}
for m in mednames:
    diffrfp[m] =analysis.compute_measurement_diff(dfexp[dfexp.samples_media==m],'RFP-YFP:585/10,620/15')
    maxrfp[m]=np.max(diffrfp[m])
    
print maxrfp

diffyfp={}
maxyfp={}
for m in mednames:
    diffyfp[m] =analysis.compute_measurement_diff(dfexp[dfexp.samples_media==m],'RFP-YFP:500/27,540/25')
    maxyfp[m]=np.max(diffyfp[m])
    
print maxyfp

diffcfp={}
maxcfp={}
for m in mednames:
    diffcfp[m] =analysis.compute_measurement_diff(dfexp[dfexp.samples_media==m],'CFP:420/50,485/20')
    maxcfp[m]=np.max(diffcfp[m])
    
print maxcfp
# Out:
# {u'M9-glicerol': 0.089999999999999969, u'M9-glucosa': 0.13900000000000001}
# {u'M9-glicerol': 30898.0, u'M9-glucosa': 14076.0}
# {u'M9-glicerol': 79048.0, u'M9-glucosa': 31717.0}
# {u'M9-glicerol': 3680.0, u'M9-glucosa': 3013.0}

# %%
Hod={}
Hcfp={}
Hrfp={}
Hyfp={}
for p in pnames:
    for m in mnames:
        for e in mednames:
            if m=='OD600:600':
                Hod[p,m,e] =analysis.channel_entropy(dfexp[dfexp.measurements_name==m][dfexp.samples_media==e][dfexp.plasmids_name==p],m, 256, [0,0.14])
                     
            elif m=='RFP-YFP:585/10,620/15':
                Hrfp[p,m,e] = analysis.channel_entropy(dfexp[dfexp.measurements_name==m][dfexp.samples_media==e][dfexp.plasmids_name==p],m, 256, [0,30900])
                      
            elif m=='RFP-YFP:500/27,540/25':
                Hyfp[p,m,e] = analysis.channel_entropy(dfexp[dfexp.measurements_name==m][dfexp.samples_media==e][dfexp.plasmids_name==p],m, 256, [0,79100])
                           
            else:
                Hcfp[p,m,e] = analysis.channel_entropy(dfexp[dfexp.measurements_name==m][dfexp.samples_media==e][dfexp.plasmids_name==p],m, 256, [0,3700])
                


print 'Entropy of OD', Hod
print 'Entropy of RFP', Hrfp           
print 'Entropy of YFP', Hyfp                
print 'Entropy of CFP', Hcfp
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# Entropy of OD {(u'pLux76:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.6704121, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.6655989, (u'pLux76:RFP/pTet:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.3954787, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.7182083, (u'pLux76:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.69065, (u'std:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.6531134, (u'pLux76:RFP/pTet:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.1755614, (u'std:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.7960067}
# Entropy of RFP {(u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 6.084033, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.7060819, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.3635464, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 6.0718784, (u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.7825603, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.937757, (u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.3272452, (u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.7222681}
# Entropy of YFP {(u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.581974, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 6.0078344, (u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.3183975, (u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.3769693, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.4138136, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.6839662, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 4.5506306, (u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.7499981}
# Entropy of CFP {(u'pLux76:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.8035898, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.5215111, (u'pLux76:RFP/pTet:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.2617817, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.8914204, (u'pLux76:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.4844527, (u'pLux76:RFP/pTet:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.7121534, (u'std:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.3750286, (u'std:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.9443636}

# %%
Hodsss={}
Hcfpsss={}
Hrfpsss={}
Hyfpsss={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodsss[m,e] =analysis.channel_entropy(dfsss[dfsss.measurements_name==m][dfsss.samples_media==e],m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfpsss[m,e] = analysis.channel_entropy(dfsss[dfsss.measurements_name==m][dfsss.samples_media==e],m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfpsss[m,e] = analysis.channel_entropy(dfsss[dfsss.measurements_name==m][dfsss.samples_media==e],m, 256, [0,79100])
                    
        else:
            Hcfpsss[m,e] = analysis.channel_entropy(dfsss[dfsss.measurements_name==m][dfsss.samples_media==e],m, 256, [0,3700])
                    


print pnames[0]
print 'Entropy of OD', Hodsss
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfpsss
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfpsss
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfpsss
print '---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# std:RFP/std:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.6531134, (u'OD600:600', u'M9-glucosa'): 4.7960067}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 6.3750286, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.9443636}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.3272452, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.7222681}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.3183975, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.581974}
# ---

# %%
Hodpss={}
Hcfppss={}
Hrfppss={}
Hyfppss={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodpss[m,e] =analysis.channel_entropy(dfpss[dfpss.measurements_name==m][dfpss.samples_media==e],m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfppss[m,e] = analysis.channel_entropy(dfpss[dfpss.measurements_name==m][dfpss.samples_media==e],m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfppss[m,e] = analysis.channel_entropy(dfpss[dfpss.measurements_name==m][dfpss.samples_media==e],m, 256, [0,79100])
                    
        else:
            Hcfppss[m,e] = analysis.channel_entropy(dfpss[dfpss.measurements_name==m][dfpss.samples_media==e],m, 256, [0,3700])
                    


print pnames[1]
print 'Entropy of OD', Hodpss
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfppss
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfppss
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfppss
print '---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# pLux76:RFP/std:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.69065, (u'OD600:600', u'M9-glucosa'): 4.6704121}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 6.4844527, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.8035898}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.7825603, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 6.084033}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.3769693, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.7499981}
# ---

# %%
Hodpts={}
Hcfppts={}
Hrfppts={}
Hyfppts={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodpts[m,e] =analysis.channel_entropy(dfpts[dfpts.measurements_name==m][dfpts.samples_media==e],m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfppts[m,e] = analysis.channel_entropy(dfpts[dfpts.measurements_name==m][dfpts.samples_media==e],m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfppts[m,e] = analysis.channel_entropy(dfpts[dfpts.measurements_name==m][dfpts.samples_media==e],m, 256, [0,79100])
                    
        else:
            Hcfppts[m,e] = analysis.channel_entropy(dfpts[dfpts.measurements_name==m][dfpts.samples_media==e],m, 256, [0,3700])
                    


print pnames[2]
print 'Entropy of OD', Hodpts
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfppts
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfppts
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfppts
print '---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# pLux76:RFP/pTet:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.3954787, (u'OD600:600', u'M9-glucosa'): 4.1755614}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 6.2617817, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.7121534}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.3635464, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.937757}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.6839662, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 6.0078344}
# ---

# %%
Hodpls={}
Hcfppls={}
Hrfppls={}
Hyfppls={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodpls[m,e] =analysis.channel_entropy(dfpls[dfpls.measurements_name==m][dfpls.samples_media==e],m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfppls[m,e] = analysis.channel_entropy(dfpls[dfpls.measurements_name==m][dfpls.samples_media==e],m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfppls[m,e] = analysis.channel_entropy(dfpls[dfpls.measurements_name==m][dfpls.samples_media==e],m, 256, [0,79100])
                    
        else:
            Hcfppls[m,e] = analysis.channel_entropy(dfpls[dfpls.measurements_name==m][dfpls.samples_media==e],m, 256, [0,3700])
                    


print pnames[3]
print 'Entropy of OD', Hodpls
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfppls
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfppls
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfppls
print '---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# pLux76:RFP/pLacI:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.6655989, (u'OD600:600', u'M9-glucosa'): 4.7182083}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 6.5215111, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.8914204}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.7060819, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 6.0718784}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 4.5506306, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.4138136}
# ---

# %%
def channel_entropies(df):
    # Calculate the entropies of all channels in the dataframe df
    Ho= {}
    Hr= {}
    Hy= {}
    Hc= {}
    
    mnames = df.measurements_name.unique()
    pnames = df.plasmids_name.unique()
    mednames = df.samples_media.unique()
    for p in pnames:
        for e in mednames:
            for m in mnames:
                if m=='OD600:600':
                    Ho[p,m,e] =analysis.channel_entropy(df[df.measurements_name==m][df.samples_media==e][df.plasmids_name==p],m, 256, [0,0.14])
                    
                else:
                    if m=='RFP-YFP:585/10,620/15':
                        Hr[p,m,e] = analysis.channel_entropy(df[df.measurements_name==m][df.samples_media==e][df.plasmids_name==p],m, 256, [0,30900])
                        
                    else:
                        if m=='RFP-YFP:500/27,540/25':
                            Hy[p,m,e] = analysis.channel_entropy(df[df.measurements_name==m][df.samples_media==e][df.plasmids_name==p],m, 256, [0,79100])
                            
                        else:
                            Hc[p,m,e] = analysis.channel_entropy(df[df.measurements_name==m][df.samples_media==e][df.plasmids_name==p],m, 256, [0,3700])
                            
    print Ho
    print' '
    print '---'
    print' '
    print Hc
    print' '
    print '---'
    print' '
    print Hr
    print' '
    print '---'
    print' '
    print Hy 
    


Hexp= channel_entropies(dfexp)
print Hexp
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# {(u'pLux76:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.6704121, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.6655989, (u'pLux76:RFP/pTet:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.3954787, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.7182083, (u'pLux76:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.69065, (u'std:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.6531134, (u'pLux76:RFP/pTet:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.1755614, (u'std:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.7960067}
#
# ---
#
# {(u'pLux76:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.8035898, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.5215111, (u'pLux76:RFP/pTet:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.2617817, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.8914204, (u'pLux76:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.4844527, (u'pLux76:RFP/pTet:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.7121534, (u'std:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.3750286, (u'std:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.9443636}
#
# ---
#
# {(u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 6.084033, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.7060819, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.3635464, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 6.0718784, (u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.7825603, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.937757, (u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.3272452, (u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.7222681}
#
# ---
#
# {(u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.581974, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 6.0078344, (u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.3183975, (u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.3769693, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.4138136, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.6839662, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 4.5506306, (u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.7499981}
# None

# %%
'''def channel_conditional_entropy(df, m1, m2, nbins, hrange):
    # Compute the conditional entropy H(m2|m1),
    # where m1 and m2 are the names of the measurements
    # Get the diffs
    values1 = compute_measurement_diff(df, m1)
    values2 = compute_measurement_diff(df, m2)
    # Compute the entropy
    density2d = prob_density2d(values1, values2, nbins, hrange)
    return conditional_entropy(density2d)'''



Hyo=analysis.channel_conditional_entropy(dfsss, 'OD600:600', 'RFP-YFP:500/27,540/25',[256,256], [[0,0.14],[0,79100]])
print 'H(dY|dlogOD)=',Hyo

print mnames
# Out:
# H(dY|dlogOD)= 4.3839
# [u'OD600:600' u'CFP:420/50,485/20' u'RFP-YFP:585/10,620/15'
#  u'RFP-YFP:500/27,540/25']

# %%
Hcosss={}
Hrosss={}
Hyosss={}
for e in mednames:
    Hcosss[e]=analysis.channel_conditional_entropy(dfsss[dfsss.samples_media==e], 'OD600:600','CFP:420/50,485/20',[256,256], [[0,0.14],[0,3700]])
    Hrosss[e]=analysis.channel_conditional_entropy(dfsss[dfsss.samples_media==e], 'OD600:600', 'RFP-YFP:585/10,620/15',[256,256], [[0,0.14],[0,30900]])
    Hyosss[e]=analysis.channel_conditional_entropy(dfsss[dfsss.samples_media==e], 'OD600:600', 'RFP-YFP:500/27,540/25',[256,256], [[0,0.14],[0,79100]])
    print pnames[0]
    print 'H(dC|dlogOD)=',[e],Hcosss[e]
    print 'H(dRC|dlogOD)=',[e],Hrosss[e]
    print 'H(dY|dlogOD)=',[e],Hyosss[e]
    print '---'
    print ' '
# Out:
# std:RFP/std:YFP/std:CFP
# H(dC|dlogOD)= [u'M9-glucosa'] 4.58492
# H(dRC|dlogOD)= [u'M9-glucosa'] 4.06433
# H(dY|dlogOD)= [u'M9-glucosa'] 4.06788
# ---
#
# std:RFP/std:YFP/std:CFP
# H(dC|dlogOD)= [u'M9-glicerol'] 4.94316
# H(dRC|dlogOD)= [u'M9-glicerol'] 4.2193
# H(dY|dlogOD)= [u'M9-glicerol'] 4.055
# ---

# %%
Hco={}
Hro={}
Hyo={}
for p in pnames:
    for e in mednames:
        Hco[p,e]=analysis.channel_conditional_entropy(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'OD600:600','CFP:420/50,485/20',[256,256], [[0,0.14],[0,3700]])
        Hro[p,e]=analysis.channel_conditional_entropy(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'OD600:600', 'RFP-YFP:585/10,620/15',[256,256], [[0,0.14],[0,30900]])
        Hyo[p,e]=analysis.channel_conditional_entropy(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'OD600:600', 'RFP-YFP:500/27,540/25',[256,256], [[0,0.14],[0,79100]])
        print 'H(dC|dlogOD)=',[p,e],Hco[p,e]
        print 'H(dR|dlogOD)=',[p,e],Hro[p,e]
        print 'H(dY|dlogOD)=',[p,e],Hyo[p,e]
        print '---'
        print ' '
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# H(dC|dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 4.58492
# H(dR|dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 4.06433
# H(dY|dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 4.06788
# ---
#
# H(dC|dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 4.94316
# H(dR|dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 4.2193
# H(dY|dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 4.055
# ---
#
# H(dC|dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 4.92138
# H(dR|dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 4.36863
# H(dY|dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 4.28004
# ---
#
# H(dC|dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 4.90475
# H(dR|dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 4.55618
# H(dY|dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 4.31808
# ---
#
# H(dC|dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 4.99173
# H(dR|dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 4.28432
# H(dY|dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 4.48924
# ---
#
# H(dC|dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 5.07112
# H(dR|dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 4.61721
# H(dY|dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 4.52389
# ---
#
# H(dC|dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 4.91609
# H(dR|dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 4.51763
# H(dY|dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 3.67122
# ---
#
# H(dC|dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 4.9946
# H(dR|dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 4.49776
# H(dY|dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 4.01428
# ---

# %%
def channel_conditional_entropy3(df, m1, m2, m3, nbins, hrange):
    # Compute the conditional entropy H(m2|m1,m3),
    # where m1 and m2 are the names of the measurements
    # Get the diffs
    values1 = analysis.compute_measurement_diff(df, m1)
    values2 = analysis.compute_measurement_diff(df, m2)
    values3 = analysis.compute_measurement_diff(df, m3)
    # Compute the entropy
    density3d = analysis.prob_density3d(values1, values2,values3, nbins, hrange)
    return analysis.conditional_entropy(density3d)

# %%
Hcyr={}
Hcyo={}
Hcro={}

Hycr={}
Hyco={}
Hyro={}

Hrcy={}
Hrco={}
Hryo={}

for p in pnames:
    for e in mednames:
        Hcyr[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:500/27,540/25','CFP:420/50,485/20','RFP-YFP:585/10,620/15',[256,256,256], [[0,79100],[0,79100],[0,79100]])
        Hcyo[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:500/27,540/25','CFP:420/50,485/20', 'OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        Hcro[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:585/10,620/15','CFP:420/50,485/20', 'OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        Hycr[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:500/27,540/25','RFP-YFP:585/10,620/15',[256,256,256], [[0,79100],[0,79100],[0,79100]])
        Hyco[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:500/27,540/25','OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        Hyro[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:585/10,620/15','RFP-YFP:500/27,540/25', 'OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        Hrcy[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:585/10,620/15','RFP-YFP:500/27,540/25',[256,256,256], [[0,79100],[0,79100],[0,79100]])
        Hrco[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:585/10,620/15', 'OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        Hryo[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:500/27,540/25','RFP-YFP:585/10,620/15', 'OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        
        print 'H(dC|dY,dR)=',[p,e],Hcyr[p,e]
        print 'H(dC|dY,dlogOD)=',[p,e],Hcyo[p,e]
        print 'H(dC|dR,dlogOD)=',[p,e],Hcro[p,e]
        print ' '
        print 'H(dY|dC,dR)=',[p,e],Hycr[p,e]
        print 'H(dY|dC,dlogOD)=',[p,e],Hyco[p,e]
        print 'H(dY|dR,dlogOD)=',[p,e],Hyro[p,e]
        print ' '
        print 'H(dR|dC,dY)=',[p,e],Hrcy[p,e]
        print 'H(dR|dC,dlogOD)=',[p,e],Hrco[p,e]
        print 'H(dR|dY,dlogOD)=',[p,e],Hryo[p,e]
        print '---'
        print '---'
        print ' '
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# H(dC|dY,dR)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 0.870149
# H(dC|dY,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 0.444924
# H(dC|dR,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 0.656171
#
# H(dY|dC,dR)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 3.28577
# H(dY|dC,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 2.88896
# H(dY|dR,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 1.75471
#
# H(dR|dC,dY)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 2.17551
# H(dR|dC,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 2.21759
# H(dR|dY,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'] 0.858804
# ---
# ---
#
# H(dC|dY,dR)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 0.579421
# H(dC|dY,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 0.450009
# H(dC|dR,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 0.652632
#
# H(dY|dC,dR)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 3.04507
# H(dY|dC,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 2.55176
# H(dY|dR,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 1.61386
#
# H(dR|dC,dY)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 1.82461
# H(dR|dC,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 1.91441
# H(dR|dY,dlogOD)= [u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'] 0.76998
# ---
# ---
#
# H(dC|dY,dR)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 0.834384
# H(dC|dY,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 0.624022
# H(dC|dR,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 0.85498
#
# H(dY|dC,dR)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 3.31646
# H(dY|dC,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 3.20187
# H(dY|dR,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 2.10826
#
# H(dR|dC,dY)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 2.46459
# H(dR|dC,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 2.53269
# H(dR|dY,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'] 1.20295
# ---
# ---
#
# H(dC|dY,dR)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 0.557139
# H(dC|dY,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 0.385601
# H(dC|dR,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 0.732944
#
# H(dY|dC,dR)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 2.88515
# H(dY|dC,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 2.88362
# H(dY|dR,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 1.69886
#
# H(dR|dC,dY)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 1.85548
# H(dR|dC,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 2.27425
# H(dR|dY,dlogOD)= [u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'] 0.762158
# ---
# ---
#
# H(dC|dY,dR)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 0.72332
# H(dC|dY,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 0.566925
# H(dC|dR,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 0.880552
#
# H(dY|dC,dR)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 3.57825
# H(dY|dC,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 3.5499
# H(dY|dR,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 2.53478
#
# H(dR|dC,dY)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 2.14208
# H(dR|dC,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 2.53953
# H(dR|dY,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'] 1.21924
# ---
# ---
#
# H(dC|dY,dR)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 0.409299
# H(dC|dY,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 0.363115
# H(dC|dR,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 0.547724
#
# H(dY|dC,dR)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 3.12491
# H(dY|dC,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 3.25208
# H(dY|dR,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 1.95134
#
# H(dR|dC,dY)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 1.56221
# H(dR|dC,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 2.30125
# H(dR|dY,dlogOD)= [u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'] 0.814992
# ---
# ---
#
# H(dC|dY,dR)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 0.973172
# H(dC|dY,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 0.703872
# H(dC|dR,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 0.712929
#
# H(dY|dC,dR)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 2.7669
# H(dY|dC,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 2.67381
# H(dY|dR,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 1.63629
#
# H(dR|dC,dY)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 2.57133
# H(dR|dC,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 2.59256
# H(dR|dY,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 1.54368
# ---
# ---
#
# H(dC|dY,dR)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 0.578705
# H(dC|dY,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 0.527044
# H(dC|dR,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 0.722641
#
# H(dY|dC,dR)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 2.75491
# H(dY|dC,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 2.80303
# H(dY|dR,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 1.58197
#
# H(dR|dC,dY)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 2.15156
# H(dR|dC,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 2.34084
# H(dR|dY,dlogOD)= [u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 0.950866
# ---
# ---

# %%
def channel_conditional_entropy4(df, m1, m2, m3, m4, nbins, hrange):
    # Compute the conditional entropy H(m2|m1,m3,m4),
    # where m1 and m2 are the names of the measurements
    # Get the diffs
    values1 = analysis.compute_measurement_diff(df, m1)
    values2 = analysis.compute_measurement_diff(df, m2)
    values3 = analysis.compute_measurement_diff(df, m3)
    values4 = analysis.compute_measurement_diff(df, m4)
    # Compute the entropy
    density4d = analysis.prob_density4d(values1, values2, values3, values4, nbins, hrange)
    return analysis.conditional_entropy(density4d)


for p in pnames:
    for e in mednames:
        Hcyro[p,e]=channel_conditional_entropy4(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p],'RFP-YFP:500/27,540/25','CFP:420/50,485/20','RFP-YFP:585/10,620/15','OD600:600',[256,256,256,256], [[0,79100],[0,79100],[0,79100],[0,0.14]])
        print 'H(dC|dY,dR,dlogOD)=',[p,e],Hcyro[p,e]

# %%
Hcyro={}
Hycro={}
Hrcyo={}

for p in pnames:
    for e in mednames:
        Hcyro[p,e]=channel_conditional_entropy4(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:500/27,540/25','CFP:420/50,485/20','RFP-YFP:585/10,620/15','OD600:600',[256,256,256,256], [[0,79100],[0,79100],[0,79100],[0,0.14]])
        Hycro[p,e]=channel_conditional_entropy4(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:500/27,540/25','RFP-YFP:585/10,620/15','OD600:600',[256,256,256,256], [[0,79100],[0,79100],[0,79100],[0,0.14]])
        Hrcyo[p,e]=channel_conditional_entropy4(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:585/10,620/15','RFP-YFP:500/27,540/25','OD600:600',[256,256,256,256], [[0,79100],[0,79100],[0,79100],[0,0.14]])
        
        print 'H(dC|dY,dR,dlogOD)=',[p,e],Hcyro[p,e]
        print ' '
        print 'H(dY|dC,dR,dlogOD)=',[p,e],Hycro[p,e]
        print ' '
        print 'H(dR|dC,dY,dlogOD)=',[p,e],Hrcyo[p,e]
        print '---'
        print '---'
        print ' '

# %%
valores_od={}
valores_rfp={}
valores_yfp={}
valores_cfp={}
t_horas=(dfexp[dfexp.measurements_name=='OD600:600']['measurements_time'].values)
      

for p in pnames:
    for e in mednames:
        valores_od[p,e]= dfexp[dfexp.samples_media==e][dfexp.measurements_name=='OD600:600']['measurements_name'].values
        valores_rfp[p,e]= dfexp[dfexp.samples_media==e][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_name'].values
        valores_yfp[p,e]= dfexp[dfexp.samples_media==e][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_name'].values
        valores_cfp[e]= dfexp[dfexp.samples_media==e][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_name'].values
            


print valores_od
print valores_rfp
print valores_yfp
print valores_cfp
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   del sys.path[0]
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# {(u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'): array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), (u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'): array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), (u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'): array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), (u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'): array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), (u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'): array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), (u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'): array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), (u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'): array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), (u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'): array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object)}
# {(u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'): array([u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', ..., u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15'], dtype=object), (u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'): array([u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', ..., u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15'], dtype=object), (u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'): array([u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', ..., u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15'], dtype=object), (u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'): array([u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', ..., u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15'], dtype=object), (u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'): array([u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', ..., u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15'], dtype=object), (u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'): array([u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', ..., u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15'], dtype=object), (u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'): array([u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', ..., u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15'], dtype=object), (u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'): array([u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', ..., u'RFP-YFP:585/10,620/15',
#        u'RFP-YFP:585/10,620/15', u'RFP-YFP:585/10,620/15'], dtype=object)}
# {(u'pLux76:RFP/std:YFP/std:CFP', u'M9-glicerol'): array([u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', ..., u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25'], dtype=object), (u'std:RFP/std:YFP/std:CFP', u'M9-glucosa'): array([u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', ..., u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25'], dtype=object), (u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glucosa'): array([u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', ..., u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25'], dtype=object), (u'pLux76:RFP/pTet:YFP/std:CFP', u'M9-glicerol'): array([u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', ..., u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25'], dtype=object), (u'pLux76:RFP/std:YFP/std:CFP', u'M9-glucosa'): array([u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', ..., u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25'], dtype=object), (u'std:RFP/std:YFP/std:CFP', u'M9-glicerol'): array([u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', ..., u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25'], dtype=object), (u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'): array([u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', ..., u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25'], dtype=object), (u'pLux76:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'): array([u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', ..., u'RFP-YFP:500/27,540/25',
#        u'RFP-YFP:500/27,540/25', u'RFP-YFP:500/27,540/25'], dtype=object)}
# {u'M9-glicerol': array([u'CFP:420/50,485/20', u'CFP:420/50,485/20', u'CFP:420/50,485/20',
#        ..., u'CFP:420/50,485/20', u'CFP:420/50,485/20',
#        u'CFP:420/50,485/20'], dtype=object), u'M9-glucosa': array([u'CFP:420/50,485/20', u'CFP:420/50,485/20', u'CFP:420/50,485/20',
#        ..., u'CFP:420/50,485/20', u'CFP:420/50,485/20',
#        u'CFP:420/50,485/20'], dtype=object)}

# %%
t_horas=(dfexp['measurements_time'].values)
t_min=((dfexp['measurements_time'].values)*60) 

print mnames
print t_horas
print t_min


vo=valores_od.values()
vr=valores_rfp.values()
vy=valores_yfp.values()
vc=valores_cfp.values()
  
print vo
# Out:
# [u'OD600:600' u'CFP:420/50,485/20' u'RFP-YFP:585/10,620/15'
#  u'RFP-YFP:500/27,540/25']
# [  0.19444444   0.19444444   0.19444444 ...,  24.22027778  24.22027778
#   24.22027778]
# [   11.66666667    11.66666667    11.66666667 ...,  1453.21666667
#   1453.21666667  1453.21666667]
# [array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object), array([u'OD600:600', u'OD600:600', u'OD600:600', ..., u'OD600:600',
#        u'OD600:600', u'OD600:600'], dtype=object)]

# %%
t_mino=((dfexp[dfexp.measurements_name=='OD600:600']['measurements_time'].values)*60)     
 
plt.plot(t_mino,vo)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-410-0d2dfc8cb446> in <module>()
#       1 t_mino=((dfexp[dfexp.measurements_name=='OD600:600']['measurements_time'].values)*60)
#       2
# ----> 3 plt.plot(t_mino,vo)
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3238                       mplDeprecation)
#    3239     try:
# -> 3240         ret = ax.plot(*args, **kwargs)
#    3241     finally:
#    3242         ax._hold = washold
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\matplotlib\axes\_axes.pyc in plot(self, *args, **kwargs)
#    1435         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1436
# -> 1437         for line in self._get_lines(*args, **kwargs):
#    1438             self.add_line(line)
#    1439             lines.append(line)
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\matplotlib\axes\_base.pyc in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\matplotlib\axes\_base.pyc in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\matplotlib\axes\_base.pyc in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (23280L,) and (8L, 11640L)
