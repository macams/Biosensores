# %%
import flapjack
from flapjack import registry as reg
from flapjack import analysis as analysis
from flapjack import tables as tables
import matplotlib.pyplot as plt
import pandas as pd
import pandas.io.sql as psql
import numpy as np
import scipy
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
registry = reg.Registry(database_name='data', username='maca', password='macata125')

# %%
# First we make a query to the database by applying filters 
qall = registry.queryAll()
qexp= qall.filter((tables.samples.experiment_id==14)|(tables.samples.experiment_id==15)|(tables.samples.experiment_id==16))


qsss = qexp.filter(tables.plasmids.name=='J23106:RFP/std:YFP/std:CFP')
qpss = qexp.filter(tables.plasmids.name=='J23106:RFP/J23107:YFP/std:CFP')
qpts = qexp.filter(tables.plasmids.name=='J23106:RFP/pLacI:YFP/std:CFP')
qpls = qexp.filter(tables.plasmids.name=='J23106:RFP/pLas81:YFP/std:CFP')

dfexp=psql.read_sql_query(qexp.selectable, registry.engine)
dfsss = psql.read_sql_query(qsss.selectable, registry.engine)
dfsss.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           446979         OD600:600
# 1                        0.0        Layout           446980         OD600:600
# 2                        0.0        Layout           446981         OD600:600
# 3                        0.0        Layout           446982         OD600:600
# 4                        0.0        Layout           446983         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.083           0.194444                    1251        1251
# 1               0.091           0.194444                    1252        1252
# 2               0.083           0.194444                    1253        1253
# 3               0.083           0.194444                    1254        1254
# 4               0.104           0.194444                    1255        1255
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                     14            1            3    M9-glucosa           12
# 1                     14            1            4    M9-glucosa           12
# 2                     14            1            5    M9-glucosa           12
# 3                     14            1            6    M9-glucosa           12
# 4                     14            1            7    M9-glucosa           12
#
#                 plasmids_name cells_strain  experiments_id  \
# 0  J23106:RFP/std:YFP/std:CFP        Top10              14
# 1  J23106:RFP/std:YFP/std:CFP        Top10              14
# 2  J23106:RFP/std:YFP/std:CFP        Top10              14
# 3  J23106:RFP/std:YFP/std:CFP        Top10              14
# 4  J23106:RFP/std:YFP/std:CFP        Top10              14
#
#      experiments_name  experiments_machine
# 0  cinetica 4 rep 1 1  Synergy HTX15070916
# 1  cinetica 4 rep 1 1  Synergy HTX15070916
# 2  cinetica 4 rep 1 1  Synergy HTX15070916
# 3  cinetica 4 rep 1 1  Synergy HTX15070916
# 4  cinetica 4 rep 1 1  Synergy HTX15070916

# %%
dfpss = psql.read_sql_query(qpss.selectable, registry.engine)
dfpss.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           446984         OD600:600
# 1                        0.0        Layout           446985         OD600:600
# 2                        0.0        Layout           446986         OD600:600
# 3                        0.0        Layout           446987         OD600:600
# 4                        0.0        Layout           446988         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.088           0.194444                    1256        1256
# 1               0.089           0.194444                    1257        1257
# 2               0.093           0.194444                    1258        1258
# 3               0.086           0.194444                    1259        1259
# 4               0.083           0.194444                    1260        1260
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                     14            1            8    M9-glucosa           13
# 1                     14            1            9    M9-glucosa           13
# 2                     14            1           10    M9-glucosa           13
# 3                     14            1           11    M9-glucosa           13
# 4                     14            1           12    M9-glucosa           13
#
#                    plasmids_name cells_strain  experiments_id  \
# 0  J23106:RFP/J23107:YFP/std:CFP        Top10              14
# 1  J23106:RFP/J23107:YFP/std:CFP        Top10              14
# 2  J23106:RFP/J23107:YFP/std:CFP        Top10              14
# 3  J23106:RFP/J23107:YFP/std:CFP        Top10              14
# 4  J23106:RFP/J23107:YFP/std:CFP        Top10              14
#
#      experiments_name  experiments_machine
# 0  cinetica 4 rep 1 1  Synergy HTX15070916
# 1  cinetica 4 rep 1 1  Synergy HTX15070916
# 2  cinetica 4 rep 1 1  Synergy HTX15070916
# 3  cinetica 4 rep 1 1  Synergy HTX15070916
# 4  cinetica 4 rep 1 1  Synergy HTX15070916

# %%
dfpts = psql.read_sql_query(qpts.selectable, registry.engine)
dfpts.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           447003         OD600:600
# 1                        0.0        Layout           447004         OD600:600
# 2                        0.0        Layout           447005         OD600:600
# 3                        0.0        Layout           447006         OD600:600
# 4                        0.0        Layout           447007         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.094           0.194444                    1275        1275
# 1               0.108           0.194444                    1276        1276
# 2               0.107           0.194444                    1277        1277
# 3               0.083           0.194444                    1278        1278
# 4               0.082           0.194444                    1279        1279
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                     14            3            3    M9-glucosa            3
# 1                     14            3            4    M9-glucosa            3
# 2                     14            3            5    M9-glucosa            3
# 3                     14            3            6    M9-glucosa            3
# 4                     14            3            7    M9-glucosa            3
#
#                   plasmids_name cells_strain  experiments_id  \
# 0  J23106:RFP/pLacI:YFP/std:CFP        Top10              14
# 1  J23106:RFP/pLacI:YFP/std:CFP        Top10              14
# 2  J23106:RFP/pLacI:YFP/std:CFP        Top10              14
# 3  J23106:RFP/pLacI:YFP/std:CFP        Top10              14
# 4  J23106:RFP/pLacI:YFP/std:CFP        Top10              14
#
#      experiments_name  experiments_machine
# 0  cinetica 4 rep 1 1  Synergy HTX15070916
# 1  cinetica 4 rep 1 1  Synergy HTX15070916
# 2  cinetica 4 rep 1 1  Synergy HTX15070916
# 3  cinetica 4 rep 1 1  Synergy HTX15070916
# 4  cinetica 4 rep 1 1  Synergy HTX15070916

# %%
dfpls = psql.read_sql_query(qpls.selectable, registry.engine)
dfpls.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           447008         OD600:600
# 1                        0.0        Layout           447009         OD600:600
# 2                        0.0        Layout           447010         OD600:600
# 3                        0.0        Layout           447011         OD600:600
# 4                        0.0        Layout           447012         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.086           0.194444                    1280        1280
# 1               0.085           0.194444                    1281        1281
# 2               0.084           0.194444                    1282        1282
# 3               0.082           0.194444                    1283        1283
# 4               0.083           0.194444                    1284        1284
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                     14            3            8    M9-glucosa           14
# 1                     14            3            9    M9-glucosa           14
# 2                     14            3           10    M9-glucosa           14
# 3                     14            3           11    M9-glucosa           14
# 4                     14            3           12    M9-glucosa           14
#
#                    plasmids_name cells_strain  experiments_id  \
# 0  J23106:RFP/pLas81:YFP/std:CFP        Top10              14
# 1  J23106:RFP/pLas81:YFP/std:CFP        Top10              14
# 2  J23106:RFP/pLas81:YFP/std:CFP        Top10              14
# 3  J23106:RFP/pLas81:YFP/std:CFP        Top10              14
# 4  J23106:RFP/pLas81:YFP/std:CFP        Top10              14
#
#      experiments_name  experiments_machine
# 0  cinetica 4 rep 1 1  Synergy HTX15070916
# 1  cinetica 4 rep 1 1  Synergy HTX15070916
# 2  cinetica 4 rep 1 1  Synergy HTX15070916
# 3  cinetica 4 rep 1 1  Synergy HTX15070916
# 4  cinetica 4 rep 1 1  Synergy HTX15070916

# %%
# Here are the unique measurement names in our dataframe
pnames = dfexp['plasmids_name'].unique()
mnames = dfexp['measurements_name'].unique()
mednames = dfexp['samples_media'].unique()

print pnames
print mnames
print mednames
# Out:
# [u'J23106:RFP/std:YFP/std:CFP' u'J23106:RFP/J23107:YFP/std:CFP'
#  u'J23106:RFP/pLacI:YFP/std:CFP' u'J23106:RFP/pLas81:YFP/std:CFP']
# [u'OD600:600' u'CFP:420/50,485/20' u'RFP-YFP:585/10,620/15'
#  u'RFP-YFP:500/27,540/25']
# [u'M9-glucosa' u'M9-glicerol']

# %%
for p in pnames:
    for e in mednames:
        plt.figure()
        plt.title([p,e])
        plt.plot(dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'],dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'],dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'],dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        
        plt.xlabel('CFP (AU)')
        plt.ylabel('YFP (AU)')
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
for p in pnames:
    for e in mednames:
        plt.figure()
        plt.title([p,e])
        plt.plot(dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'],dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'],dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'],dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'], '.')
        
        plt.xlabel('CFP (AU)')
        plt.ylabel('RFP (AU)')
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
for p in pnames:
    for e in mednames:
        plt.figure()
        plt.title([p,e])
        plt.plot(dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_value'],dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_value'],dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_value'],dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'], '.')
        
        plt.xlabel('OD600(nm)')
        plt.ylabel('CFP (AU)')
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
for p in pnames:
    for e in mednames:
        plt.figure()
        plt.title([p,e])
        plt.plot(dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_value'],dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_value'],dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_value'],dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'], '.')
        
        plt.xlabel('OD600(nm)')
        plt.ylabel('RFP (AU)')
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
for p in pnames:
    for e in mednames:
        plt.figure()
        plt.title([p,e])
        plt.plot(dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_value'],dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_value'],dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_value'],dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        
        plt.xlabel('OD600(nm)')
        plt.ylabel('YFP (AU)')
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
for p in pnames:
    for e in mednames:
        plt.figure()
        plt.title([p,e])
        plt.plot(dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_time'],dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_time'],dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='OD600:600']['measurements_time'],dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        
        plt.xlabel('Time(h)')
        plt.ylabel('OD600(nm)')
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
for p in pnames:
    for e in mednames:
        plt.figure()
        plt.title([p,e])
        plt.plot(dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_time'],dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_time'],dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_time'],dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'], '.')
        
        plt.xlabel('Time(h)')
        plt.ylabel('CFP(AU)')
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
for p in pnames:
    for e in mednames:
        plt.figure()
        plt.title([p,e])
        plt.plot(dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_time'],dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_time'],dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_time'],dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'], '.')
        
        plt.xlabel('Time(h)')
        plt.ylabel('YFP(AU)')
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
for p in pnames:
    for e in mednames:
        plt.figure()
        plt.title([p,e])
        plt.plot(dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_time'],dfexp[dfexp.samples_experiment_id==14][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_time'],dfexp[dfexp.samples_experiment_id==15][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'], '.')
        plt.plot(dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_time'],dfexp[dfexp.samples_experiment_id==16][dfexp.samples_media==e][dfexp.plasmids_name==p][dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'], '.')
        
        plt.xlabel('Time(h)')
        plt.ylabel('RFP(AU)')
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
#max mediciones(no diff)
odmax = np.max(dfexp[dfexp.measurements_name=='OD600:600']['measurements_value'].values)
print odmax
yfpmax = np.max(dfexp[dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'].values)
print yfpmax
rfpmax = np.max(dfexp[dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'].values)
print rfpmax
cfpmax = np.max(dfexp[dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'].values)
print cfpmax
# Out:
# 1.131
# 705814.0
# 91894.0
# 147607.0

# %%
measmax = {}
for e in mednames:
    for m in mnames:
        measmax[e,m] = np.max(dfexp[dfexp.measurements_name==m][dfexp.samples_media==e]['measurements_value'].values)
        print [e,m],measmax[e,m]
        print '---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# [u'M9-glucosa', u'OD600:600'] 1.131
# ---
# [u'M9-glucosa', u'CFP:420/50,485/20'] 45805.0
# ---
# [u'M9-glucosa', u'RFP-YFP:585/10,620/15'] 67869.0
# ---
# [u'M9-glucosa', u'RFP-YFP:500/27,540/25'] 544547.0
# ---
# [u'M9-glicerol', u'OD600:600'] 0.969
# ---
# [u'M9-glicerol', u'CFP:420/50,485/20'] 147607.0
# ---
# [u'M9-glicerol', u'RFP-YFP:585/10,620/15'] 91894.0
# ---
# [u'M9-glicerol', u'RFP-YFP:500/27,540/25'] 705814.0
# ---

# %%
ddif={}
for p in pnames:
    for m in mnames:
        for e in mednames:
            dfe=dfexp[dfexp.measurements_name==m][dfexp.samples_media==e][dfexp.plasmids_name==p]
            ddif[p,m,e]=analysis.compute_measurement_diff(dfe,m)
            print [p,m,e],ddif[p,m,e]
            print'---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# [u'J23106:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glucosa'] [ 0.     0.     0.001 ..., -0.001 -0.009  0.002]
# ---
# [u'J23106:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glicerol'] [ 0.     0.     0.005 ...,  0.    -0.008  0.005]
# ---
# [u'J23106:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'] [   0.    0.  -76. ...,  429.  181.  183.]
# ---
# [u'J23106:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'] [   0.    0.   86. ...,  492.  180.  105.]
# ---
# [u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'] [   0.    0.  -54. ...,  322.  162.  252.]
# ---
# [u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'] [   0.    0.   62. ...,  806.  147.  564.]
# ---
# [u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'] [    0.     0.   102. ...,  2590.  4441.  3467.]
# ---
# [u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'] [    0.     0.    17. ...,  7919.  4632.  6145.]
# ---
# [u'J23106:RFP/J23107:YFP/std:CFP', u'OD600:600', u'M9-glucosa'] [ 0.     0.    -0.004 ..., -0.001  0.001 -0.002]
# ---
# [u'J23106:RFP/J23107:YFP/std:CFP', u'OD600:600', u'M9-glicerol'] [ 0.     0.     0.    ...,  0.     0.001  0.004]
# ---
# [u'J23106:RFP/J23107:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'] [   0.    0.  -44. ...,   91.  102.   60.]
# ---
# [u'J23106:RFP/J23107:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'] [   0.    0.  -25. ...,   41.  154. -107.]
# ---
# [u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'] [   0.    0. -182. ...,   51.  -40.   31.]
# ---
# [u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'] [   0.    0.  -79. ...,  157.  201.  378.]
# ---
# [u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'] [   0.    0.  -26. ...,   -5.  157.  162.]
# ---
# [u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'] [   0.    0.   -9. ...,  474.   74.  327.]
# ---
# [u'J23106:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glucosa'] [ 0.     0.     0.002 ..., -0.003 -0.007  0.006]
# ---
# [u'J23106:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glicerol'] [ 0.     0.     0.001 ...,  0.002 -0.002  0.001]
# ---
# [u'J23106:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'] [   0.    0.   -8. ...,  487.  248.  177.]
# ---
# [u'J23106:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'] [   0.    0.  -55. ...,  397.  288.  264.]
# ---
# [u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'] [   0.    0.    5. ...,  356.   86.  456.]
# ---
# [u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'] [   0.    0. -111. ...,  420.  412.  320.]
# ---
# [u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'] [    0.     0.   -42. ...,  1578.   623.  2354.]
# ---
# [u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'] [    0.     0.    37. ...,  5044.  5568.  3797.]
# ---
# [u'J23106:RFP/pLas81:YFP/std:CFP', u'OD600:600', u'M9-glucosa'] [ 0.     0.    -0.001 ...,  0.     0.     0.   ]
# ---
# [u'J23106:RFP/pLas81:YFP/std:CFP', u'OD600:600', u'M9-glicerol'] [ 0.     0.     0.    ..., -0.001 -0.001  0.002]
# ---
# [u'J23106:RFP/pLas81:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'] [   0.    0.  -94. ...,  173.  165.  -44.]
# ---
# [u'J23106:RFP/pLas81:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'] [   0.    0.  -11. ...,  179.   97.   12.]
# ---
# [u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'] [   0.    0.   -3. ...,   -1.  -10.  166.]
# ---
# [u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'] [   0.    0.   79. ...,  157.  274.  104.]
# ---
# [u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'] [   0.    0.   29. ...,  112.   48. -138.]
# ---
# [u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'] [   0.    0.   68. ...,   86.  102.   63.]
# ---

# %%
measdiffsss = {}

print pnames[0]
for m in mnames:
    for e in mednames:
        measdiffsss[e,m] =analysis.compute_measurement_diff(dfsss[dfsss.measurements_name==m][dfsss.samples_media==e],m)
        print [e,m],measdiffsss[e,m]
        
sssdiff=measdiffsss

print'----'
print pnames[1]
measdiffpss = {}

for e in mednames:
    for m in mnames:
        measdiffpss[e,m] =analysis.compute_measurement_diff(dfpss[dfpss.measurements_name==m][dfpss.samples_media==e],m)
        print [e,m],measdiffpss[e,m]  
#print measdiffpss
pssdiff=measdiffpss

print'----'
print pnames[2]
measdiffpts = {}

for e in mednames:
    for m in mnames:
        measdiffpts[e,m] =analysis.compute_measurement_diff(dfpts[dfpts.measurements_name==m][dfpts.samples_media==e],m)
        print [e,m],measdiffpts[e,m]
        
ptsdiff=measdiffpts

print'----'
print pnames[3]
measdiffpls = {}

for e in mednames:
    for m in mnames:
        measdiffpls[e,m] =analysis.compute_measurement_diff(dfpls[dfpls.measurements_name==m][dfpls.samples_media==e],m)
        print [e,m],measdiffpls[e,m]   
    
#print measdiffpls
plsdiff=measdiffpls

diffs=[measdiffsss,measdiffpss,measdiffpts,measdiffpls]
# Out:
# J23106:RFP/std:YFP/std:CFP
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# [u'M9-glucosa', u'OD600:600'] [ 0.     0.     0.001 ..., -0.001 -0.009  0.002]
# [u'M9-glicerol', u'OD600:600'] [ 0.     0.     0.005 ...,  0.    -0.008  0.005]
# [u'M9-glucosa', u'CFP:420/50,485/20'] [   0.    0.  -76. ...,  429.  181.  183.]
# [u'M9-glicerol', u'CFP:420/50,485/20'] [   0.    0.   86. ...,  492.  180.  105.]
# [u'M9-glucosa', u'RFP-YFP:585/10,620/15'] [   0.    0.  -54. ...,  322.  162.  252.]
# [u'M9-glicerol', u'RFP-YFP:585/10,620/15'] [   0.    0.   62. ...,  806.  147.  564.]
# [u'M9-glucosa', u'RFP-YFP:500/27,540/25'] [    0.     0.   102. ...,  2590.  4441.  3467.]
# [u'M9-glicerol', u'RFP-YFP:500/27,540/25'] [    0.     0.    17. ...,  7919.  4632.  6145.]
# ----
# J23106:RFP/J23107:YFP/std:CFP
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# [u'M9-glucosa', u'OD600:600'] [ 0.     0.    -0.004 ..., -0.001  0.001 -0.002]
# [u'M9-glucosa', u'CFP:420/50,485/20'] [   0.    0.  -44. ...,   91.  102.   60.]
# [u'M9-glucosa', u'RFP-YFP:585/10,620/15'] [   0.    0. -182. ...,   51.  -40.   31.]
# [u'M9-glucosa', u'RFP-YFP:500/27,540/25'] [   0.    0.  -26. ...,   -5.  157.  162.]
# [u'M9-glicerol', u'OD600:600'] [ 0.     0.     0.    ...,  0.     0.001  0.004]
# [u'M9-glicerol', u'CFP:420/50,485/20'] [   0.    0.  -25. ...,   41.  154. -107.]
# [u'M9-glicerol', u'RFP-YFP:585/10,620/15'] [   0.    0.  -79. ...,  157.  201.  378.]
# [u'M9-glicerol', u'RFP-YFP:500/27,540/25'] [   0.    0.   -9. ...,  474.   74.  327.]
# ----
# J23106:RFP/pLacI:YFP/std:CFP
# [u'M9-glucosa', u'OD600:600'] [ 0.     0.     0.002 ..., -0.003 -0.007  0.006]
# [u'M9-glucosa', u'CFP:420/50,485/20'] [   0.    0.   -8. ...,  487.  248.  177.]
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# [u'M9-glucosa', u'RFP-YFP:585/10,620/15'] [   0.    0.    5. ...,  356.   86.  456.]
# [u'M9-glucosa', u'RFP-YFP:500/27,540/25'] [    0.     0.   -42. ...,  1578.   623.  2354.]
# [u'M9-glicerol', u'OD600:600'] [ 0.     0.     0.001 ...,  0.002 -0.002  0.001]
# [u'M9-glicerol', u'CFP:420/50,485/20'] [   0.    0.  -55. ...,  397.  288.  264.]
# [u'M9-glicerol', u'RFP-YFP:585/10,620/15'] [   0.    0. -111. ...,  420.  412.  320.]
# [u'M9-glicerol', u'RFP-YFP:500/27,540/25'] [    0.     0.    37. ...,  5044.  5568.  3797.]
# ----
# J23106:RFP/pLas81:YFP/std:CFP
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# [u'M9-glucosa', u'OD600:600'] [ 0.     0.    -0.001 ...,  0.     0.     0.   ]
# [u'M9-glucosa', u'CFP:420/50,485/20'] [   0.    0.  -94. ...,  173.  165.  -44.]
# [u'M9-glucosa', u'RFP-YFP:585/10,620/15'] [   0.    0.   -3. ...,   -1.  -10.  166.]
# [u'M9-glucosa', u'RFP-YFP:500/27,540/25'] [   0.    0.   29. ...,  112.   48. -138.]
# [u'M9-glicerol', u'OD600:600'] [ 0.     0.     0.    ..., -0.001 -0.001  0.002]
# [u'M9-glicerol', u'CFP:420/50,485/20'] [   0.    0.  -11. ...,  179.   97.   12.]
# [u'M9-glicerol', u'RFP-YFP:585/10,620/15'] [   0.    0.   79. ...,  157.  274.  104.]
# [u'M9-glicerol', u'RFP-YFP:500/27,540/25'] [   0.    0.   68. ...,   86.  102.   63.]

# %%
#max de diffs para rangos de H(x)
diffod={}
maxod={}
for m in mednames:
    diffod[m] =analysis.compute_measurement_diff(dfexp[dfexp.samples_media==m],'OD600:600')
    maxod[m]=np.max(diffod[m])
    
print maxod

diffrfp={}
maxrfp={}
for m in mednames:
    diffrfp[m] =analysis.compute_measurement_diff(dfexp[dfexp.samples_media==m],'RFP-YFP:585/10,620/15')
    maxrfp[m]=np.max(diffrfp[m])
    
print maxrfp

diffyfp={}
maxyfp={}
for m in mednames:
    diffyfp[m] =analysis.compute_measurement_diff(dfexp[dfexp.samples_media==m],'RFP-YFP:500/27,540/25')
    maxyfp[m]=np.max(diffyfp[m])
    
print maxyfp

diffcfp={}
maxcfp={}
for m in mednames:
    diffcfp[m] =analysis.compute_measurement_diff(dfexp[dfexp.samples_media==m],'CFP:420/50,485/20')
    maxcfp[m]=np.max(diffcfp[m])
    
print maxcfp
# Out:
# {u'M9-glicerol': 0.46000000000000008, u'M9-glucosa': 0.11199999999999999}
# {u'M9-glicerol': 5504.0, u'M9-glucosa': 3301.0}
# {u'M9-glicerol': 29994.0, u'M9-glucosa': 27937.0}
# {u'M9-glicerol': 95015.0, u'M9-glucosa': 6133.0}

# %%
Hod={}
Hcfp={}
Hrfp={}
Hyfp={}
for p in pnames:
    for m in mnames:
        for e in mednames:
            if m=='OD600:600':
                Hod[p,m,e] =analysis.channel_entropy(dfexp[dfexp.measurements_name==m][dfexp.samples_media==e][dfexp.plasmids_name==p],m, 256, [0,0.14])
                     
            elif m=='RFP-YFP:585/10,620/15':
                Hrfp[p,m,e] = analysis.channel_entropy(dfexp[dfexp.measurements_name==m][dfexp.samples_media==e][dfexp.plasmids_name==p],m, 256, [0,30900])
                      
            elif m=='RFP-YFP:500/27,540/25':
                Hyfp[p,m,e] = analysis.channel_entropy(dfexp[dfexp.measurements_name==m][dfexp.samples_media==e][dfexp.plasmids_name==p],m, 256, [0,79100])
                           
            else:
                Hcfp[p,m,e] = analysis.channel_entropy(dfexp[dfexp.measurements_name==m][dfexp.samples_media==e][dfexp.plasmids_name==p],m, 256, [0,3700])
                


print 'Entropy of OD', Hod
print 'Entropy of RFP', Hrfp           
print 'Entropy of YFP', Hyfp                
print 'Entropy of CFP', Hcfp
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# Entropy of OD {(u'J23106:RFP/pLas81:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.1523714, (u'J23106:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.8541846, (u'J23106:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.7801843, (u'J23106:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.4750071, (u'J23106:RFP/J23107:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.1685362, (u'J23106:RFP/J23107:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.1816425, (u'J23106:RFP/pLas81:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.0928698, (u'J23106:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.4157972}
# Entropy of RFP {(u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.9083281, (u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 3.408603, (u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.5807559, (u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 3.2990246, (u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 2.917773, (u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.6442237, (u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 3.1240065, (u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.9327581}
# Entropy of YFP {(u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 1.8842399, (u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 2.7958231, (u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 4.7949729, (u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 3.5175614, (u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 3.7712228, (u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.4357138, (u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 1.4753222, (u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.02177}
# Entropy of CFP {(u'J23106:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.6342506, (u'J23106:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 5.726943, (u'J23106:RFP/J23107:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.4479847, (u'J23106:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 5.7601142, (u'J23106:RFP/J23107:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 5.7864971, (u'J23106:RFP/pLas81:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.4067626, (u'J23106:RFP/pLas81:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 5.8122077, (u'J23106:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.5236025}

# %%
Hodsss={}
Hcfpsss={}
Hrfpsss={}
Hyfpsss={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodsss[m,e] =analysis.channel_entropy(dfsss[dfsss.measurements_name==m][dfsss.samples_media==e],m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfpsss[m,e] = analysis.channel_entropy(dfsss[dfsss.measurements_name==m][dfsss.samples_media==e],m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfpsss[m,e] = analysis.channel_entropy(dfsss[dfsss.measurements_name==m][dfsss.samples_media==e],m, 256, [0,79100])
                    
        else:
            Hcfpsss[m,e] = analysis.channel_entropy(dfsss[dfsss.measurements_name==m][dfsss.samples_media==e],m, 256, [0,3700])
                    


print pnames[0]
print 'Entropy of OD', Hodsss
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfpsss
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfpsss
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfpsss
print '---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# J23106:RFP/std:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.4157972, (u'OD600:600', u'M9-glucosa'): 4.7801843}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 5.726943, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.5236025}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 3.408603, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.9327581}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 4.7949729, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.4357138}
# ---

# %%
Hodpss={}
Hcfppss={}
Hrfppss={}
Hyfppss={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodpss[m,e] =analysis.channel_entropy(dfpss[dfpss.measurements_name==m][dfpss.samples_media==e],m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfppss[m,e] = analysis.channel_entropy(dfpss[dfpss.measurements_name==m][dfpss.samples_media==e],m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfppss[m,e] = analysis.channel_entropy(dfpss[dfpss.measurements_name==m][dfpss.samples_media==e],m, 256, [0,79100])
                    
        else:
            Hcfppss[m,e] = analysis.channel_entropy(dfpss[dfpss.measurements_name==m][dfpss.samples_media==e],m, 256, [0,3700])
                    


print pnames[1]
print 'Entropy of OD', Hodpss
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfppss
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfppss
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfppss
print '---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# J23106:RFP/J23107:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.1816425, (u'OD600:600', u'M9-glucosa'): 4.1685362}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 5.7864971, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.4479847}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 2.917773, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.5807559}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 2.7958231, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 3.5175614}
# ---

# %%
Hodpts={}
Hcfppts={}
Hrfppts={}
Hyfppts={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodpts[m,e] =analysis.channel_entropy(dfpts[dfpts.measurements_name==m][dfpts.samples_media==e],m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfppts[m,e] = analysis.channel_entropy(dfpts[dfpts.measurements_name==m][dfpts.samples_media==e],m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfppts[m,e] = analysis.channel_entropy(dfpts[dfpts.measurements_name==m][dfpts.samples_media==e],m, 256, [0,79100])
                    
        else:
            Hcfppts[m,e] = analysis.channel_entropy(dfpts[dfpts.measurements_name==m][dfpts.samples_media==e],m, 256, [0,3700])
                    


print pnames[2]
print 'Entropy of OD', Hodpts
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfppts
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfppts
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfppts
print '---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# J23106:RFP/pLacI:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.4750071, (u'OD600:600', u'M9-glucosa'): 4.8541846}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 5.7601142, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.6342506}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 3.2990246, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.9083281}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 3.7712228, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.02177}
# ---

# %%
Hodpls={}
Hcfppls={}
Hrfppls={}
Hyfppls={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodpls[m,e] =analysis.channel_entropy(dfpls[dfpls.measurements_name==m][dfpls.samples_media==e],m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfppls[m,e] = analysis.channel_entropy(dfpls[dfpls.measurements_name==m][dfpls.samples_media==e],m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfppls[m,e] = analysis.channel_entropy(dfpls[dfpls.measurements_name==m][dfpls.samples_media==e],m, 256, [0,79100])
                    
        else:
            Hcfppls[m,e] = analysis.channel_entropy(dfpls[dfpls.measurements_name==m][dfpls.samples_media==e],m, 256, [0,3700])
                    


print pnames[3]
print 'Entropy of OD', Hodpls
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfppls
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfppls
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfppls
print '---'
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# J23106:RFP/pLas81:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.1523714, (u'OD600:600', u'M9-glucosa'): 4.0928698}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 5.8122077, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.4067626}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 3.1240065, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.6442237}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 1.4753222, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 1.8842399}
# ---

# %%
def channel_entropies(df):
    # Calculate the entropies of all channels in the dataframe df
    Ho= {}
    Hr= {}
    Hy= {}
    Hc= {}
    
    mnames = df.measurements_name.unique()
    pnames = df.plasmids_name.unique()
    mednames = df.samples_media.unique()
    for p in pnames:
        for e in mednames:
            for m in mnames:
                if m=='OD600:600':
                    Ho[p,m,e] =analysis.channel_entropy(df[df.measurements_name==m][df.samples_media==e][df.plasmids_name==p],m, 256, [0,0.14])
                    
                else:
                    if m=='RFP-YFP:585/10,620/15':
                        Hr[p,m,e] = analysis.channel_entropy(df[df.measurements_name==m][df.samples_media==e][df.plasmids_name==p],m, 256, [0,30900])
                        
                    else:
                        if m=='RFP-YFP:500/27,540/25':
                            Hy[p,m,e] = analysis.channel_entropy(df[df.measurements_name==m][df.samples_media==e][df.plasmids_name==p],m, 256, [0,79100])
                            
                        else:
                            Hc[p,m,e] = analysis.channel_entropy(df[df.measurements_name==m][df.samples_media==e][df.plasmids_name==p],m, 256, [0,3700])
                            
    print Ho
    print' '
    print '---'
    print' '
    print Hc
    print' '
    print '---'
    print' '
    print Hr
    print' '
    print '---'
    print' '
    print Hy 
    


Hexp= channel_entropies(dfexp)
print Hexp
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# {(u'J23106:RFP/pLas81:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.1523714, (u'J23106:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.8541846, (u'J23106:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.7801843, (u'J23106:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.4750071, (u'J23106:RFP/J23107:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.1685362, (u'J23106:RFP/J23107:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.1816425, (u'J23106:RFP/pLas81:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.0928698, (u'J23106:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.4157972}
#
# ---
#
# {(u'J23106:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.6342506, (u'J23106:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 5.726943, (u'J23106:RFP/J23107:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.4479847, (u'J23106:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 5.7601142, (u'J23106:RFP/J23107:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 5.7864971, (u'J23106:RFP/pLas81:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.4067626, (u'J23106:RFP/pLas81:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 5.8122077, (u'J23106:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.5236025}
#
# ---
#
# {(u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.9083281, (u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 3.408603, (u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.5807559, (u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 3.2990246, (u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 2.917773, (u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.6442237, (u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 3.1240065, (u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 3.9327581}
#
# ---
#
# {(u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 1.8842399, (u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 2.7958231, (u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 4.7949729, (u'J23106:RFP/J23107:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 3.5175614, (u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 3.7712228, (u'J23106:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.4357138, (u'J23106:RFP/pLas81:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 1.4753222, (u'J23106:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.02177}
# None

# %%
'''def channel_conditional_entropy(df, m1, m2, nbins, hrange):
    # Compute the conditional entropy H(m2|m1),
    # where m1 and m2 are the names of the measurements
    # Get the diffs
    values1 = compute_measurement_diff(df, m1)
    values2 = compute_measurement_diff(df, m2)
    # Compute the entropy
    density2d = prob_density2d(values1, values2, nbins, hrange)
    return conditional_entropy(density2d)'''



Hyo=analysis.channel_conditional_entropy(dfsss, 'OD600:600', 'RFP-YFP:500/27,540/25',[256,256], [[0,0.14],[0,79100]])
print 'H(dY|dlogOD)=',Hyo

print mnames
# Out:
# H(dY|dlogOD)= 4.44159
# [u'OD600:600' u'CFP:420/50,485/20' u'RFP-YFP:585/10,620/15'
#  u'RFP-YFP:500/27,540/25']

# %%
Hcosss={}
Hrosss={}
Hyosss={}
for e in mednames:
    Hcosss[e]=analysis.channel_conditional_entropy(dfsss[dfsss.samples_media==e], 'OD600:600','CFP:420/50,485/20',[256,256], [[0,0.14],[0,3700]])
    Hrosss[e]=analysis.channel_conditional_entropy(dfsss[dfsss.samples_media==e], 'OD600:600', 'RFP-YFP:585/10,620/15',[256,256], [[0,0.14],[0,30900]])
    Hyosss[e]=analysis.channel_conditional_entropy(dfsss[dfsss.samples_media==e], 'OD600:600', 'RFP-YFP:500/27,540/25',[256,256], [[0,0.14],[0,79100]])
    print pnames[0]
    print 'H(dC|dlogOD)=',[e],Hcosss[e]
    print 'H(dRC|dlogOD)=',[e],Hrosss[e]
    print 'H(dY|dlogOD)=',[e],Hyosss[e]
    print '---'
    print ' '
# Out:
# J23106:RFP/std:YFP/std:CFP
# H(dC|dlogOD)= [u'M9-glucosa'] 4.48821
# H(dRC|dlogOD)= [u'M9-glucosa'] 2.80262
# H(dY|dlogOD)= [u'M9-glucosa'] 3.82583
# ---
#
# J23106:RFP/std:YFP/std:CFP
# H(dC|dlogOD)= [u'M9-glicerol'] 5.30172
# H(dRC|dlogOD)= [u'M9-glicerol'] 3.29612
# H(dY|dlogOD)= [u'M9-glicerol'] 4.34672
# ---

# %%
Hco={}
Hro={}
Hyo={}
for p in pnames:
    for e in mednames:
        Hco[p,e]=analysis.channel_conditional_entropy(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'OD600:600','CFP:420/50,485/20',[256,256], [[0,0.14],[0,3700]])
        Hro[p,e]=analysis.channel_conditional_entropy(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'OD600:600', 'RFP-YFP:585/10,620/15',[256,256], [[0,0.14],[0,30900]])
        Hyo[p,e]=analysis.channel_conditional_entropy(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'OD600:600', 'RFP-YFP:500/27,540/25',[256,256], [[0,0.14],[0,79100]])
        print 'H(dC|dlogOD)=',[p,e],Hco[p,e]
        print 'H(dR|dlogOD)=',[p,e],Hro[p,e]
        print 'H(dY|dlogOD)=',[p,e],Hyo[p,e]
        print '---'
        print ' '
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# H(dC|dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 4.48821
# H(dR|dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 2.80262
# H(dY|dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 3.82583
# ---
#
# H(dC|dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 5.30172
# H(dR|dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 3.29612
# H(dY|dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 4.34672
# ---
#
# H(dC|dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 4.5356
# H(dR|dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 2.37196
# H(dY|dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 2.21141
# ---
#
# H(dC|dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 5.20886
# H(dR|dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 3.04307
# H(dY|dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 2.90331
# ---
#
# H(dC|dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 4.4904
# H(dR|dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 2.71534
# H(dY|dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 3.09018
# ---
#
# H(dC|dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 5.38235
# H(dR|dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 3.2861
# H(dY|dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 4.06947
# ---
#
# H(dC|dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 4.59268
# H(dR|dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 2.55155
# H(dY|dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 1.23627
# ---
#
# H(dC|dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 5.19884
# H(dR|dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 3.05166
# H(dY|dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 1.54244
# ---

# %%
def channel_conditional_entropy3(df, m1, m2, m3, nbins, hrange):
    # Compute the conditional entropy H(m2|m1,m3),
    # where m1 and m2 are the names of the measurements
    # Get the diffs
    values1 = analysis.compute_measurement_diff(df, m1)
    values2 = analysis.compute_measurement_diff(df, m2)
    values3 = analysis.compute_measurement_diff(df, m3)
    # Compute the entropy
    density3d = analysis.prob_density3d(values1, values2,values3, nbins, hrange)
    return analysis.conditional_entropy(density3d)

# %%
Hcyr={}
Hcyo={}
Hcro={}

Hycr={}
Hyco={}
Hyro={}

Hrcy={}
Hrco={}
Hryo={}

for p in pnames:
    for e in mednames:
        Hcyr[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:500/27,540/25','CFP:420/50,485/20','RFP-YFP:585/10,620/15',[256,256,256], [[0,79100],[0,79100],[0,79100]])
        Hcyo[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:500/27,540/25','CFP:420/50,485/20', 'OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        Hcro[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:585/10,620/15','CFP:420/50,485/20', 'OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        Hycr[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:500/27,540/25','RFP-YFP:585/10,620/15',[256,256,256], [[0,79100],[0,79100],[0,79100]])
        Hyco[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:500/27,540/25','OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        Hyro[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:585/10,620/15','RFP-YFP:500/27,540/25', 'OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        Hrcy[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:585/10,620/15','RFP-YFP:500/27,540/25',[256,256,256], [[0,79100],[0,79100],[0,79100]])
        Hrco[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:585/10,620/15', 'OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        Hryo[p,e]=channel_conditional_entropy3(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:500/27,540/25','RFP-YFP:585/10,620/15', 'OD600:600',[256,256,256], [[0,79100],[0,79100],[0,0.14]])
        
        print 'H(dC|dY,dR)=',[p,e],Hcyr[p,e]
        print 'H(dC|dY,dlogOD)=',[p,e],Hcyo[p,e]
        print 'H(dC|dR,dlogOD)=',[p,e],Hcro[p,e]
        print ' '
        print 'H(dY|dC,dR)=',[p,e],Hycr[p,e]
        print 'H(dY|dC,dlogOD)=',[p,e],Hyco[p,e]
        print 'H(dY|dR,dlogOD)=',[p,e],Hyro[p,e]
        print ' '
        print 'H(dR|dC,dY)=',[p,e],Hrcy[p,e]
        print 'H(dR|dC,dlogOD)=',[p,e],Hrco[p,e]
        print 'H(dR|dY,dlogOD)=',[p,e],Hryo[p,e]
        print '---'
        print '---'
        print ' '
# Out:
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\maca\Anaconda3\envs\flapjack\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# H(dC|dY,dR)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 0.962816
# H(dC|dY,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 0.465649
# H(dC|dR,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 0.807281
#
# H(dY|dC,dR)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 3.68583
# H(dY|dC,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 3.08588
# H(dY|dR,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 2.81127
#
# H(dR|dC,dY)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 1.21128
# H(dR|dC,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 1.29834
# H(dR|dY,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glucosa'] 0.693489
# ---
# ---
#
# H(dC|dY,dR)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 1.20985
# H(dC|dY,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 0.623299
# H(dC|dR,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 1.08192
#
# H(dY|dC,dR)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 3.57005
# H(dY|dC,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 3.25519
# H(dY|dR,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 2.6756
#
# H(dR|dC,dY)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 0.890897
# H(dR|dC,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 1.53693
# H(dR|dY,dlogOD)= [u'J23106:RFP/std:YFP/std:CFP', u'M9-glicerol'] 0.495934
# ---
# ---
#
# H(dC|dY,dR)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 0.89673
# H(dC|dY,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 0.644832
# H(dC|dR,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 0.784091
#
# H(dY|dC,dR)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 1.69722
# H(dY|dC,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 1.6429
# H(dY|dR,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 1.44829
#
# H(dR|dC,dY)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 0.683647
# H(dR|dC,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 0.823016
# H(dR|dY,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glucosa'] 0.484865
# ---
# ---
#
# H(dC|dY,dR)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 1.01064
# H(dC|dY,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 0.783624
# H(dC|dR,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 0.9819
#
# H(dY|dC,dR)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 2.06749
# H(dY|dC,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 2.01894
# H(dY|dR,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 1.73375
#
# H(dR|dC,dY)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 1.06049
# H(dR|dC,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 1.27181
# H(dR|dY,dlogOD)= [u'J23106:RFP/J23107:YFP/std:CFP', u'M9-glicerol'] 0.773437
# ---
# ---
#
# H(dC|dY,dR)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 0.883677
# H(dC|dY,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 0.50011
# H(dC|dR,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 0.749367
#
# H(dY|dC,dR)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 2.57059
# H(dY|dC,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 2.39924
# H(dY|dR,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 2.06802
#
# H(dR|dC,dY)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 0.933569
# H(dR|dC,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 1.16674
# H(dR|dY,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glucosa'] 0.595813
# ---
# ---
#
# H(dC|dY,dR)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 1.26982
# H(dC|dY,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 0.663321
# H(dC|dR,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 1.19887
#
# H(dY|dC,dR)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 3.19548
# H(dY|dC,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 2.86747
# H(dY|dR,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 2.46956
#
# H(dR|dC,dY)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 1.02751
# H(dR|dC,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 1.51463
# H(dR|dY,dlogOD)= [u'J23106:RFP/pLacI:YFP/std:CFP', u'M9-glicerol'] 0.581233
# ---
# ---
#
# H(dC|dY,dR)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 0.935565
# H(dC|dY,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 0.71361
# H(dC|dR,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 0.703829
#
# H(dY|dC,dR)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 0.69076
# H(dY|dC,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 0.777599
# H(dY|dR,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 0.621921
#
# H(dR|dC,dY)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 1.10193
# H(dR|dC,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 0.983673
# H(dR|dY,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glucosa'] 0.835803
# ---
# ---
#
# H(dC|dY,dR)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 1.15521
# H(dC|dY,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 1.07727
# H(dC|dR,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 0.984677
#
# H(dY|dC,dR)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 0.853703
# H(dY|dC,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 0.932293
# H(dY|dR,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 0.774054
#
# H(dR|dC,dY)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 1.35823
# H(dR|dC,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 1.2629
# H(dR|dY,dlogOD)= [u'J23106:RFP/pLas81:YFP/std:CFP', u'M9-glicerol'] 1.19588
# ---
# ---

# %%
def channel_conditional_entropy4(df, m1, m2, m3, m4, nbins, hrange):
    # Compute the conditional entropy H(m2|m1,m3,m4),
    # where m1 and m2 are the names of the measurements
    # Get the diffs
    values1 = analysis.compute_measurement_diff(df, m1)
    values2 = analysis.compute_measurement_diff(df, m2)
    values3 = analysis.compute_measurement_diff(df, m3)
    values4 = analysis.compute_measurement_diff(df, m4)
    # Compute the entropy
    density4d = analysis.prob_density4d(values1, values2, values3, values4, nbins, hrange)
    return analysis.conditional_entropy(density4d)


for p in pnames:
    for e in mednames:
        Hcyro[p,e]=channel_conditional_entropy4(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p],'RFP-YFP:500/27,540/25','CFP:420/50,485/20','RFP-YFP:585/10,620/15','OD600:600',[256,256,256,256], [[0,79100],[0,79100],[0,79100],[0,0.14]])
        print 'H(dC|dY,dR,dlogOD)=',[p,e],Hcyro[p,e]

# %%
Hcyro={}
Hycro={}
Hrcyo={}

for p in pnames:
    for e in mednames:
        Hcyro[p,e]=channel_conditional_entropy4(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'RFP-YFP:500/27,540/25','CFP:420/50,485/20','RFP-YFP:585/10,620/15','OD600:600',[256,256,256,256], [[0,79100],[0,79100],[0,79100],[0,0.14]])
        Hycro[p,e]=channel_conditional_entropy4(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:500/27,540/25','RFP-YFP:585/10,620/15','OD600:600',[256,256,256,256], [[0,79100],[0,79100],[0,79100],[0,0.14]])
        Hrcyo[p,e]=channel_conditional_entropy4(dfexp[dfexp.samples_media==e][dfexp.plasmids_name==p], 'CFP:420/50,485/20','RFP-YFP:585/10,620/15','RFP-YFP:500/27,540/25','OD600:600',[256,256,256,256], [[0,79100],[0,79100],[0,79100],[0,0.14]])
        
        print 'H(dC|dY,dR,dlogOD)=',[p,e],Hcyro[p,e]
        print ' '
        print 'H(dY|dC,dR,dlogOD)=',[p,e],Hycro[p,e]
        print ' '
        print 'H(dR|dC,dY,dlogOD)=',[p,e],Hrcyo[p,e]
        print '---'
        print '---'
        print ' '
