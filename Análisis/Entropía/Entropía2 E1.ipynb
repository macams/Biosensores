# %%
import flapjack
from flapjack import registry as reg
from flapjack import analysis as analysis
from flapjack import tables as tables
import matplotlib.pyplot as plt
import pandas as pd
import pandas.io.sql as psql
import numpy as np
import scipy
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
registry = reg.Registry(database_name='data', username='maca', password='macata125')

# %%
# First we make a query to the database by applying filters 
qall = registry.queryAll()
qexp= qall.filter((tables.samples.experiment_id==5)|(tables.samples.experiment_id==6)|(tables.samples.experiment_id==7))
qsss = qexp.filter(tables.plasmids.name=='std:RFP/std:YFP/std:CFP')
qpss = qexp.filter(tables.plasmids.name=='pLux76:RFP/std:YFP/std:CFP')
qpts = qexp.filter(tables.plasmids.name=='pLux76:RFP/pTet:YFP/std:CFP')
qpls = qexp.filter(tables.plasmids.name=='pLux76:RFP/pLacI:YFP/std:CFP')

dfexp=psql.read_sql_query(qexp.selectable, registry.engine)
dfsss = psql.read_sql_query(qsss.selectable, registry.engine)
dfsss.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           111747         OD600:600
# 1                        0.0        Layout           111748         OD600:600
# 2                        0.0        Layout           111749         OD600:600
# 3                        0.0        Layout           111750         OD600:600
# 4                        0.0        Layout           111751         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.083           0.194444                     387         387
# 1               0.082           0.194444                     388         388
# 2               0.082           0.194444                     389         389
# 3               0.082           0.194444                     390         390
# 4               0.083           0.194444                     391         391
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                      5            1            3    M9-glucosa            4
# 1                      5            1            4    M9-glucosa            4
# 2                      5            1            5    M9-glucosa            4
# 3                      5            1            6    M9-glucosa            4
# 4                      5            1            7    M9-glucosa            4
#
#              plasmids_name cells_strain  experiments_id  \
# 0  std:RFP/std:YFP/std:CFP        Top10               5
# 1  std:RFP/std:YFP/std:CFP        Top10               5
# 2  std:RFP/std:YFP/std:CFP        Top10               5
# 3  std:RFP/std:YFP/std:CFP        Top10               5
# 4  std:RFP/std:YFP/std:CFP        Top10               5
#
#                  experiments_name  experiments_machine
# 0  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 1  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 2  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 3  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 4  Cinetica 1 rep 1 base de datos  Synergy HTX15070916

# %%
dfpss = psql.read_sql_query(qpss.selectable, registry.engine)
dfpss.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           111752         OD600:600
# 1                        0.0        Layout           111753         OD600:600
# 2                        0.0        Layout           111754         OD600:600
# 3                        0.0        Layout           111755         OD600:600
# 4                        0.0        Layout           111756         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.083           0.194444                     392         392
# 1               0.084           0.194444                     393         393
# 2               0.083           0.194444                     394         394
# 3               0.083           0.194444                     395         395
# 4               0.082           0.194444                     396         396
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                      5            1            8    M9-glucosa            5
# 1                      5            1            9    M9-glucosa            5
# 2                      5            1           10    M9-glucosa            5
# 3                      5            1           11    M9-glucosa            5
# 4                      5            1           12    M9-glucosa            5
#
#                 plasmids_name cells_strain  experiments_id  \
# 0  pLux76:RFP/std:YFP/std:CFP        Top10               5
# 1  pLux76:RFP/std:YFP/std:CFP        Top10               5
# 2  pLux76:RFP/std:YFP/std:CFP        Top10               5
# 3  pLux76:RFP/std:YFP/std:CFP        Top10               5
# 4  pLux76:RFP/std:YFP/std:CFP        Top10               5
#
#                  experiments_name  experiments_machine
# 0  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 1  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 2  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 3  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 4  Cinetica 1 rep 1 base de datos  Synergy HTX15070916

# %%
dfpts = psql.read_sql_query(qpts.selectable, registry.engine)
dfpts.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           111771         OD600:600
# 1                        0.0        Layout           111772         OD600:600
# 2                        0.0        Layout           111773         OD600:600
# 3                        0.0        Layout           111774         OD600:600
# 4                        0.0        Layout           111775         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.085           0.194444                     411         411
# 1               0.083           0.194444                     412         412
# 2               0.082           0.194444                     413         413
# 3               0.083           0.194444                     414         414
# 4               0.082           0.194444                     415         415
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                      5            3            3    M9-glucosa            6
# 1                      5            3            4    M9-glucosa            6
# 2                      5            3            5    M9-glucosa            6
# 3                      5            3            6    M9-glucosa            6
# 4                      5            3            7    M9-glucosa            6
#
#                  plasmids_name cells_strain  experiments_id  \
# 0  pLux76:RFP/pTet:YFP/std:CFP        Top10               5
# 1  pLux76:RFP/pTet:YFP/std:CFP        Top10               5
# 2  pLux76:RFP/pTet:YFP/std:CFP        Top10               5
# 3  pLux76:RFP/pTet:YFP/std:CFP        Top10               5
# 4  pLux76:RFP/pTet:YFP/std:CFP        Top10               5
#
#                  experiments_name  experiments_machine
# 0  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 1  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 2  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 3  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 4  Cinetica 1 rep 1 base de datos  Synergy HTX15070916

# %%
dfpls = psql.read_sql_query(qpls.selectable, registry.engine)
dfpls.head()
# Out:
#    supplements_concentration inducers_name  measurements_id measurements_name  \
# 0                        0.0        Layout           111776         OD600:600
# 1                        0.0        Layout           111777         OD600:600
# 2                        0.0        Layout           111778         OD600:600
# 3                        0.0        Layout           111779         OD600:600
# 4                        0.0        Layout           111780         OD600:600
#
#    measurements_value  measurements_time  measurements_sample_id  samples_id  \
# 0               0.083           0.194444                     416         416
# 1               0.084           0.194444                     417         417
# 2               0.084           0.194444                     418         418
# 3               0.083           0.194444                     419         419
# 4               0.083           0.194444                     420         420
#
#    samples_experiment_id  samples_row  samples_col samples_media  plasmids_id  \
# 0                      5            3            8    M9-glucosa            7
# 1                      5            3            9    M9-glucosa            7
# 2                      5            3           10    M9-glucosa            7
# 3                      5            3           11    M9-glucosa            7
# 4                      5            3           12    M9-glucosa            7
#
#                   plasmids_name cells_strain  experiments_id  \
# 0  pLux76:RFP/pLacI:YFP/std:CFP        Top10               5
# 1  pLux76:RFP/pLacI:YFP/std:CFP        Top10               5
# 2  pLux76:RFP/pLacI:YFP/std:CFP        Top10               5
# 3  pLux76:RFP/pLacI:YFP/std:CFP        Top10               5
# 4  pLux76:RFP/pLacI:YFP/std:CFP        Top10               5
#
#                  experiments_name  experiments_machine
# 0  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 1  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 2  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 3  Cinetica 1 rep 1 base de datos  Synergy HTX15070916
# 4  Cinetica 1 rep 1 base de datos  Synergy HTX15070916

# %%
# Here are the unique measurement names in our dataframe
pnames = dfexp['plasmids_name'].unique()
mnames = dfexp['measurements_name'].unique()
mednames = dfexp['samples_media'].unique()

print pnames
print mnames
print mednames
# Out:
# [u'std:RFP/std:YFP/std:CFP' u'pLux76:RFP/std:YFP/std:CFP'
#  u'pLux76:RFP/pTet:YFP/std:CFP' u'pLux76:RFP/pLacI:YFP/std:CFP']
# [u'OD600:600' u'CFP:420/50,485/20' u'RFP-YFP:585/10,620/15'
#  u'RFP-YFP:500/27,540/25']
# [u'M9-glucosa' u'M9-glicerol']

# %%
#max mediciones(no diff)
qexp= qall.filter((tables.samples.experiment_id==5)|(tables.samples.experiment_id==6)|(tables.samples.experiment_id==7))
dfexp = psql.read_sql_query(qexp.selectable, registry.engine)

odmax = np.max(dfexp[dfexp.measurements_name=='OD600:600']['measurements_value'].values)
print odmax
yfpmax = np.max(dfexp[dfexp.measurements_name=='RFP-YFP:500/27,540/25']['measurements_value'].values)
print yfpmax
rfpmax = np.max(dfexp[dfexp.measurements_name=='RFP-YFP:585/10,620/15']['measurements_value'].values)
print rfpmax
cfpmax = np.max(dfexp[dfexp.measurements_name=='CFP:420/50,485/20']['measurements_value'].values)
print cfpmax
# Out:
# 1.174
# 1137316.0
# 551860.0
# 100165.0

# %%
measmax = {}
for e in mednames:
    for m in mnames:
        measmax[e,m] = np.max(dfexp[dfexp.measurements_name==m]['measurements_value'].values)
    
print measmax

print '---'

mesmax = {}
for m in mnames:
    mesmax[e,m] = np.max(dfexp[dfexp.measurements_name==m]['measurements_value'].values)
    
print mesmax
# Out:
# {(u'M9-glucosa', u'OD600:600'): 1.1739999999999999, (u'M9-glucosa', u'RFP-YFP:500/27,540/25'): 1137316.0, (u'M9-glucosa', u'CFP:420/50,485/20'): 100165.0, (u'M9-glucosa', u'RFP-YFP:585/10,620/15'): 551860.0, (u'M9-glicerol', u'RFP-YFP:500/27,540/25'): 1137316.0, (u'M9-glicerol', u'RFP-YFP:585/10,620/15'): 551860.0, (u'M9-glicerol', u'CFP:420/50,485/20'): 100165.0, (u'M9-glicerol', u'OD600:600'): 1.1739999999999999}
# ---
# {(u'M9-glicerol', u'RFP-YFP:585/10,620/15'): 551860.0, (u'M9-glicerol', u'OD600:600'): 1.1739999999999999, (u'M9-glicerol', u'CFP:420/50,485/20'): 100165.0, (u'M9-glicerol', u'RFP-YFP:500/27,540/25'): 1137316.0}

# %%
measdiffsss = {}

print pnames[0]
for m in mnames:
    for e in mednames:
        measdiffsss[e,m] =analysis.compute_measurement_diff(dfsss,m)

#print measdiffsss
sssdiff=measdiffsss

print'----'
print pnames[1]
measdiffpss = {}

for e in mednames:
    for m in mnames:
        measdiffpss[e,m] =analysis.compute_measurement_diff(dfpss,m)
          
#print measdiffpss
pssdiff=measdiffpss

print'----'
print pnames[2]
measdiffpts = {}

for e in mednames:
    for m in mnames:
        measdiffpts[e,m] =analysis.compute_measurement_diff(dfpts,m)
print '-' 
#print measdiffpts
ptsdiff=measdiffpts

print'----'
print pnames[3]
measdiffpls = {}

for e in mednames:
    for m in mnames:
        measdiffpls[e,m] =analysis.compute_measurement_diff(dfpls,m)
           
    
#print measdiffpls
plsdiff=measdiffpls

diffs=[measdiffsss,measdiffpss,measdiffpts,measdiffpls]
maxdiffs=[maxsss,maxpss,maxpts, maxpls]

a={}
for m in mednames:
    a[m] =analysis.compute_measurement_diff(dfsss,'OD600:600',)
print a
# Out:
# std:RFP/std:YFP/std:CFP
# ----
# pLux76:RFP/std:YFP/std:CFP
# ----
# pLux76:RFP/pTet:YFP/std:CFP
# -
# ----
# pLux76:RFP/pLacI:YFP/std:CFP
# {u'M9-glicerol': array([ 0.   ,  0.   ,  0.001, ..., -0.003, -0.001, -0.002]), u'M9-glucosa': array([ 0.   ,  0.   ,  0.001, ..., -0.003, -0.001, -0.002])}

# %%
#max de diffs para rangos de H(x)
diffod={}
maxod={}
for m in mednames:
    diffod[m] =analysis.compute_measurement_diff(dfexp,'OD600:600')
    maxod[m]=np.max(diffod[m])
    
print maxod

diffrfp={}
maxrfp={}
for m in mednames:
    diffrfp[m] =analysis.compute_measurement_diff(dfexp,'RFP-YFP:585/10,620/15')
    maxrfp[m]=np.max(diffrfp[m])
    
print maxrfp

diffyfp={}
maxyfp={}
for m in mednames:
    diffyfp[m] =analysis.compute_measurement_diff(dfexp,'RFP-YFP:500/27,540/25')
    maxyfp[m]=np.max(diffyfp[m])
    
print maxyfp

diffcfp={}
maxcfp={}
for m in mednames:
    diffcfp[m] =analysis.compute_measurement_diff(dfexp,'CFP:420/50,485/20')
    maxcfp[m]=np.max(diffcfp[m])
    
print maxcfp
# Out:
# {u'M9-glicerol': 0.13900000000000001, u'M9-glucosa': 0.13900000000000001}
# {u'M9-glicerol': 30898.0, u'M9-glucosa': 30898.0}
# {u'M9-glicerol': 79048.0, u'M9-glucosa': 79048.0}
# {u'M9-glicerol': 3680.0, u'M9-glucosa': 3680.0}

# %%
Hod={}
Hcfp={}
Hrfp={}
Hyfp={}
for p in pnames:
    for m in mnames:
        for e in mednames:
            if m=='OD600:600':
                Hod[p,m,e] =analysis.channel_entropy(dfexp,m, 256, [0,0.14])

            elif m=='RFP-YFP:585/10,620/15':
                Hrfp[p,m,e] = analysis.channel_entropy(dfexp,m, 256, [0,30900])
            
            elif m=='RFP-YFP:500/27,540/25':
                Hyfp[p,m,e] = analysis.channel_entropy(dfexp,m, 256, [0,79100])
                    
            else:
                Hcfp[p,m,e] = analysis.channel_entropy(dfexp,m, 256, [0,3700])
            
          
                
print 'Entropy of OD', Hod
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfp
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfp
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfp
print '---'
# Out:
# Entropy of OD {(u'pLux76:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.7175694, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.7175694, (u'pLux76:RFP/pTet:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.7175694, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.7175694, (u'pLux76:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.7175694, (u'std:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glicerol'): 4.7175694, (u'pLux76:RFP/pTet:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.7175694, (u'std:RFP/std:YFP/std:CFP', u'OD600:600', u'M9-glucosa'): 4.7175694}
# ---
#
# Entropy of CFP {(u'pLux76:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.7788687, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.7788687, (u'pLux76:RFP/pTet:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.7788687, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.7788687, (u'pLux76:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.7788687, (u'pLux76:RFP/pTet:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.7788687, (u'std:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glucosa'): 6.7788687, (u'std:RFP/std:YFP/std:CFP', u'CFP:420/50,485/20', u'M9-glicerol'): 6.7788687}
# ---
#
# Entropy of RFP {(u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.8875694, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.8875694, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.8875694, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.8875694, (u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.8875694, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.8875694, (u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.8875694, (u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.8875694}
# ---
#
# Entropy of YFP {(u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.645226, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.645226, (u'std:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.645226, (u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.645226, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.645226, (u'pLux76:RFP/pTet:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.645226, (u'pLux76:RFP/pLacI:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.645226, (u'pLux76:RFP/std:YFP/std:CFP', u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.645226}
# ---

# %%
Hodsss={}
Hcfpsss={}
Hrfpsss={}
Hyfpsss={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodsss[m,e] =analysis.channel_entropy(dfsss,m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfpsss[m,e] = analysis.channel_entropy(dfsss,m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfpsss[m,e] = analysis.channel_entropy(dfsss,m, 256, [0,79100])
                    
        else:
            Hcfpsss[m,e] = analysis.channel_entropy(dfsss,m, 256, [0,3700])
                    


print pnames[0]
print 'Entropy of OD', Hodsss
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfpsss
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfpsss
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfpsss
print '---'
# Out:
# std:RFP/std:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.7977185, (u'OD600:600', u'M9-glucosa'): 4.7977185}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 6.7690821, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.7690821}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.6178856, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.6178856}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.5227385, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.5227385}
# ---

# %%
Hodpss={}
Hcfppss={}
Hrfppss={}
Hyfppss={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodpss[m,e] =analysis.channel_entropy(dfpss,m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfppss[m,e] = analysis.channel_entropy(dfpss,m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfppss[m,e] = analysis.channel_entropy(dfpss,m, 256, [0,79100])
                    
        else:
            Hcfppss[m,e] = analysis.channel_entropy(dfpss,m, 256, [0,3700])
                    


print pnames[1]
print 'Entropy of OD', Hodpss
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfppss
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfppss
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfppss
print '---'
# Out:
# pLux76:RFP/std:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.7850423, (u'OD600:600', u'M9-glucosa'): 4.7850423}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 6.7616353, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.7616353}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.9984994, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.9984994}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.6622257, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.6622257}
# ---

# %%
Hodpts={}
Hcfppts={}
Hrfppts={}
Hyfppts={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodpts[m,e] =analysis.channel_entropy(dfpts,m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfppts[m,e] = analysis.channel_entropy(dfpts,m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfppts[m,e] = analysis.channel_entropy(dfpts,m, 256, [0,79100])
                    
        else:
            Hcfppts[m,e] = analysis.channel_entropy(dfpts,m, 256, [0,3700])
                    


print pnames[2]
print 'Entropy of OD', Hodpts
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfppts
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfppts
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfppts
print '---'
# Out:
# pLux76:RFP/pTet:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.4221077, (u'OD600:600', u'M9-glucosa'): 4.4221077}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 6.5637946, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.5637946}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.7587614, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.7587614}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.911253, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.911253}
# ---

# %%
Hodpls={}
Hcfppls={}
Hrfppls={}
Hyfppls={}

for m in mnames:
    for e in mednames:
        if m=='OD600:600':
            Hodpls[m,e] =analysis.channel_entropy(dfpls,m, 256, [0,0.14])

        elif m=='RFP-YFP:585/10,620/15':
            Hrfppls[m,e] = analysis.channel_entropy(dfpls,m, 256, [0,30900])
            
        elif m=='RFP-YFP:500/27,540/25':
            Hyfppls[m,e] = analysis.channel_entropy(dfpls,m, 256, [0,79100])
                    
        else:
            Hcfppls[m,e] = analysis.channel_entropy(dfpls,m, 256, [0,3700])
                    


print pnames[3]
print 'Entropy of OD', Hodpls
print '---'                                                    
print ' ' 
print 'Entropy of CFP', Hcfppls
print '---' 
print ' ' 
print 'Entropy of RFP', Hrfppls
print '---'  
print ' ' 
print 'Entropy of YFP', Hyfppls
print '---'
# Out:
# pLux76:RFP/pLacI:YFP/std:CFP
# Entropy of OD {(u'OD600:600', u'M9-glicerol'): 4.778018, (u'OD600:600', u'M9-glucosa'): 4.778018}
# ---
#
# Entropy of CFP {(u'CFP:420/50,485/20', u'M9-glucosa'): 6.8413153, (u'CFP:420/50,485/20', u'M9-glicerol'): 6.8413153}
# ---
#
# Entropy of RFP {(u'RFP-YFP:585/10,620/15', u'M9-glucosa'): 5.9523854, (u'RFP-YFP:585/10,620/15', u'M9-glicerol'): 5.9523854}
# ---
#
# Entropy of YFP {(u'RFP-YFP:500/27,540/25', u'M9-glucosa'): 5.1794548, (u'RFP-YFP:500/27,540/25', u'M9-glicerol'): 5.1794548}
# ---

# %%
Hc=analysis.channel_conditional_entropy(dfatc, 'OD600:600', 'RFP-YFP:500/27,540/25',[256,256], [[0,0.1],[0,8000]])
print Hc

# %%
# Or
H1 = analysis.channel_entropy(dfatc, mnames[0], 256, [0,0.1])
print 'Entropy of', mnames[0], H1
print '---'

# Entropy of all channels (same binning, not good)
# Gives a dictionary with pairs name:entropy
H = analysis.channel_entropies(dfatc, 256, [0,8000])
print H
print '---'

Hc=analysis.channel_conditional_entropy(dfatc, 'OD600:600', 'RFP-YFP:500/27,540/25',[256,256], [[0,0.1],[0,8000]])
print Hc
