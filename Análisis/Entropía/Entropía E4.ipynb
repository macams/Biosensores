# %%
import flapjack
from flapjack import registry as reg
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
from matplotlib import colors

# %%
registry = reg.Registry(database_name='data', username='maca', password='macata125')

# %%
#Plásmidos ensayo 4
a = registry.get_plasmid('J23106:RFP/std:YFP/std:CFP')
b = registry.get_plasmid('J23106:RFP/J23107:YFP/std:CFP')
c = registry.get_plasmid('J23106:RFP/pLacI:YFP/std:CFP')
d = registry.get_plasmid('J23106:RFP/pLas81:YFP/std:CFP')
print a.head()
# Out:
#    measurements_id measurements_name  measurements_value  measurements_time  \
# 0           446979         OD600:600               0.083           0.194444
# 1           446980         OD600:600               0.091           0.194444
# 2           446981         OD600:600               0.083           0.194444
# 3           446982         OD600:600               0.083           0.194444
# 4           446983         OD600:600               0.104           0.194444
#
#    measurements_sample_id  samples_id  samples_experiment_id  samples_row  \
# 0                    1251        1251                     14            1
# 1                    1252        1252                     14            1
# 2                    1253        1253                     14            1
# 3                    1254        1254                     14            1
# 4                    1255        1255                     14            1
#
#    samples_col samples_media
# 0            3    M9-glucosa
# ...

# %%
#106-Std-Std glucosa
ayfp_glu = a[(a.measurements_name=='RFP-YFP:500/27,540/25')&(a.samples_media=='M9-glucosa')]
arfp_glu = a[(a.measurements_name=='RFP-YFP:585/10,620/15')&(a.samples_media=='M9-glucosa')]
acfp_glu = a[(a.measurements_name=='CFP:420/50,485/20')&(a.samples_media=='M9-glucosa')]
aod_glu = a[(a.measurements_name=='OD600:600')&(a.samples_media=='M9-glucosa')]
#106-Std-Std glicerol
ayfp_gli = a[(a.measurements_name=='RFP-YFP:500/27,540/25')&(a.samples_media=='M9-glicerol')]
arfp_gli = a[(a.measurements_name=='RFP-YFP:585/10,620/15')&(a.samples_media=='M9-glicerol')]
acfp_gli = a[(a.measurements_name=='CFP:420/50,485/20')&(a.samples_media=='M9-glicerol')]
aod_gli = a[(a.measurements_name=='OD600:600')&(a.samples_media=='M9-glicerol')]

#106-107-Std glucosa
byfp_glu = b[(b.measurements_name=='RFP-YFP:500/27,540/25')&(b.samples_media=='M9-glucosa')]
brfp_glu = b[(b.measurements_name=='RFP-YFP:585/10,620/15')&(b.samples_media=='M9-glucosa')]
bcfp_glu = b[(b.measurements_name=='CFP:420/50,485/20')&(b.samples_media=='M9-glucosa')]
bod_glu = b[(b.measurements_name=='OD600:600')&(b.samples_media=='M9-glucosa')]
#106-107-Std glicerol
byfp_gli = b[(b.measurements_name=='RFP-YFP:500/27,540/25')&(b.samples_media=='M9-glicerol')]
brfp_gli = b[(b.measurements_name=='RFP-YFP:585/10,620/15')&(b.samples_media=='M9-glicerol')]
bcfp_gli = b[(b.measurements_name=='CFP:420/50,485/20')&(b.samples_media=='M9-glicerol')]
bod_gli = b[(b.measurements_name=='OD600:600')&(b.samples_media=='M9-glicerol')]

#106-plac-Std glucosa
cyfp_glu = c[(c.measurements_name=='RFP-YFP:500/27,540/25')&(c.samples_media=='M9-glucosa')]
cyfp_glu =cyfp_glu[(cyfp_glu.samples_experiment_id==14)|(cyfp_glu.samples_experiment_id==15)|(cyfp_glu.samples_experiment_id==16)]
crfp_glu = c[(c.measurements_name=='RFP-YFP:585/10,620/15')&(c.samples_media=='M9-glucosa')]
crfp_glu =crfp_glu[(crfp_glu.samples_experiment_id==14)|(crfp_glu.samples_experiment_id==15)|(crfp_glu.samples_experiment_id==16)]
ccfp_glu = c[(c.measurements_name=='CFP:420/50,485/20')&(c.samples_media=='M9-glucosa')]
ccfp_glu =ccfp_glu[(ccfp_glu.samples_experiment_id==14)|(ccfp_glu.samples_experiment_id==15)|(ccfp_glu.samples_experiment_id==16)]
cod_glu = c[(c.measurements_name=='OD600:600')&(c.samples_media=='M9-glucosa')]
cod_glu =cod_glu[(cod_glu.samples_experiment_id==14)|(cod_glu.samples_experiment_id==15)|(cod_glu.samples_experiment_id==16)]
#106-plac-Std glicerol
cyfp_gli = c[(c.measurements_name=='RFP-YFP:500/27,540/25')&(c.samples_media=='M9-glicerol')]
cyfp_gli =cyfp_gli[(cyfp_gli.samples_experiment_id==14)|(cyfp_gli.samples_experiment_id==15)|(cyfp_gli.samples_experiment_id==16)]
crfp_gli = c[(c.measurements_name=='RFP-YFP:585/10,620/15')&(c.samples_media=='M9-glicerol')]
crfp_gli =crfp_gli[(crfp_gli.samples_experiment_id==14)|(crfp_gli.samples_experiment_id==15)|(crfp_gli.samples_experiment_id==16)]
ccfp_gli = c[(c.measurements_name=='CFP:420/50,485/20')&(c.samples_media=='M9-glicerol')]
ccfp_gli =ccfp_gli[(ccfp_gli.samples_experiment_id==14)|(ccfp_gli.samples_experiment_id==15)|(ccfp_gli.samples_experiment_id==16)]
cod_gli = c[(c.measurements_name=='OD600:600')&(c.samples_media=='M9-glicerol')]
cod_gli =cod_gli[(cod_gli.samples_experiment_id==14)|(cod_gli.samples_experiment_id==15)|(cod_gli.samples_experiment_id==16)]
#106-plas-Std glucosa
dyfp_glu = d[(d.measurements_name=='RFP-YFP:500/27,540/25')&(d.samples_media=='M9-glucosa')]
drfp_glu = d[(d.measurements_name=='RFP-YFP:585/10,620/15')&(d.samples_media=='M9-glucosa')]
dcfp_glu = d[(d.measurements_name=='CFP:420/50,485/20')&(d.samples_media=='M9-glucosa')]
dod_glu = d[(d.measurements_name=='OD600:600')&(d.samples_media=='M9-glucosa')]
#106-plas-Std glicerol
dyfp_gli = d[(d.measurements_name=='RFP-YFP:500/27,540/25')&(d.samples_media=='M9-glicerol')]
drfp_gli = d[(d.measurements_name=='RFP-YFP:585/10,620/15')&(d.samples_media=='M9-glicerol')]
dcfp_gli = d[(d.measurements_name=='CFP:420/50,485/20')&(d.samples_media=='M9-glicerol')]
dod_gli = d[(d.measurements_name=='OD600:600')&(d.samples_media=='M9-glicerol')]

# %%
plt.figure()
plt.plot(acfp_gli['measurements_value'], ayfp_gli['measurements_value'], '.')
plt.xlabel('yfp (AU)')
plt.ylabel('cfp (AU)')
# Out:
# Text(0,0.5,u'cfp (AU)')

# %%
#106-Std-Std glucosa
ayglu=ayfp_glu['measurements_value'].values
arglu=arfp_glu['measurements_value'].values  
acglu=acfp_glu['measurements_value'].values
aoglu=aod_glu['measurements_value'].values
#106-Std-Std glicerol
aygli=ayfp_gli['measurements_value'].values
argli=arfp_gli['measurements_value'].values  
acgli=acfp_gli['measurements_value'].values
aogli=aod_gli['measurements_value'].values

#106-107-Std glucosa
byglu=byfp_glu['measurements_value'].values
brglu=brfp_glu['measurements_value'].values
bcglu=bcfp_glu['measurements_value'].values
boglu=bod_glu['measurements_value'].values
#106-107-Std glicerol
bygli=byfp_gli['measurements_value'].values
brgli=brfp_gli['measurements_value'].values
bcgli=bcfp_gli['measurements_value'].values
bogli=bod_gli['measurements_value'].values

#106-plac-Std glucosa
cyglu=cyfp_glu['measurements_value'].values
crglu=crfp_glu['measurements_value'].values
ccglu=ccfp_glu['measurements_value'].values
coglu=cod_glu['measurements_value'].values
#106-plac-Std glicerol
cygli=cyfp_gli['measurements_value'].values
crgli=crfp_gli['measurements_value'].values
ccgli=ccfp_gli['measurements_value'].values
cogli=cod_gli['measurements_value'].values

#106-plas-Std glucosa
dyglu=dyfp_glu['measurements_value'].values
drglu=drfp_glu['measurements_value'].values
dcglu=dcfp_glu['measurements_value'].values
doglu=dod_glu['measurements_value'].values
#106-plas-Std glicerol
dygli=dyfp_gli['measurements_value'].values
drgli=drfp_gli['measurements_value'].values
dcgli=dcfp_gli['measurements_value'].values
dogli=dod_gli['measurements_value'].values

# %%
#106-Std-Std glucosa
dy1=np.diff(ayglu)
dr1=np.diff(arglu)
dc1=np.diff(acglu)
do1=np.diff(aoglu)
#106-Std-Std glicerol
dy2=np.diff(aygli)
dr2=np.diff(argli)
dc2=np.diff(acgli)
do2=np.diff(aogli)

#106-107-Std glucosa
dy3=np.diff(byglu)
dr3=np.diff(brglu)
dc3=np.diff(bcglu)
do3=np.diff(boglu)
#106-107-Std glicerol
dy4=np.diff(bygli)
dr4=np.diff(brgli)
dc4=np.diff(bcgli)
do4=np.diff(bogli)

#106-plac-Std glucosa
dy5=np.diff(cyglu)
dr5=np.diff(crglu)
dc5=np.diff(ccglu)
do5=np.diff(coglu)
#106-plac-Std glicerol
dy6=np.diff(cygli)
dr6=np.diff(crgli)
dc6=np.diff(ccgli)
do6=np.diff(cogli)

#106-plas-Std glucosa
dy7=np.diff(dyglu)
dr7=np.diff(drglu)
dc7=np.diff(dcglu)
do7=np.diff(doglu)
#106-plas-Std glicerol
dy8=np.diff(dygli)
dr8=np.diff(drgli)
dc8=np.diff(dcgli)
do8=np.diff(dogli)

# %%
import numpy as np

nb = 84

def entropy(density):
    nzs = np.where(density>0)
    return -np.sum(density[nzs]*np.log2(density[nzs].ravel()))

def joint_entropy(density2d):
    nzs = np.where(density2d>0)
    return -np.sum(density2d[nzs].ravel()*np.log2(density2d[nzs].ravel()))
    
def conditional_entropy(density2d):
    # conditional on the first variable (X), i.e. H(Y|X)
    density = np.sum(density2d, axis=1)
    ex = entropy(density)
    je = joint_entropy(density2d)
    # H(Y|X) = H(X,Y) - H(X)
    return je-ex

def mutual_information(density2d):
    # H(Y)
    density = np.sum(density2d, axis=0)
    # I(X,Y) = H(Y) - H(Y|X)
    return entropy(density)-conditional_entropy(density2d)

def prob_density(x, nbins=nb):
    H, edges = np.histogram(x.ravel(), nbins)
    H = H.astype(np.float32)
    return H/np.sum(H.ravel())

def prob_density2d(x, y, nbins=nb):
    H, xedges, yedges = np.histogram2d(x.ravel(), y.ravel(), [nbins,nbins])
    H = H.astype(np.float32)
    return H/np.sum(H.ravel())

def prob_density3d(x, y, z, nbins=nb):
    H, edges = np.histogramdd([x.ravel(), y.ravel(), z.ravel()], [nbins,nbins,nbins])
    H = H.astype(np.float32)
    return H/np.sum(H.ravel())

def prob_density4d(x, y, z, w, nbins=nb):
    H, edges = np.histogramdd([x.ravel(), y.ravel(), z.ravel(), w.ravel()], [nbins,nbins,nbins,nbins])
    H = H.astype(np.float32)
    return H/np.sum(H.ravel())

# %%
print "J23106-J23101-J23101 Glucosa"
print "---"
print "H(dY) = ", entropy(prob_density(dy1))
print "H(dC) = ", entropy(prob_density(dc1))
print "H(dR) = ", entropy(prob_density(dr1))
print "H(dlogOD) = ", entropy(prob_density(do1))

print "---"
print "H(dY|dlogOD) = ", conditional_entropy(prob_density2d(do1,dy1))
print "H(dC|dlogOD) = ", conditional_entropy(prob_density2d(do1,dc1))
print "H(dR|dlogOD) = ", conditional_entropy(prob_density2d(do1,dr1))
print "H(dY|dC) = ", conditional_entropy(prob_density2d(dc1,dy1))
print "H(dY|dR) = ", conditional_entropy(prob_density2d(dr1,dy1))
print "H(dR|dC) = ", conditional_entropy(prob_density2d(dc1,dr1))
print "H(dR|dY) = ", conditional_entropy(prob_density2d(dy1,dr1))
print "H(dC|dY) = ", conditional_entropy(prob_density2d(dy1,dc1))
print "H(dC|dR) = ", conditional_entropy(prob_density2d(dr1,dc1))


print "---"
print "I(dlogOD,dC) = ", mutual_information(prob_density2d(do1,dc1))
print "I(dlogOD,dY) = ", mutual_information(prob_density2d(do1,dy1))
print "I(dlogOD,dR) = ", mutual_information(prob_density2d(do1,dr1))
print "I(dY,dC) = ", mutual_information(prob_density2d(dc1,dy1))
print "I(dY,dR) = ", mutual_information(prob_density2d(dr1,dy1))
print "I(dR,dC) = ", mutual_information(prob_density2d(dc1,dr1))


print "---"
print "H(dY|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc1,dy1,do1))
print "H(dY|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr1,dy1,do1))
print "H(dY|dC,dR) = ", conditional_entropy(prob_density3d(dc1,dy1,dr1))
print "H(dY|dC,dR,dlogOD) = ", conditional_entropy(prob_density4d(dc1,dy1,dr1,do1))
print "H(dR|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc1,dr1,do1))
print "H(dR|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy1,dr1,do1))
print "H(dR|dC,dY) = ", conditional_entropy(prob_density3d(dc1,dr1,dy1))
print "H(dR|dC,dY,dlogOD) = ", conditional_entropy(prob_density4d(dc1,dr1,dy1,do1))
print "H(dC|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy1,dc1,do1))
print "H(dC|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr1,dc1,do1))
print "H(dC|dY,dR) = ", conditional_entropy(prob_density3d(dy1,dc1,dr1))
print "H(dC|dY,dR,dlogOD) = ", conditional_entropy(prob_density4d(dy1,dc1,dr1,do1))

print "---"
print "H(dY|dC,dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density4d(dc1,dy1,dr1,do1))/entropy(prob_density(dy1))
print "H(dY|dC,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dc1,dy1,do1))/entropy(prob_density(dy1))
print "H(dY|dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dr1,dy1,do1))/entropy(prob_density(dy1))
print "H(dY|dlogOD) / H(dY) = ", conditional_entropy(prob_density2d(do1,dy1))/entropy(prob_density(dy1))
print "H(dR|dC,dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density4d(dc1,dr1,dy1,do1))/entropy(prob_density(dr1))
print "H(dR|dC,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dc1,dr1,do1))/entropy(prob_density(dr1))
print "H(dR|dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dy1,dr1,do1))/entropy(prob_density(dr1))
print "H(dR|dlogOD) / H(dR) = ", conditional_entropy(prob_density2d(do1,dr1))/entropy(prob_density(dr1))
print "H(dC|dR,dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density4d(dr1,dc1,dy1,do1))/entropy(prob_density(dc1))
print "H(dC|dR,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dr1,dc1,do1))/entropy(prob_density(dr1))
print "H(dC|dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dy1,dc1,do1))/entropy(prob_density(dr1))
print "H(dC|dlogOD) / H(dC) = ", conditional_entropy(prob_density2d(do1,dc1))/entropy(prob_density(dr1))

print "H(dY|dC)/ H(dY) = ", conditional_entropy(prob_density2d(dc1,dy1))/entropy(prob_density(dy1))
print "H(dY|dR)/ H(dY) = ", conditional_entropy(prob_density2d(dr1,dy1))/entropy(prob_density(dy1))
print "H(dR|dC)/ H(dR) = ", conditional_entropy(prob_density2d(dc1,dr1))/entropy(prob_density(dr1))
print "H(dR|dY)/ H(dR) = ", conditional_entropy(prob_density2d(dy1,dr1))/entropy(prob_density(dr1))
print "H(dC|dY)/ H(dC) = ", conditional_entropy(prob_density2d(dy1,dc1))/entropy(prob_density(dc1))
print "H(dC|dR)/ H(dC) = ", conditional_entropy(prob_density2d(dr1,dc1))/entropy(prob_density(dc1))
# Out:
# J23106-J23101-J23101 Glucosa
# ---
# H(dY) =  3.62571
# H(dC) =  3.53271
# H(dR) =  3.66788
# H(dlogOD) =  4.38764
# ---
# H(dY|dlogOD) =  2.53453
# H(dC|dlogOD) =  2.38863
# H(dR|dlogOD) =  2.54128
# H(dY|dC) =  2.04403
# H(dY|dR) =  1.41573
# H(dR|dC) =  2.05747
# H(dR|dY) =  1.4579
# H(dC|dY) =  1.95103
# H(dC|dR) =  1.92231
# ---
# I(dlogOD,dC) =  1.14409
# I(dlogOD,dY) =  1.09117
# I(dlogOD,dR) =  1.1266
# I(dY,dC) =  1.58168
# I(dY,dR) =  2.20998
# I(dR,dC) =  1.61041
# ---
# H(dY|dC,dlogOD) =  1.27723
# H(dY|dR,dlogOD) =  0.849737
# H(dY|dC,dR) =  1.02876
# H(dY|dC,dR,dlogOD) =  0.545965
# H(dR|dC,dlogOD) =  1.25038
# H(dR|dY,dlogOD) =  0.856484
# H(dR|dC,dY) =  1.04221
# H(dR|dC,dY,dlogOD) =  0.519123
# H(dC|dY,dlogOD) =  1.13132
# H(dC|dR,dlogOD) =  1.09773
# H(dC|dY,dR) =  1.53535
# H(dC|dY,dR,dlogOD) =  0.793957
# ---
# H(dY|dC,dR,dlogOD) / H(dY) =  0.150582
# H(dY|dC,dlogOD) / H(dY) =  0.35227
# H(dY|dR,dlogOD) / H(dY) =  0.234364
# H(dY|dlogOD) / H(dY) =  0.699046
# ...

# %%
#Porcentajes respecto a entropía inicial
A1= (conditional_entropy(prob_density2d(dc1,dy1))/entropy(prob_density(dy1)))*100 #H(dY|dC)/ H(dY)
B1= (conditional_entropy(prob_density2d(dr1,dy1))/entropy(prob_density(dy1)))*100 #H(dY|dR)/ H(dY)
C1=(conditional_entropy(prob_density2d(do1,dy1))/entropy(prob_density(dy1)))*100 #H(dY|dlogOD) / H(dY)
D1=(conditional_entropy(prob_density3d(dr1,dy1,do1))/entropy(prob_density(dy1)))*100 #H(dY|dR,dlogOD) / H(dY)
E1=(conditional_entropy(prob_density3d(dc1,dy1,do1))/entropy(prob_density(dy1)))*100 #H(dY|dC,dlogOD) / H(dY)
F1=(conditional_entropy(prob_density3d(dc1,dy1,dr1))/entropy(prob_density(dy1)))*100#H(dY|dC,dR)/H(dY)
G1= (conditional_entropy(prob_density4d(dc1,dy1,dr1,do1))/entropy(prob_density(dy1)))*100 #H(dY|dC,dR,dlogOD) / H(dY)

ent_y1=[A1,B1,C1,D1,E1,F1,G1]

X = np.arange(8)
plt.figure()
plt.title('J23106-J23101-J23101 Glucosa 0,4%')
plt.ylabel('Porcentaje respecto a H(dY)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y1[0],color='y',width=0.25,zorder=3)
plt.bar(X[1],ent_y1[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],ent_y1[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],ent_y1[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],ent_y1[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],ent_y1[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],ent_y1[6],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY|dC)/ H(dY)',"H(dY|dR)/ H(dY)",'H(dY|dlogOD) / H(dY)',"H(dY|dR,dlogOD) / H(dY)",'H(dY|dC,dlogOD) / H(dY)','H(dY|dC,dR) / H(dY)',"H(dY|dC,dR,dlogOD) / H(dY)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y1):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hy 106-std glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

A2= (conditional_entropy(prob_density2d(dc1,dr1))/entropy(prob_density(dr1)))*100 #H(dR|dC)/ H(dR)
B2= (conditional_entropy(prob_density2d(dy1,dr1))/entropy(prob_density(dr1)))*100 #H(dR|dY)/ H(dR)
C2=(conditional_entropy(prob_density2d(do1,dr1))/entropy(prob_density(dr1)))*100 #H(dR|dlogOD) / H(dR)
D2=(conditional_entropy(prob_density3d(dy1,dr1,do1))/entropy(prob_density(dr1)))*100 #H(dR|dY,dlogOD) / H(dR)
E2=(conditional_entropy(prob_density3d(dc1,dr1,do1))/entropy(prob_density(dr1)))*100 #H(dR|dC,dlogOD) / H(dR)
F2=(conditional_entropy(prob_density3d(dc1,dr1,dy1))/entropy(prob_density(dr1)))*100 #H(dR|dC,dY)
G2= (conditional_entropy(prob_density4d(dc1,dr1,dy1,do1))/entropy(prob_density(dr1)))*100 #H(dR|dC,dY,dlogOD) / H(dR)

ent_y2=[A2,B2,C2,D2,E2,F2,G2]

X = np.arange(8)
plt.figure()
plt.title('J23106-J23101-J23101 Glucosa 0,4%')
plt.ylabel('Porcentaje respecto a H(dR)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y2[0],color='r',width=0.25,zorder=3)
plt.bar(X[1],ent_y2[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],ent_y2[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],ent_y2[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],ent_y2[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],ent_y2[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],ent_y2[6],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR|dC)/ H(dR)',"H(dR|dY)/ H(dR)",'H(dR|dlogOD) / H(dR)',"H(dR|dY,dlogOD) / H(dR)",'H(dR|dC,dlogOD) / H(dR)','H(dR|dC,dY)/H(dR)',"H(dR|dC,dY,dlogOD) / H(dR)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y2):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hr 106-std glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
#Porcentajes respecto a entropía inicial
hc1=entropy(prob_density(dc1))#H(dC)
ho1=entropy(prob_density(do1))#H(dlogOD)
hyo1=conditional_entropy(prob_density2d(do1,dy1))#H(dY|dlogOD)
hco1=conditional_entropy(prob_density2d(do1,dc1))#H(dC|dlogOD)
hro1=conditional_entropy(prob_density2d(do1,dr1))#H(dR|dlogOD)

hy1=entropy(prob_density(dy1))#H(dY)
hyc1=conditional_entropy(prob_density2d(dc1,dy1))#H(dY|dC)
hyr1=conditional_entropy(prob_density2d(dr1,dy1))#H(dY|dR)
hyco1=conditional_entropy(prob_density3d(dc1,dy1,do1))#H(dY|dC,dlogOD)
hyro1=conditional_entropy(prob_density3d(dr1,dy1,do1))#H(dY|dR,dlogOD)
hycr1= conditional_entropy(prob_density3d(dc1,dy1,dr1))#H(dY|dC,dR) 
hycro1=conditional_entropy(prob_density4d(dc1,dy1,dr1,do1))#H(dY|dC,dR,dlogOD)

hr1=entropy(prob_density(dr1))#H(dR)
hrc1= conditional_entropy(prob_density2d(dc1,dr1))#H(dR|dC)
hry1=conditional_entropy(prob_density2d(dy1,dr1))#H(dR|dY)
hrco1=conditional_entropy(prob_density3d(dc1,dr1,do1))#H(dR|dC,dlogOD)
hryo1=conditional_entropy(prob_density3d(dy1,dr1,do1))#H(dR|dY,dlogOD)
hrcy1= conditional_entropy(prob_density3d(dc1,dr1,dy1))#H(dR|dC,dY)
hrcyo1=conditional_entropy(prob_density4d(dc1,dr1,dy1,do1))#H(dR|dC,dY,dlogOD)

hc1=entropy(prob_density(dc1))#H(dC)
hcy1=conditional_entropy(prob_density2d(dy1,dc1))#H(dC|dY)
hcr1=conditional_entropy(prob_density2d(dr1,dc1))#H(dC|dR)
hcyo1=conditional_entropy(prob_density3d(dy1,dc1,do1))#H(dC|dY,dlogOD)
hcro1=conditional_entropy(prob_density3d(dr1,dc1,do1))#H(dC|dR,dlogOD)
hcyr1=conditional_entropy(prob_density3d(dy1,dc1,dr1))#H(dC|dY,dR)
hcyro1=conditional_entropy(prob_density4d(dy1,dc1,dr1,do1))#H(dC|dY,dR,dlogOD)
soloc1=[hc1,hcy1,hcr1,hcyo1,hcro1,hcyr1,hycro1]

soloh1=[hr1,hy1,hc1,ho1]
hod1=[hr1,hro1,hy1,hyo1,hc1,hco1]
soloy1=[hy1,hyc1,hyr1,hyo1,hyco1,hyro1,hycr1,hycro1]
solor1=[hr1,hrc1,hry1,hro1,hrco1,hryo1,hrcy1,hrcyo1]


X = np.arange(4)
plt.figure()
plt.title('J23106-J23101-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloh1[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],soloh1[1],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[2],soloh1[2],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[3],soloh1[3],color='g',width=0.25,label='H(dlogOD)',zorder=3)
plt.xticks(X, ['H(dR)',"H(dY)",'H(dC)',"H(dlogOD)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloh1):
    plt.text(a-0.15,b+0.2,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='h 106-std glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)


X = np.arange(7)
plt.figure()
plt.title('J23106-J23101-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],hod1[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],hod1[1],color='coral',width=0.25,label='H(dR)|dlogOD',zorder=3)
plt.bar(X[2],hod1[2],color='gold',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[3],hod1[3],color='y',width=0.25,label='H(dY)|dlogOD',zorder=3)
plt.bar(X[4],hod1[4],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[5],hod1[5],color='skyblue',width=0.25,label='H(dC)|dlogOD',zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dlogOD)","H(dY)",'H(dY|dlogOD)','H(dC)',"H(dC|dlogOD) "],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,hod1):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='ho 106-std glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
soloy1=[hy1,hyc1,hyr1,hyo1,hyco1,hyro1,hycr1,hycro1]
solor1=[hr1,hrc1,hry1,hro1,hrco1,hryo1,hrcy1,hrcyo1]


X = np.arange(9)
plt.figure()
plt.title('J23106-J23101-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloy1[0],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[1],soloy1[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],soloy1[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],soloy1[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],soloy1[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],soloy1[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],soloy1[6],color='y',width=0.25,zorder=3)
plt.bar(X[7],soloy1[7],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY)',"H(dY|dC)",'H(dY|dR)','H(dY|dlogOD)',"H(dY|dC,dlogOD)",'H(dY|dR,dlogOD)',"H(dY|dC,dR)",'H(dY|dC,dR,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloy1):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hy 106-std glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

X = np.arange(9)
plt.figure()
plt.title('J23106-J23101-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],solor1[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],solor1[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],solor1[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],solor1[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],solor1[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],solor1[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],solor1[6],color='r',width=0.25,zorder=3)
plt.bar(X[7],solor1[7],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dC)",'H(dR|dY)','H(dR|dlogOD)',"H(dR|dC,dlogOD)",'H(dR|dY,dlogOD)',"H(dR|dC,dY)",'H(dR|dC,dY,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloy1):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hr 106-std glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
print "J23106-J23101-J23101 Glicerol"
print "---"
print "H(dY) = ", entropy(prob_density(dy2))
print "H(dC) = ", entropy(prob_density(dc2))
print "H(dR) = ", entropy(prob_density(dr2))
print "H(dlogOD) = ", entropy(prob_density(do2))

print "---"
print "H(dY|dlogOD) = ", conditional_entropy(prob_density2d(do2,dy2))
print "H(dC|dlogOD) = ", conditional_entropy(prob_density2d(do2,dc2))
print "H(dR|dlogOD) = ", conditional_entropy(prob_density2d(do2,dr2))
print "H(dY|dC) = ", conditional_entropy(prob_density2d(dc2,dy2))
print "H(dY|dR) = ", conditional_entropy(prob_density2d(dr2,dy2))
print "H(dR|dC) = ", conditional_entropy(prob_density2d(dc2,dr2))
print "H(dR|dY) = ", conditional_entropy(prob_density2d(dy2,dr2))
print "H(dC|dY) = ", conditional_entropy(prob_density2d(dy2,dc2))
print "H(dC|dR) = ", conditional_entropy(prob_density2d(dr2,dc2))

print "---"
print "I(dlogOD,dC) = ", mutual_information(prob_density2d(do2,dc2))
print "I(dlogOD,dY) = ", mutual_information(prob_density2d(do2,dy2))
print "I(dlogOD,dR) = ", mutual_information(prob_density2d(do2,dr2))
print "I(dY,dC) = ", mutual_information(prob_density2d(dc2,dy2))
print "I(dY,dR) = ", mutual_information(prob_density2d(dr2,dy2))
print "I(dR,dC) = ", mutual_information(prob_density2d(dc2,dr2))


print "---"
print "H(dY|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc2,dy2,do2))
print "H(dY|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr2,dy2,do2))
print "H(dY|dC,dR) = ", conditional_entropy(prob_density3d(dc2,dy2,dr2))
print "H(dY|dC,dR,dlogOD) = ", conditional_entropy(prob_density4d(dc2,dy2,dr2,do2))
print "H(dR|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc2,dr2,do2))
print "H(dR|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy2,dr2,do2))
print "H(dR|dC,dY) = ", conditional_entropy(prob_density3d(dc2,dr2,dy2))
print "H(dR|dC,dY,dlogOD) = ", conditional_entropy(prob_density4d(dc2,dr2,dy2,do2))
print "H(dC|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy2,dc2,do2))
print "H(dC|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr2,dc2,do2))
print "H(dC|dY,dR) = ", conditional_entropy(prob_density3d(dy2,dc2,dr2))
print "H(dC|dY,dR,dlogOD) = ", conditional_entropy(prob_density4d(dy2,dc2,dr2,do2))


print "---"
print "H(dY|dC,dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density4d(dc2,dy2,dr2,do2))/entropy(prob_density(dy2))
print "H(dY|dC,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dc2,dy2,do2))/entropy(prob_density(dy2))
print "H(dY|dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dr2,dy2,do2))/entropy(prob_density(dy2))
print "H(dY|dlogOD) / H(dY) = ", conditional_entropy(prob_density2d(do2,dy2))/entropy(prob_density(dy2))
print "H(dR|dC,dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density4d(dc2,dr2,dy2,do2))/entropy(prob_density(dr2))
print "H(dR|dC,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dc2,dr2,do2))/entropy(prob_density(dr2))
print "H(dR|dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dy2,dr2,do2))/entropy(prob_density(dr2))
print "H(dR|dlogOD) / H(dR) = ", conditional_entropy(prob_density2d(do2,dr2))/entropy(prob_density(dr2))
print "H(dC|dR,dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density4d(dr2,dc2,dy2,do2))/entropy(prob_density(dc2))
print "H(dC|dR,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dr2,dc2,do2))/entropy(prob_density(dr2))
print "H(dC|dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dy2,dc2,do2))/entropy(prob_density(dr2))
print "H(dC|dlogOD) / H(dC) = ", conditional_entropy(prob_density2d(do2,dc2))/entropy(prob_density(dr2))


print "H(dY|dC)/ H(dY) = ", conditional_entropy(prob_density2d(dc2,dy2))/entropy(prob_density(dy2))
print "H(dY|dR)/ H(dY) = ", conditional_entropy(prob_density2d(dr2,dy2))/entropy(prob_density(dy2))
print "H(dR|dC)/ H(dR) = ", conditional_entropy(prob_density2d(dc2,dr2))/entropy(prob_density(dr2))
print "H(dR|dY)/ H(dR) = ", conditional_entropy(prob_density2d(dy2,dr2))/entropy(prob_density(dr2))
print "H(dC|dY)/ H(dC) = ", conditional_entropy(prob_density2d(dy2,dc2))/entropy(prob_density(dc2))
print "H(dC|dR)/ H(dC) = ", conditional_entropy(prob_density2d(dr2,dc2))/entropy(prob_density(dc2))
# Out:
# J23106-J23101-J23101 Glicerol
# ---
# H(dY) =  3.28302
# H(dC) =  2.98918
# H(dR) =  3.11067
# H(dlogOD) =  4.15867
# ---
# H(dY|dlogOD) =  2.15306
# H(dC|dlogOD) =  2.22058
# H(dR|dlogOD) =  2.10876
# H(dY|dC) =  2.34669
# H(dY|dR) =  1.47902
# H(dR|dC) =  2.3164
# H(dR|dY) =  1.30668
# H(dC|dY) =  2.05285
# H(dC|dR) =  2.19491
# ---
# I(dlogOD,dC) =  0.768603
# I(dlogOD,dY) =  1.12996
# I(dlogOD,dR) =  1.00191
# I(dY,dC) =  0.936331
# I(dY,dR) =  1.804
# I(dR,dC) =  0.794271
# ---
# H(dY|dC,dlogOD) =  1.11132
# H(dY|dR,dlogOD) =  0.84108
# H(dY|dC,dR) =  0.879529
# H(dY|dC,dR,dlogOD) =  0.394932
# H(dR|dC,dlogOD) =  1.19736
# H(dR|dY,dlogOD) =  0.796787
# H(dR|dC,dY) =  0.849244
# H(dR|dC,dY,dlogOD) =  0.480973
# H(dC|dY,dlogOD) =  1.17884
# H(dC|dR,dlogOD) =  1.30917
# H(dC|dY,dR) =  1.59542
# H(dC|dY,dR,dlogOD) =  0.863023
# ---
# H(dY|dC,dR,dlogOD) / H(dY) =  0.120295
# H(dY|dC,dlogOD) / H(dY) =  0.338505
# H(dY|dR,dlogOD) / H(dY) =  0.256191
# H(dY|dlogOD) / H(dY) =  0.655816
# ...

# %%
#Porcentajes respecto a entropía inicial
A3= (conditional_entropy(prob_density2d(dc2,dy2))/entropy(prob_density(dy2)))*100 #H(dY|dC)/ H(dY)
B3= (conditional_entropy(prob_density2d(dr2,dy2))/entropy(prob_density(dy2)))*100 #H(dY|dR)/ H(dY)
C3=(conditional_entropy(prob_density2d(do2,dy2))/entropy(prob_density(dy2)))*100 #H(dY|dlogOD) / H(dY)
D3=(conditional_entropy(prob_density3d(dr2,dy2,do2))/entropy(prob_density(dy2)))*100 #H(dY|dR,dlogOD) / H(dY)
E3=(conditional_entropy(prob_density3d(dc2,dy2,do2))/entropy(prob_density(dy2)))*100 #H(dY|dC,dlogOD) / H(dY)
F3=(conditional_entropy(prob_density3d(dc2,dy2,dr2))/entropy(prob_density(dy2)))*100#H(dY|dC,dR)/H(dY)
G3=(conditional_entropy(prob_density4d(dc2,dy2,dr2,do2))/entropy(prob_density(dy2)))*100 #H(dY|dC,dR,dlogOD) / H(dY)

ent_y3=[A3,B3,C3,D3,E3,F3,G3]

X = np.arange(8)
plt.figure()
plt.title('J23101-J23101-J23101 Glicerol 0,2%')
plt.ylabel('Porcentaje respecto a H(dY)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y3[0],color='y',width=0.25,zorder=3)
plt.bar(X[1],ent_y3[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],ent_y3[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],ent_y3[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],ent_y3[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],ent_y3[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],ent_y3[6],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY|dC)/ H(dY)',"H(dY|dR)/ H(dY)",'H(dY|dlogOD) / H(dY)',"H(dY|dR,dlogOD) / H(dY)",'H(dY|dC,dlogOD) / H(dY)','H(dY|dC,dR) / H(dY)',"H(dY|dC,dR,dlogOD) / H(dY)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y3):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hy 106-std gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

A4= (conditional_entropy(prob_density2d(dc2,dr2))/entropy(prob_density(dr2)))*100 #H(dR|dC)/ H(dR)
B4= (conditional_entropy(prob_density2d(dy2,dr2))/entropy(prob_density(dr2)))*100 #H(dR|dY)/ H(dR)
C4=(conditional_entropy(prob_density2d(do2,dr2))/entropy(prob_density(dr2)))*100 #H(dR|dlogOD) / H(dR)
D4=(conditional_entropy(prob_density3d(dy2,dr2,do2))/entropy(prob_density(dr2)))*100 #H(dR|dY,dlogOD) / H(dR)
E4=(conditional_entropy(prob_density3d(dc2,dr2,do2))/entropy(prob_density(dr2)))*100 #H(dR|dC,dlogOD) / H(dR)
F4=(conditional_entropy(prob_density3d(dc2,dr2,dy2))/entropy(prob_density(dr2)))*100 #H(dR|dC,dY)
G4= (conditional_entropy(prob_density4d(dc2,dr2,dy2,do2))/entropy(prob_density(dr2)))*100 #H(dR|dC,dY,dlogOD) / H(dR)

ent_y4=[A4,B4,C4,D4,E4,F4,G4]

X = np.arange(8)
plt.figure()
plt.title('J23101-J23101-J23101 Glicerol 0,2%')
plt.ylabel('Porcentaje respecto a H(dR)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y4[0],color='r',width=0.25,zorder=3)
plt.bar(X[1],ent_y4[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],ent_y4[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],ent_y4[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],ent_y4[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],ent_y4[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],ent_y4[6],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR|dC)/ H(dR)',"H(dR|dY)/ H(dR)",'H(dR|dlogOD) / H(dR)',"H(dR|dY,dlogOD) / H(dR)",'H(dR|dC,dlogOD) / H(dR)','H(dR|dC,dY)/H(dR)',"H(dR|dC,dY,dlogOD) / H(dR)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y4):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hr 106-std gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
#Porcentajes respecto a entropía inicial
hc2=entropy(prob_density(dc2))#H(dC)
ho2=entropy(prob_density(do2))#H(dlogOD)
hyo2=conditional_entropy(prob_density2d(do2,dy2))#H(dY|dlogOD)
hco2=conditional_entropy(prob_density2d(do2,dc2))#H(dC|dlogOD)
hro2=conditional_entropy(prob_density2d(do2,dr2))#H(dR|dlogOD)

hy2=entropy(prob_density(dy2))#H(dY)
hyc2=conditional_entropy(prob_density2d(dc2,dy2))#H(dY|dC)
hyr2=conditional_entropy(prob_density2d(dr2,dy2))#H(dY|dR)
hyco2=conditional_entropy(prob_density3d(dc2,dy2,do2))#H(dY|dC,dlogOD)
hyro2=conditional_entropy(prob_density3d(dr2,dy2,do2))#H(dY|dR,dlogOD)
hycr2= conditional_entropy(prob_density3d(dc2,dy2,dr2))#H(dY|dC,dR) 
hycro2=conditional_entropy(prob_density4d(dc2,dy2,dr2,do2))#H(dY|dC,dR,dlogOD)

hr2=entropy(prob_density(dr2))#H(dR)
hrc2= conditional_entropy(prob_density2d(dc2,dr2))#H(dR|dC)
hry2=conditional_entropy(prob_density2d(dy2,dr2))#H(dR|dY)
hrco2=conditional_entropy(prob_density3d(dc2,dr2,do2))#H(dR|dC,dlogOD)
hryo2=conditional_entropy(prob_density3d(dy2,dr2,do2))#H(dR|dY,dlogOD)
hrcy2= conditional_entropy(prob_density3d(dc2,dr2,dy2))#H(dR|dC,dY)
hrcyo2=conditional_entropy(prob_density4d(dc2,dr2,dy2,do2))#H(dR|dC,dY,dlogOD)

hc2=entropy(prob_density(dc2))#H(dC)
hcy2=conditional_entropy(prob_density2d(dy2,dc2))#H(dC|dY)
hcr2=conditional_entropy(prob_density2d(dr2,dc2))#H(dC|dR)
hcyo2=conditional_entropy(prob_density3d(dy2,dc2,do2))#H(dC|dY,dlogOD)
hcro2=conditional_entropy(prob_density3d(dr2,dc2,do2))#H(dC|dR,dlogOD)
hcyr2=conditional_entropy(prob_density3d(dy2,dc2,dr2))#H(dC|dY,dR)
hcyro2=conditional_entropy(prob_density4d(dy2,dc2,dr2,do2))#H(dC|dY,dR,dlogOD)
soloc2=[hc2,hcy2,hcr2,hcyo2,hcro2,hcyr2,hycro2]

soloh2=[hr2,hy2,hc2,ho2]
hod2=[hr2,hro2,hy2,hyo2,hc2,hco2]
soloy2=[hy2,hyc2,hyr2,hyo2,hyco2,hyro2,hycr2,hycro2]
solor2=[hr2,hrc2,hry2,hro2,hrco2,hryo2,hrcy2,hrcyo2]


X = np.arange(4)
plt.figure()
plt.title('J23106-J23101-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloh2[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],soloh2[1],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[2],soloh2[2],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[3],soloh2[3],color='g',width=0.25,label='H(dlogOD)',zorder=3)
plt.xticks(X, ['H(dR)',"H(dY)",'H(dC)',"H(dlogOD)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloh2):
    plt.text(a-0.15,b+0.2,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='h 106-std gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)


X = np.arange(7)
plt.figure()
plt.title('J23106-J23101-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],hod2[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],hod2[1],color='coral',width=0.25,label='H(dR)|dlogOD',zorder=3)
plt.bar(X[2],hod2[2],color='gold',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[3],hod2[3],color='y',width=0.25,label='H(dY)|dlogOD',zorder=3)
plt.bar(X[4],hod2[4],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[5],hod2[5],color='skyblue',width=0.25,label='H(dC)|dlogOD',zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dlogOD)","H(dY)",'H(dY|dlogOD)','H(dC)',"H(dC|dlogOD) "],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,hod2):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='ho 106-std gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
soloy2=[hy2,hyc2,hyr2,hyo2,hyco2,hyro2,hycr2,hycro2]
solor2=[hr2,hrc2,hry2,hro2,hrco2,hryo2,hrcy2,hrcyo2]


X = np.arange(9)
plt.figure()
plt.title('J23106-J23101-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloy2[0],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[1],soloy2[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],soloy2[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],soloy2[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],soloy2[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],soloy2[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],soloy2[6],color='y',width=0.25,zorder=3)
plt.bar(X[7],soloy2[7],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY)',"H(dY|dC)",'H(dY|dR)','H(dY|dlogOD)',"H(dY|dC,dlogOD)",'H(dY|dR,dlogOD)',"H(dY|dC,dR)",'H(dY|dC,dR,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloy2):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hy 106-std gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

X = np.arange(9)
plt.figure()
plt.title('J23106-J23101-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],solor2[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],solor2[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],solor2[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],solor2[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],solor2[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],solor2[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],solor2[6],color='r',width=0.25,zorder=3)
plt.bar(X[7],solor2[7],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dC)",'H(dR|dY)','H(dR|dlogOD)',"H(dR|dC,dlogOD)",'H(dR|dY,dlogOD)',"H(dR|dC,dY)",'H(dR|dC,dY,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,solor2):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hr 106-std gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
print "J23106-J23107-J23101 Glucosa"
print "---"
print "H(dY) = ", entropy(prob_density(dy3))
print "H(dC) = ", entropy(prob_density(dc3))
print "H(dR) = ", entropy(prob_density(dr3))
print "H(dlogOD) = ", entropy(prob_density(do3))

print "---"
print "H(dY|dlogOD) = ", conditional_entropy(prob_density2d(do3,dy3))
print "H(dC|dlogOD) = ", conditional_entropy(prob_density2d(do3,dc3))
print "H(dR|dlogOD) = ", conditional_entropy(prob_density2d(do3,dr3))
print "H(dY|dC) = ", conditional_entropy(prob_density2d(dc3,dy3))
print "H(dY|dR) = ", conditional_entropy(prob_density2d(dr3,dy3))
print "H(dR|dC) = ", conditional_entropy(prob_density2d(dc3,dr3))
print "H(dR|dY) = ", conditional_entropy(prob_density2d(dy3,dr3))
print "H(dC|dY) = ", conditional_entropy(prob_density2d(dy3,dc3))
print "H(dC|dR) = ", conditional_entropy(prob_density2d(dr3,dc3))

print "---"
print "I(dlogOD,dC) = ", mutual_information(prob_density2d(do3,dc3))
print "I(dlogOD,dY) = ", mutual_information(prob_density2d(do3,dy3))
print "I(dlogOD,dR) = ", mutual_information(prob_density2d(do3,dr3))
print "I(dY,dC) = ", mutual_information(prob_density2d(dc3,dy3))
print "I(dY,dR) = ", mutual_information(prob_density2d(dr3,dy3))
print "I(dR,dC) = ", mutual_information(prob_density2d(dc3,dr3))


print "---"
print "H(dY|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc3,dy3,do3))
print "H(dY|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr3,dy3,do3))
print "H(dY|dC,dR) = ", conditional_entropy(prob_density3d(dc3,dy3,dr3))
print "H(dY|dC,dR,dlogOD) = ", conditional_entropy(prob_density4d(dc3,dy3,dr3,do3))
print "H(dR|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc3,dr3,do3))
print "H(dR|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy3,dr3,do3))
print "H(dR|dC,dY) = ", conditional_entropy(prob_density3d(dc3,dr3,dy3))
print "H(dR|dC,dY,dlogOD) = ", conditional_entropy(prob_density4d(dc3,dr3,dy3,do3))
print "H(dC|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy3,dc3,do3))
print "H(dC|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr3,dc3,do3))
print "H(dC|dY,dR) = ", conditional_entropy(prob_density3d(dy3,dc3,dr3))
print "H(dC|dY,dR,dlogOD) = ", conditional_entropy(prob_density4d(dy3,dc3,dr3,do3))

print "---"
print "H(dY|dC,dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density4d(dc3,dy3,dr3,do3))/entropy(prob_density(dy3))
print "H(dY|dC,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dc3,dy3,do3))/entropy(prob_density(dy3))
print "H(dY|dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dr3,dy3,do3))/entropy(prob_density(dy3))
print "H(dY|dlogOD) / H(dY) = ", conditional_entropy(prob_density2d(do3,dy3))/entropy(prob_density(dy3))
print "H(dR|dC,dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density4d(dc3,dr3,dy3,do3))/entropy(prob_density(dr3))
print "H(dR|dC,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dc3,dr3,do3))/entropy(prob_density(dr3))
print "H(dR|dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dy3,dr3,do3))/entropy(prob_density(dr3))
print "H(dR|dlogOD) / H(dR) = ", conditional_entropy(prob_density2d(do3,dr3))/entropy(prob_density(dr3))
print "H(dC|dR,dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density4d(dr3,dc3,dy3,do3))/entropy(prob_density(dc3))
print "H(dC|dR,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dr3,dc3,do3))/entropy(prob_density(dr3))
print "H(dC|dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dy3,dc3,do3))/entropy(prob_density(dr3))
print "H(dC|dlogOD) / H(dC) = ", conditional_entropy(prob_density2d(do3,dc3))/entropy(prob_density(dr3))


print "H(dY|dC)/ H(dY) = ", conditional_entropy(prob_density2d(dc3,dy3))/entropy(prob_density(dy3))
print "H(dY|dR)/ H(dY) = ", conditional_entropy(prob_density2d(dr3,dy3))/entropy(prob_density(dy3))
print "H(dR|dC)/ H(dR) = ", conditional_entropy(prob_density2d(dc3,dr3))/entropy(prob_density(dr3))
print "H(dR|dY)/ H(dR) = ", conditional_entropy(prob_density2d(dy3,dr3))/entropy(prob_density(dr3))
print "H(dC|dY)/ H(dC) = ", conditional_entropy(prob_density2d(dy3,dc3))/entropy(prob_density(dc3))
print "H(dC|dR)/ H(dC) = ", conditional_entropy(prob_density2d(dr3,dc3))/entropy(prob_density(dc3))
# Out:
# J23106-J23107-J23101 Glucosa
# ---
# H(dY) =  3.38006
# H(dC) =  3.2576
# H(dR) =  3.60865
# H(dlogOD) =  4.09126
# ---
# H(dY|dlogOD) =  2.62221
# H(dC|dlogOD) =  2.36085
# H(dR|dlogOD) =  2.74353
# H(dY|dC) =  2.06593
# H(dY|dR) =  1.49379
# H(dR|dC) =  2.16883
# H(dR|dY) =  1.72238
# H(dC|dY) =  1.94346
# H(dC|dR) =  1.81777
# ---
# I(dlogOD,dC) =  0.896746
# I(dlogOD,dY) =  0.757851
# I(dlogOD,dR) =  0.865127
# I(dY,dC) =  1.31413
# I(dY,dR) =  1.88627
# I(dR,dC) =  1.43982
# ---
# H(dY|dC,dlogOD) =  1.24336
# H(dY|dR,dlogOD) =  0.909606
# H(dY|dC,dR) =  1.12476
# H(dY|dC,dR,dlogOD) =  0.581995
# H(dR|dC,dlogOD) =  1.31582
# H(dR|dY,dlogOD) =  1.03092
# H(dR|dC,dY) =  1.22766
# H(dR|dC,dY,dlogOD) =  0.654451
# H(dC|dY,dlogOD) =  0.982006
# H(dC|dR,dlogOD) =  0.933145
# H(dC|dY,dR) =  1.44875
# H(dC|dY,dR,dlogOD) =  0.605535
# ---
# H(dY|dC,dR,dlogOD) / H(dY) =  0.172185
# H(dY|dC,dlogOD) / H(dY) =  0.367853
# H(dY|dR,dlogOD) / H(dY) =  0.269109
# H(dY|dlogOD) / H(dY) =  0.775788
# ...

# %%
#Porcentajes respecto a entropía inicial
A5= (conditional_entropy(prob_density2d(dc3,dy3))/entropy(prob_density(dy3)))*100 #H(dY|dC)/ H(dY)
B5= (conditional_entropy(prob_density2d(dr3,dy3))/entropy(prob_density(dy3)))*100 #H(dY|dR)/ H(dY)
C5=(conditional_entropy(prob_density2d(do3,dy3))/entropy(prob_density(dy3)))*100 #H(dY|dlogOD) / H(dY)
D5=(conditional_entropy(prob_density3d(dr3,dy3,do3))/entropy(prob_density(dy3)))*100 #H(dY|dR,dlogOD) / H(dY)
E5=(conditional_entropy(prob_density3d(dc3,dy3,do3))/entropy(prob_density(dy3)))*100 #H(dY|dC,dlogOD) / H(dY)
F5=(conditional_entropy(prob_density3d(dc3,dy3,dr3))/entropy(prob_density(dy3)))*100#H(dY|dC,dR)/H(dY)
G5= (conditional_entropy(prob_density4d(dc3,dy3,dr3,do3))/entropy(prob_density(dy3)))*100 #H(dY|dC,dR,dlogOD) / H(dY)

ent_y5=[A5,B5,C5,D5,E5,F5,G5]

X = np.arange(8)
plt.figure()
plt.title('J23106-J23107-J23101 Glucosa 0,4%')
plt.ylabel('Porcentaje respecto a H(dY)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y5[0],color='y',width=0.25,zorder=3)
plt.bar(X[1],ent_y5[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],ent_y5[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],ent_y5[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],ent_y5[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],ent_y5[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],ent_y5[6],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY|dC)/ H(dY)',"H(dY|dR)/ H(dY)",'H(dY|dlogOD) / H(dY)',"H(dY|dR,dlogOD) / H(dY)",'H(dY|dC,dlogOD) / H(dY)','H(dY|dC,dR) / H(dY)',"H(dY|dC,dR,dlogOD) / H(dY)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y5):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hy 106-107 glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

A6= (conditional_entropy(prob_density2d(dc3,dr3))/entropy(prob_density(dr3)))*100 #H(dR|dC)/ H(dR)
B6= (conditional_entropy(prob_density2d(dy3,dr3))/entropy(prob_density(dr3)))*100 #H(dR|dY)/ H(dR)
C6=(conditional_entropy(prob_density2d(do3,dr3))/entropy(prob_density(dr3)))*100 #H(dR|dlogOD) / H(dR)
D6=(conditional_entropy(prob_density3d(dy3,dr3,do3))/entropy(prob_density(dr3)))*100 #H(dR|dY,dlogOD) / H(dR)
E6=(conditional_entropy(prob_density3d(dc3,dr3,do3))/entropy(prob_density(dr3)))*100 #H(dR|dC,dlogOD) / H(dR)
F6=(conditional_entropy(prob_density3d(dc3,dr3,dy3))/entropy(prob_density(dr3)))*100 #H(dR|dC,dY)
G6= (conditional_entropy(prob_density4d(dc3,dr3,dy3,do3))/entropy(prob_density(dr3)))*100 #H(dR|dC,dY,dlogOD) / H(dR)

ent_y6=[A6,B6,C6,D6,E6,F6,G6]

X = np.arange(8)
plt.figure()
plt.title('J23106-J23107-J23101 Glucosa 0,4%')
plt.ylabel('Porcentaje respecto a H(dR)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y6[0],color='r',width=0.25,zorder=3)
plt.bar(X[1],ent_y6[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],ent_y6[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],ent_y6[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],ent_y6[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],ent_y6[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],ent_y6[6],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR|dC)/ H(dR)',"H(dR|dY)/ H(dR)",'H(dR|dlogOD) / H(dR)',"H(dR|dY,dlogOD) / H(dR)",'H(dR|dC,dlogOD) / H(dR)','H(dR|dC,dY)/H(dR)',"H(dR|dC,dY,dlogOD) / H(dR)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y6):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hr 106-107 glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
#Porcentajes respecto a entropía inicial
hc3=entropy(prob_density(dc3))#H(dC)
ho3=entropy(prob_density(do3))#H(dlogOD)
hyo3=conditional_entropy(prob_density2d(do3,dy3))#H(dY|dlogOD)
hco3=conditional_entropy(prob_density2d(do3,dc3))#H(dC|dlogOD)
hro3=conditional_entropy(prob_density2d(do3,dr3))#H(dR|dlogOD)

hy3=entropy(prob_density(dy3))#H(dY)
hyc3=conditional_entropy(prob_density2d(dc3,dy3))#H(dY|dC)
hyr3=conditional_entropy(prob_density2d(dr3,dy3))#H(dY|dR)
hyco3=conditional_entropy(prob_density3d(dc3,dy3,do3))#H(dY|dC,dlogOD)
hyro3=conditional_entropy(prob_density3d(dr3,dy3,do3))#H(dY|dR,dlogOD)
hycr3= conditional_entropy(prob_density3d(dc3,dy3,dr3))#H(dY|dC,dR) 
hycro3=conditional_entropy(prob_density4d(dc3,dy3,dr3,do3))#H(dY|dC,dR,dlogOD)

hr3=entropy(prob_density(dr3))#H(dR)
hrc3= conditional_entropy(prob_density2d(dc3,dr3))#H(dR|dC)
hry3=conditional_entropy(prob_density2d(dy3,dr3))#H(dR|dY)
hrco3=conditional_entropy(prob_density3d(dc3,dr3,do3))#H(dR|dC,dlogOD)
hryo3=conditional_entropy(prob_density3d(dy3,dr3,do3))#H(dR|dY,dlogOD)
hrcy3= conditional_entropy(prob_density3d(dc3,dr3,dy3))#H(dR|dC,dY)
hrcyo3=conditional_entropy(prob_density4d(dc3,dr3,dy3,do3))#H(dR|dC,dY,dlogOD)

hc3=entropy(prob_density(dc3))#H(dC)
hcy3=conditional_entropy(prob_density2d(dy3,dc3))#H(dC|dY)
hcr3=conditional_entropy(prob_density2d(dr3,dc3))#H(dC|dR)
hcyo3=conditional_entropy(prob_density3d(dy3,dc3,do3))#H(dC|dY,dlogOD)
hcro3=conditional_entropy(prob_density3d(dr3,dc3,do3))#H(dC|dR,dlogOD)
hcyr3=conditional_entropy(prob_density3d(dy3,dc3,dr3))#H(dC|dY,dR)
hcyro3=conditional_entropy(prob_density4d(dy3,dc3,dr3,do3))#H(dC|dY,dR,dlogOD)
soloc3=[hc3,hcy3,hcr3,hcyo3,hcro3,hcyr3,hycro3]

soloh3=[hr3,hy3,hc3,ho3]
hod3=[hr3,hro3,hy3,hyo3,hc3,hco3]
soloy3=[hy3,hyc3,hyr3,hyo3,hyco3,hyro3,hycr3,hycro3]
solor3=[hr3,hrc3,hry3,hro3,hrco3,hryo3,hrcy3,hrcyo3]


X = np.arange(4)
plt.figure()
plt.title('J23106-J23107-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloh3[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],soloh3[1],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[2],soloh3[2],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[3],soloh3[3],color='g',width=0.25,label='H(dlogOD)',zorder=3)
plt.xticks(X, ['H(dR)',"H(dY)",'H(dC)',"H(dlogOD)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloh3):
    plt.text(a-0.15,b+0.2,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='h 106-107 glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)


X = np.arange(7)
plt.figure()
plt.title('J23106-J23107-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],hod3[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],hod3[1],color='coral',width=0.25,label='H(dR)|dlogOD',zorder=3)
plt.bar(X[2],hod3[2],color='gold',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[3],hod3[3],color='y',width=0.25,label='H(dY)|dlogOD',zorder=3)
plt.bar(X[4],hod3[4],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[5],hod3[5],color='skyblue',width=0.25,label='H(dC)|dlogOD',zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dlogOD)","H(dY)",'H(dY|dlogOD)','H(dC)',"H(dC|dlogOD) "],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,hod3):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='ho 106-107 glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
soloy3=[hy3,hyc3,hyr3,hyo3,hyco3,hyro3,hycr3,hycro3]
solor3=[hr3,hrc3,hry3,hro3,hrco3,hryo3,hrcy3,hrcyo3]


X = np.arange(9)
plt.figure()
plt.title('J23106-J23107-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloy3[0],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[1],soloy3[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],soloy3[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],soloy3[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],soloy3[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],soloy3[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],soloy3[6],color='y',width=0.25,zorder=3)
plt.bar(X[7],soloy3[7],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY)',"H(dY|dC)",'H(dY|dR)','H(dY|dlogOD)',"H(dY|dC,dlogOD)",'H(dY|dR,dlogOD)',"H(dY|dC,dR)",'H(dY|dC,dR,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloy3):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hy 106-107 glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

X = np.arange(9)
plt.figure()
plt.title('J23106-J23107-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],solor3[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],solor3[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],solor3[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],solor3[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],solor3[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],solor3[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],solor3[6],color='r',width=0.25,zorder=3)
plt.bar(X[7],solor3[7],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dC)",'H(dR|dY)','H(dR|dlogOD)',"H(dR|dC,dlogOD)",'H(dR|dY,dlogOD)',"H(dR|dC,dY)",'H(dR|dC,dY,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,solor3):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hr 106-107 glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
print "J23106-J23107-J23101 Glicerol"
print "---"
print "H(dY) = ", entropy(prob_density(dy4))
print "H(dC) = ", entropy(prob_density(dc4))
print "H(dR) = ", entropy(prob_density(dr4))
print "H(dlogOD) = ", entropy(prob_density(do4))

print "---"
print "H(dY|dlogOD) = ", conditional_entropy(prob_density2d(do4,dy4))
print "H(dC|dlogOD) = ", conditional_entropy(prob_density2d(do4,dc4))
print "H(dR|dlogOD) = ", conditional_entropy(prob_density2d(do4,dr4))
print "H(dY|dC) = ", conditional_entropy(prob_density2d(dc4,dy4))
print "H(dY|dR) = ", conditional_entropy(prob_density2d(dr4,dy4))
print "H(dR|dC) = ", conditional_entropy(prob_density2d(dc4,dr4))
print "H(dR|dY) = ", conditional_entropy(prob_density2d(dy4,dr4))
print "H(dC|dY) = ", conditional_entropy(prob_density2d(dy4,dc4))
print "H(dC|dR) = ", conditional_entropy(prob_density2d(dr4,dc4))

print "---"
print "I(dlogOD,dC) = ", mutual_information(prob_density2d(do4,dc4))
print "I(dlogOD,dY) = ", mutual_information(prob_density2d(do4,dy4))
print "I(dlogOD,dR) = ", mutual_information(prob_density2d(do4,dr4))
print "I(dY,dC) = ", mutual_information(prob_density2d(dc4,dy4))
print "I(dY,dR) = ", mutual_information(prob_density2d(dr4,dy4))
print "I(dR,dC) = ", mutual_information(prob_density2d(dc4,dr4))


print "---"
print "H(dY|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc4,dy4,do4))
print "H(dY|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr4,dy4,do4))
print "H(dY|dC,dR) = ", conditional_entropy(prob_density3d(dc4,dy4,dr4))
print "H(dY|dC,dR,dlogOD) = ", conditional_entropy(prob_density4d(dc4,dy4,dr4,do4))
print "H(dR|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc4,dr4,do4))
print "H(dR|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy4,dr4,do4))
print "H(dR|dC,dY) = ", conditional_entropy(prob_density3d(dc4,dr4,dy4))
print "H(dR|dC,dY,dlogOD) = ", conditional_entropy(prob_density4d(dc4,dr4,dy4,do4))
print "H(dC|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy4,dc4,do4))
print "H(dC|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr4,dc4,do4))
print "H(dC|dY,dR) = ", conditional_entropy(prob_density3d(dy4,dc4,dr4))
print "H(dC|dY,dR,dlogOD) = ", conditional_entropy(prob_density4d(dy4,dc4,dr4,do4))

print "---"
print "H(dY|dC,dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density4d(dc4,dy4,dr4,do4))/entropy(prob_density(dy4))
print "H(dY|dC,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dc4,dy4,do4))/entropy(prob_density(dy4))
print "H(dY|dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dr4,dy4,do4))/entropy(prob_density(dy4))
print "H(dY|dlogOD) / H(dY) = ", conditional_entropy(prob_density2d(do4,dy4))/entropy(prob_density(dy4))
print "H(dR|dC,dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density4d(dc4,dr4,dy4,do4))/entropy(prob_density(dr4))
print "H(dR|dC,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dc4,dr4,do4))/entropy(prob_density(dr4))
print "H(dR|dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dy4,dr4,do4))/entropy(prob_density(dr4))
print "H(dR|dlogOD) / H(dR) = ", conditional_entropy(prob_density2d(do4,dr4))/entropy(prob_density(dr4))
print "H(dC|dR,dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density4d(dr4,dc4,dy4,do4))/entropy(prob_density(dc4))
print "H(dC|dR,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dr4,dc4,do4))/entropy(prob_density(dr4))
print "H(dC|dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dy4,dc4,do4))/entropy(prob_density(dr4))
print "H(dC|dlogOD) / H(dC) = ", conditional_entropy(prob_density2d(do4,dc4))/entropy(prob_density(dr4))


print "H(dY|dC)/ H(dY) = ", conditional_entropy(prob_density2d(dc4,dy4))/entropy(prob_density(dy4))
print "H(dY|dR)/ H(dY) = ", conditional_entropy(prob_density2d(dr4,dy4))/entropy(prob_density(dy4))
print "H(dR|dC)/ H(dR) = ", conditional_entropy(prob_density2d(dc4,dr4))/entropy(prob_density(dr4))
print "H(dR|dY)/ H(dR) = ", conditional_entropy(prob_density2d(dy4,dr4))/entropy(prob_density(dr4))
print "H(dC|dY)/ H(dC) = ", conditional_entropy(prob_density2d(dy4,dc4))/entropy(prob_density(dc4))
print "H(dC|dR)/ H(dC) = ", conditional_entropy(prob_density2d(dr4,dc4))/entropy(prob_density(dc4))
# Out:
# J23106-J23107-J23101 Glicerol
# ---
# H(dY) =  3.8549
# H(dC) =  3.40914
# H(dR) =  3.42622
# H(dlogOD) =  3.84202
# ---
# H(dY|dlogOD) =  2.99215
# H(dC|dlogOD) =  2.44249
# H(dR|dlogOD) =  2.60861
# H(dY|dC) =  2.44563
# H(dY|dR) =  1.89268
# H(dR|dC) =  2.21911
# H(dR|dY) =  1.464
# H(dC|dY) =  1.99987
# H(dC|dR) =  2.20202
# ---
# I(dlogOD,dC) =  0.966645
# I(dlogOD,dY) =  0.86275
# I(dlogOD,dR) =  0.817615
# I(dY,dC) =  1.40927
# I(dY,dR) =  1.96222
# I(dR,dC) =  1.20711
# ---
# H(dY|dC,dlogOD) =  1.56991
# H(dY|dR,dlogOD) =  1.14375
# H(dY|dC,dR) =  1.16168
# H(dY|dC,dR,dlogOD) =  0.650578
# H(dR|dC,dlogOD) =  1.36142
# H(dR|dY,dlogOD) =  0.76021
# H(dR|dC,dY) =  0.935155
# H(dR|dC,dY,dlogOD) =  0.442088
# H(dC|dY,dlogOD) =  1.02025
# H(dC|dR,dlogOD) =  1.19531
# H(dC|dY,dR) =  1.47103
# H(dC|dY,dR,dlogOD) =  0.702132
# ---
# H(dY|dC,dR,dlogOD) / H(dY) =  0.168766
# H(dY|dC,dlogOD) / H(dY) =  0.407251
# H(dY|dR,dlogOD) / H(dY) =  0.296701
# H(dY|dlogOD) / H(dY) =  0.776194
# ...

# %%
#Porcentajes respecto a entropía inicial
A7= (conditional_entropy(prob_density2d(dc4,dy4))/entropy(prob_density(dy4)))*100 #H(dY|dC)/ H(dY)
B7= (conditional_entropy(prob_density2d(dr4,dy4))/entropy(prob_density(dy4)))*100 #H(dY|dR)/ H(dY)
C7=(conditional_entropy(prob_density2d(do4,dy4))/entropy(prob_density(dy4)))*100 #H(dY|dlogOD) / H(dY)
D7=(conditional_entropy(prob_density3d(dr4,dy4,do4))/entropy(prob_density(dy4)))*100 #H(dY|dR,dlogOD) / H(dY)
E7=(conditional_entropy(prob_density3d(dc4,dy4,do4))/entropy(prob_density(dy4)))*100 #H(dY|dC,dlogOD) / H(dY)
F7=(conditional_entropy(prob_density3d(dc4,dy4,dr4))/entropy(prob_density(dy4)))*100#H(dY|dC,dR)/H(dY)
G7=(conditional_entropy(prob_density4d(dc4,dy4,dr4,do4))/entropy(prob_density(dy4)))*100 #H(dY|dC,dR,dlogOD) / H(dY)

ent_y7=[A7,B7,C7,D7,E7,F7,G7]

X = np.arange(8)
plt.figure()
plt.title('J23106-J23107-J23101 Glicerol 0,2%')
plt.ylabel('Porcentaje respecto a H(dY)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y7[0],color='y',width=0.25,zorder=3)
plt.bar(X[1],ent_y7[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],ent_y7[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],ent_y7[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],ent_y7[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],ent_y7[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],ent_y7[6],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY|dC)/ H(dY)',"H(dY|dR)/ H(dY)",'H(dY|dlogOD) / H(dY)',"H(dY|dR,dlogOD) / H(dY)",'H(dY|dC,dlogOD) / H(dY)','H(dY|dC,dR) / H(dY)',"H(dY|dC,dR,dlogOD) / H(dY)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y7):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hy 106-107 gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

A8= (conditional_entropy(prob_density2d(dc4,dr4))/entropy(prob_density(dr4)))*100 #H(dR|dC)/ H(dR)
B8= (conditional_entropy(prob_density2d(dy4,dr4))/entropy(prob_density(dr4)))*100 #H(dR|dY)/ H(dR)
C8=(conditional_entropy(prob_density2d(do4,dr4))/entropy(prob_density(dr4)))*100 #H(dR|dlogOD) / H(dR)
D8=(conditional_entropy(prob_density3d(dy4,dr4,do4))/entropy(prob_density(dr4)))*100 #H(dR|dY,dlogOD) / H(dR)
E8=(conditional_entropy(prob_density3d(dc4,dr4,do4))/entropy(prob_density(dr4)))*100 #H(dR|dC,dlogOD) / H(dR)
F8=(conditional_entropy(prob_density3d(dc4,dr4,dy4))/entropy(prob_density(dr4)))*100 #H(dR|dC,dY)
G8= (conditional_entropy(prob_density4d(dc4,dr4,dy4,do4))/entropy(prob_density(dr4)))*100 #H(dR|dC,dY,dlogOD) / H(dR)

ent_y8=[A8,B8,C8,D8,E8,F8,G8]

X = np.arange(8)
plt.figure()
plt.title('J23106-J23107-J23101 Glicerol 0,2%')
plt.ylabel('Porcentaje respecto a H(dR)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y8[0],color='r',width=0.25,zorder=3)
plt.bar(X[1],ent_y8[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],ent_y8[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],ent_y8[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],ent_y8[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],ent_y8[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],ent_y8[6],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR|dC)/ H(dR)',"H(dR|dY)/ H(dR)",'H(dR|dlogOD) / H(dR)',"H(dR|dY,dlogOD) / H(dR)",'H(dR|dC,dlogOD) / H(dR)','H(dR|dC,dY)/H(dR)',"H(dR|dC,dY,dlogOD) / H(dR)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y8):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hr 106-107 gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
#Porcentajes respecto a entropía inicial
hc4=entropy(prob_density(dc4))#H(dC)
ho4=entropy(prob_density(do4))#H(dlogOD)
hyo4=conditional_entropy(prob_density2d(do4,dy4))#H(dY|dlogOD)
hco4=conditional_entropy(prob_density2d(do4,dc4))#H(dC|dlogOD)
hro4=conditional_entropy(prob_density2d(do4,dr4))#H(dR|dlogOD)

hy4=entropy(prob_density(dy4))#H(dY)
hyc4=conditional_entropy(prob_density2d(dc4,dy4))#H(dY|dC)
hyr4=conditional_entropy(prob_density2d(dr4,dy4))#H(dY|dR)
hyco4=conditional_entropy(prob_density3d(dc4,dy4,do4))#H(dY|dC,dlogOD)
hyro4=conditional_entropy(prob_density3d(dr4,dy4,do4))#H(dY|dR,dlogOD)
hycr4= conditional_entropy(prob_density3d(dc4,dy4,dr4))#H(dY|dC,dR) 
hycro4=conditional_entropy(prob_density4d(dc4,dy4,dr4,do4))#H(dY|dC,dR,dlogOD)

hr4=entropy(prob_density(dr4))#H(dR)
hrc4= conditional_entropy(prob_density2d(dc4,dr4))#H(dR|dC)
hry4=conditional_entropy(prob_density2d(dy4,dr4))#H(dR|dY)
hrco4=conditional_entropy(prob_density3d(dc4,dr4,do4))#H(dR|dC,dlogOD)
hryo4=conditional_entropy(prob_density3d(dy4,dr4,do4))#H(dR|dY,dlogOD)
hrcy4= conditional_entropy(prob_density3d(dc4,dr4,dy4))#H(dR|dC,dY)
hrcyo4=conditional_entropy(prob_density4d(dc4,dr4,dy4,do4))#H(dR|dC,dY,dlogOD)

hc4=entropy(prob_density(dc4))#H(dC)
hcy4=conditional_entropy(prob_density2d(dy4,dc4))#H(dC|dY)
hcr4=conditional_entropy(prob_density2d(dr4,dc4))#H(dC|dR)
hcyo4=conditional_entropy(prob_density3d(dy4,dc4,do4))#H(dC|dY,dlogOD)
hcro4=conditional_entropy(prob_density3d(dr4,dc4,do4))#H(dC|dR,dlogOD)
hcyr4=conditional_entropy(prob_density3d(dy4,dc4,dr4))#H(dC|dY,dR)
hcyro4=conditional_entropy(prob_density4d(dy4,dc4,dr4,do4))#H(dC|dY,dR,dlogOD)
soloc4=[hc4,hcy4,hcr4,hcyo4,hcro4,hcyr4,hycro4]

soloh4=[hr4,hy4,hc4,ho4]
hod4=[hr4,hro4,hy4,hyo4,hc4,hco4]
soloy4=[hy4,hyc4,hyr4,hyo4,hyco4,hyro4,hycr4,hycro4]
solor4=[hr4,hrc4,hry4,hro4,hrco4,hryo4,hrcy4,hrcyo4]


X = np.arange(4)
plt.figure()
plt.title('J23106-J23107-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloh4[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],soloh4[1],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[2],soloh4[2],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[3],soloh4[3],color='g',width=0.25,label='H(dlogOD)',zorder=3)
plt.xticks(X, ['H(dR)',"H(dY)",'H(dC)',"H(dlogOD)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloh4):
    plt.text(a-0.15,b+0.2,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='h 106-107 gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)


X = np.arange(7)
plt.figure()
plt.title('J23106-J23107-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],hod4[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],hod4[1],color='coral',width=0.25,label='H(dR)|dlogOD',zorder=3)
plt.bar(X[2],hod4[2],color='gold',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[3],hod4[3],color='y',width=0.25,label='H(dY)|dlogOD',zorder=3)
plt.bar(X[4],hod4[4],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[5],hod4[5],color='skyblue',width=0.25,label='H(dC)|dlogOD',zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dlogOD)","H(dY)",'H(dY|dlogOD)','H(dC)',"H(dC|dlogOD) "],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,hod4):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='ho 106-107 gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
soloy4=[hy4,hyc4,hyr4,hyo4,hyco4,hyro4,hycr4,hycro4]
solor4=[hr4,hrc4,hry4,hro4,hrco4,hryo4,hrcy4,hrcyo4]


X = np.arange(9)
plt.figure()
plt.title('J23106-J23107-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloy4[0],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[1],soloy4[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],soloy4[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],soloy4[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],soloy4[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],soloy4[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],soloy4[6],color='y',width=0.25,zorder=3)
plt.bar(X[7],soloy4[7],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY)',"H(dY|dC)",'H(dY|dR)','H(dY|dlogOD)',"H(dY|dC,dlogOD)",'H(dY|dR,dlogOD)',"H(dY|dC,dR)",'H(dY|dC,dR,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloy4):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hy 106-107 gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

X = np.arange(9)
plt.figure()
plt.title('J23106-J23107-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],solor4[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],solor4[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],solor4[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],solor4[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],solor4[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],solor4[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],solor4[6],color='r',width=0.25,zorder=3)
plt.bar(X[7],solor4[7],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dC)",'H(dR|dY)','H(dR|dlogOD)',"H(dR|dC,dlogOD)",'H(dR|dY,dlogOD)',"H(dR|dC,dY)",'H(dR|dC,dY,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,solor4):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hr 106-107 gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
print "J23106-pLacI-J23101 Glucosa"
print "---"
print "H(dY) = ", entropy(prob_density(dy5))
print "H(dC) = ", entropy(prob_density(dc5))
print "H(dR) = ", entropy(prob_density(dr5))
print "H(dlogOD) = ", entropy(prob_density(do5))

print "---"
print "H(dY|dlogOD) = ", conditional_entropy(prob_density2d(do5,dy5))
print "H(dC|dlogOD) = ", conditional_entropy(prob_density2d(do5,dc5))
print "H(dR|dlogOD) = ", conditional_entropy(prob_density2d(do5,dr5))
print "H(dY|dC) = ", conditional_entropy(prob_density2d(dc5,dy5))
print "H(dY|dR) = ", conditional_entropy(prob_density2d(dr5,dy5))
print "H(dR|dC) = ", conditional_entropy(prob_density2d(dc5,dr5))
print "H(dR|dY) = ", conditional_entropy(prob_density2d(dy5,dr5))
print "H(dC|dY) = ", conditional_entropy(prob_density2d(dy5,dc5))
print "H(dC|dR) = ", conditional_entropy(prob_density2d(dr5,dc5))


print "---"
print "I(dlogOD,dC) = ", mutual_information(prob_density2d(do5,dc5))
print "I(dlogOD,dY) = ", mutual_information(prob_density2d(do5,dy5))
print "I(dlogOD,dR) = ", mutual_information(prob_density2d(do5,dr5))
print "I(dY,dC) = ", mutual_information(prob_density2d(dc5,dy5))
print "I(dY,dR) = ", mutual_information(prob_density2d(dr5,dy5))
print "I(dR,dC) = ", mutual_information(prob_density2d(dc5,dr5))

print "---"
print "H(dY|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc5,dy5,do5))
print "H(dY|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr5,dy5,do5))
print "H(dY|dC,dR) = ", conditional_entropy(prob_density3d(dc5,dy5,dr5))
print "H(dY|dC,dR,dlogOD) = ", conditional_entropy(prob_density4d(dc5,dy5,dr5,do5))
print "H(dR|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc5,dr5,do5))
print "H(dR|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy5,dr5,do5))
print "H(dR|dC,dY) = ", conditional_entropy(prob_density3d(dc5,dr5,dy5))
print "H(dR|dC,dY,dlogOD) = ", conditional_entropy(prob_density4d(dc5,dr5,dy5,do5))
print "H(dC|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy5,dc5,do5))
print "H(dC|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr5,dc5,do5))
print "H(dC|dY,dR) = ", conditional_entropy(prob_density3d(dy5,dc5,dr5))
print "H(dC|dY,dR,dlogOD) = ", conditional_entropy(prob_density4d(dy5,dc5,dr5,do5))

print "---"
print "H(dY|dC,dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density4d(dc5,dy5,dr5,do5))/entropy(prob_density(dy5))
print "H(dY|dC,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dc5,dy5,do5))/entropy(prob_density(dy5))
print "H(dY|dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dr5,dy5,do5))/entropy(prob_density(dy5))
print "H(dY|dlogOD) / H(dY) = ", conditional_entropy(prob_density2d(do5,dy5))/entropy(prob_density(dy5))
print "H(dR|dC,dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density4d(dc5,dr5,dy5,do5))/entropy(prob_density(dr5))
print "H(dR|dC,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dc5,dr5,do5))/entropy(prob_density(dr5))
print "H(dR|dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dy5,dr5,do5))/entropy(prob_density(dr5))
print "H(dR|dlogOD) / H(dR) = ", conditional_entropy(prob_density2d(do5,dr5))/entropy(prob_density(dr5))
print "H(dC|dR,dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density4d(dr5,dc5,dy5,do5))/entropy(prob_density(dc5))
print "H(dC|dR,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dr5,dc5,do5))/entropy(prob_density(dr5))
print "H(dC|dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dy5,dc5,do5))/entropy(prob_density(dr5))
print "H(dC|dlogOD) / H(dC) = ", conditional_entropy(prob_density2d(do5,dc5))/entropy(prob_density(dr5))

print "H(dY|dC)/ H(dY) = ", conditional_entropy(prob_density2d(dc5,dy5))/entropy(prob_density(dy5))
print "H(dY|dR)/ H(dY) = ", conditional_entropy(prob_density2d(dr5,dy5))/entropy(prob_density(dy5))
print "H(dR|dC)/ H(dR) = ", conditional_entropy(prob_density2d(dc5,dr5))/entropy(prob_density(dr5))
print "H(dR|dY)/ H(dR) = ", conditional_entropy(prob_density2d(dy5,dr5))/entropy(prob_density(dr5))
print "H(dC|dY)/ H(dC) = ", conditional_entropy(prob_density2d(dy5,dc5))/entropy(prob_density(dc5))
print "H(dC|dR)/ H(dC) = ", conditional_entropy(prob_density2d(dr5,dc5))/entropy(prob_density(dc5))
# Out:
# J23106-pLacI-J23101 Glucosa
# ---
# H(dY) =  3.47285
# H(dC) =  3.32839
# H(dR) =  3.65592
# H(dlogOD) =  4.22719
# ---
# H(dY|dlogOD) =  2.64674
# H(dC|dlogOD) =  2.52327
# H(dR|dlogOD) =  2.82797
# H(dY|dC) =  2.2122
# H(dY|dR) =  1.91256
# H(dR|dC) =  1.97385
# H(dR|dY) =  2.09563
# H(dC|dY) =  2.06773
# H(dC|dR) =  1.64632
# ---
# I(dlogOD,dC) =  0.805117
# I(dlogOD,dY) =  0.826118
# I(dlogOD,dR) =  0.827957
# I(dY,dC) =  1.26065
# I(dY,dR) =  1.56029
# I(dR,dC) =  1.68208
# ---
# H(dY|dC,dlogOD) =  1.28577
# H(dY|dR,dlogOD) =  1.05076
# H(dY|dC,dR) =  1.45739
# H(dY|dC,dR,dlogOD) =  0.673397
# H(dR|dC,dlogOD) =  1.24775
# H(dR|dY,dlogOD) =  1.23199
# H(dR|dC,dY) =  1.21903
# H(dR|dC,dY,dlogOD) =  0.635377
# H(dC|dY,dlogOD) =  1.1623
# H(dC|dR,dlogOD) =  0.943054
# H(dC|dY,dR) =  1.19114
# H(dC|dY,dR,dlogOD) =  0.565694
# ---
# H(dY|dC,dR,dlogOD) / H(dY) =  0.193903
# H(dY|dC,dlogOD) / H(dY) =  0.370234
# H(dY|dR,dlogOD) / H(dY) =  0.302563
# H(dY|dlogOD) / H(dY) =  0.762121
# ...

# %%
#Porcentajes respecto a entropía inicial
A9= (conditional_entropy(prob_density2d(dc5,dy5))/entropy(prob_density(dy5)))*100 #H(dY|dC)/ H(dY)
B9= (conditional_entropy(prob_density2d(dr5,dy5))/entropy(prob_density(dy5)))*100 #H(dY|dR)/ H(dY)
C9=(conditional_entropy(prob_density2d(do5,dy5))/entropy(prob_density(dy5)))*100 #H(dY|dlogOD) / H(dY)
D9=(conditional_entropy(prob_density3d(dr5,dy5,do5))/entropy(prob_density(dy5)))*100 #H(dY|dR,dlogOD) / H(dY)
E9=(conditional_entropy(prob_density3d(dc5,dy5,do5))/entropy(prob_density(dy5)))*100 #H(dY|dC,dlogOD) / H(dY)
F9=(conditional_entropy(prob_density3d(dc5,dy5,dr5))/entropy(prob_density(dy5)))*100#H(dY|dC,dR)/H(dY)
G9= (conditional_entropy(prob_density4d(dc5,dy5,dr5,do5))/entropy(prob_density(dy5)))*100 #H(dY|dC,dR,dlogOD) / H(dY)

ent_y9=[A9,B9,C9,D9,E9,F9,G9]

X = np.arange(8)
plt.figure()
plt.title('J23106-pLacI-J23101 Glucosa 0,4%')
plt.ylabel('Porcentaje respecto a H(dY)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y9[0],color='y',width=0.25,zorder=3)
plt.bar(X[1],ent_y9[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],ent_y9[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],ent_y9[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],ent_y9[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],ent_y9[5],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY|dC)/ H(dY)',"H(dY|dR)/ H(dY)",'H(dY|dlogOD) / H(dY)',"H(dY|dR,dlogOD) / H(dY)",'H(dY|dC,dlogOD) / H(dY)',"H(dY|dC,dR,dlogOD) / H(dY)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y9):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hy 106-plac glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

A10= (conditional_entropy(prob_density2d(dc5,dr5))/entropy(prob_density(dr5)))*100 #H(dR|dC)/ H(dR)
B10= (conditional_entropy(prob_density2d(dy5,dr5))/entropy(prob_density(dr5)))*100 #H(dR|dY)/ H(dR)
C10=(conditional_entropy(prob_density2d(do5,dr5))/entropy(prob_density(dr5)))*100 #H(dR|dlogOD) / H(dR)
D10=(conditional_entropy(prob_density3d(dy5,dr5,do5))/entropy(prob_density(dr5)))*100 #H(dR|dY,dlogOD) / H(dR)
E10=(conditional_entropy(prob_density3d(dc5,dr5,do5))/entropy(prob_density(dr5)))*100 #H(dR|dC,dlogOD) / H(dR)
F10=(conditional_entropy(prob_density3d(dc5,dr5,dy5))/entropy(prob_density(dr5)))*100 #H(dR|dC,dY)
G10= (conditional_entropy(prob_density4d(dc5,dr5,dy5,do5))/entropy(prob_density(dr5)))*100 #H(dR|dC,dY,dlogOD) / H(dR)

ent_y10=[A10,B10,C10,D10,E10,F10,G10]

X = np.arange(8)
plt.figure()
plt.title('J23106-pLacI-J23101 Glucosa 0,4%')
plt.ylabel('Porcentaje respecto a H(dR)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y10[0],color='r',width=0.25,zorder=3)
plt.bar(X[1],ent_y10[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],ent_y10[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],ent_y10[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],ent_y10[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],ent_y10[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],ent_y10[6],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR|dC)/ H(dR)',"H(dR|dY)/ H(dR)",'H(dR|dlogOD) / H(dR)',"H(dR|dY,dlogOD) / H(dR)",'H(dR|dC,dlogOD) / H(dR)','H(dR|dC,dY)/H(dR)',"H(dR|dC,dY,dlogOD) / H(dR)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y10):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hr plux-plac glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
#Porcentajes respecto a entropía inicial
hc5=entropy(prob_density(dc5))#H(dC)
ho5=entropy(prob_density(do5))#H(dlogOD)
hyo5=conditional_entropy(prob_density2d(do5,dy5))#H(dY|dlogOD)
hco5=conditional_entropy(prob_density2d(do5,dc5))#H(dC|dlogOD)
hro5=conditional_entropy(prob_density2d(do5,dr5))#H(dR|dlogOD)

hy5=entropy(prob_density(dy5))#H(dY)
hyc5=conditional_entropy(prob_density2d(dc5,dy5))#H(dY|dC)
hyr5=conditional_entropy(prob_density2d(dr5,dy5))#H(dY|dR)
hyco5=conditional_entropy(prob_density3d(dc5,dy5,do5))#H(dY|dC,dlogOD)
hyro5=conditional_entropy(prob_density3d(dr5,dy5,do5))#H(dY|dR,dlogOD)
hycr5= conditional_entropy(prob_density3d(dc5,dy5,dr5))#H(dY|dC,dR) 
hycro5=conditional_entropy(prob_density4d(dc5,dy5,dr5,do5))#H(dY|dC,dR,dlogOD)

hr5=entropy(prob_density(dr5))#H(dR)
hrc5= conditional_entropy(prob_density2d(dc5,dr5))#H(dR|dC)
hry5=conditional_entropy(prob_density2d(dy5,dr5))#H(dR|dY)
hrco5=conditional_entropy(prob_density3d(dc5,dr5,do5))#H(dR|dC,dlogOD)
hryo5=conditional_entropy(prob_density3d(dy5,dr5,do5))#H(dR|dY,dlogOD)
hrcy5= conditional_entropy(prob_density3d(dc5,dr5,dy5))#H(dR|dC,dY)
hrcyo5=conditional_entropy(prob_density4d(dc5,dr5,dy5,do5))#H(dR|dC,dY,dlogOD)

hc5=entropy(prob_density(dc5))#H(dC)
hcy5=conditional_entropy(prob_density2d(dy5,dc5))#H(dC|dY)
hcr5=conditional_entropy(prob_density2d(dr5,dc5))#H(dC|dR)
hcyo5=conditional_entropy(prob_density3d(dy5,dc5,do5))#H(dC|dY,dlogOD)
hcro5=conditional_entropy(prob_density3d(dr5,dc5,do5))#H(dC|dR,dlogOD)
hcyr5=conditional_entropy(prob_density3d(dy5,dc5,dr5))#H(dC|dY,dR)
hcyro5=conditional_entropy(prob_density4d(dy5,dc5,dr5,do5))#H(dC|dY,dR,dlogOD)
soloc5=[hc5,hcy5,hcr5,hcyo5,hcro5,hcyr5,hycro5]


soloh5=[hr5,hy5,hc5,ho5]
hod5=[hr5,hro5,hy5,hyo5,hc5,hco5]
soloy5=[hy5,hyc5,hyr5,hyo5,hyco5,hyro5,hycr5,hycro5]
solor5=[hr5,hrc5,hry5,hro5,hrco5,hryo5,hrcy5,hrcyo5]


X = np.arange(4)
plt.figure()
plt.title('J23106-pLacI-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloh5[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],soloh5[1],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[2],soloh5[2],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[3],soloh5[3],color='g',width=0.25,label='H(dlogOD)',zorder=3)
plt.xticks(X, ['H(dR)',"H(dY)",'H(dC)',"H(dlogOD)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloh5):
    plt.text(a-0.15,b+0.2,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='h 106-plac glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)


X = np.arange(7)
plt.figure()
plt.title('J23106-pLacI-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],hod5[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],hod5[1],color='coral',width=0.25,label='H(dR)|dlogOD',zorder=3)
plt.bar(X[2],hod5[2],color='gold',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[3],hod5[3],color='y',width=0.25,label='H(dY)|dlogOD',zorder=3)
plt.bar(X[4],hod5[4],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[5],hod5[5],color='skyblue',width=0.25,label='H(dC)|dlogOD',zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dlogOD)","H(dY)",'H(dY|dlogOD)','H(dC)',"H(dC|dlogOD) "],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,hod5):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='ho 106-plac glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
X = np.arange(9)
plt.figure()
plt.title('J23106-pLacI-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloy5[0],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[1],soloy5[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],soloy5[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],soloy5[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],soloy5[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],soloy5[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],soloy5[6],color='y',width=0.25,zorder=3)
plt.bar(X[7],soloy5[7],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY)',"H(dY|dC)",'H(dY|dR)','H(dY|dlogOD)',"H(dY|dC,dlogOD)",'H(dY|dR,dlogOD)',"H(dY|dC,dR)",'H(dY|dC,dR,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloy5):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hy 106-plac glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

X = np.arange(9)
plt.figure()
plt.title('J23106-pLacI-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],solor5[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],solor5[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],solor5[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],solor5[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],solor5[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],solor5[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],solor5[6],color='r',width=0.25,zorder=3)
plt.bar(X[7],solor5[7],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dC)",'H(dR|dY)','H(dR|dlogOD)',"H(dR|dC,dlogOD)",'H(dR|dY,dlogOD)',"H(dR|dC,dY)",'H(dR|dC,dY,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,solor5):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hr 106-plac glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
print "J23106-pLacI-J23101 Glicerol"
print "---"
print "H(dY) = ", entropy(prob_density(dy6))
print "H(dC) = ", entropy(prob_density(dc6))
print "H(dR) = ", entropy(prob_density(dr6))
print "H(dlogOD) = ", entropy(prob_density(do6))

print "---"
print "H(dY|dlogOD) = ", conditional_entropy(prob_density2d(do6,dy6))
print "H(dC|dlogOD) = ", conditional_entropy(prob_density2d(do6,dc6))
print "H(dR|dlogOD) = ", conditional_entropy(prob_density2d(do6,dr6))
print "H(dY|dC) = ", conditional_entropy(prob_density2d(dc6,dy6))
print "H(dY|dR) = ", conditional_entropy(prob_density2d(dr6,dy6))
print "H(dR|dC) = ", conditional_entropy(prob_density2d(dc6,dr6))
print "H(dR|dY) = ", conditional_entropy(prob_density2d(dy6,dr6))
print "H(dC|dY) = ", conditional_entropy(prob_density2d(dy6,dc6))
print "H(dC|dR) = ", conditional_entropy(prob_density2d(dr6,dc6))


print "---"
print "I(dlogOD,dC) = ", mutual_information(prob_density2d(do6,dc6))
print "I(dlogOD,dY) = ", mutual_information(prob_density2d(do6,dy6))
print "I(dlogOD,dR) = ", mutual_information(prob_density2d(do6,dr6))
print "I(dY,dC) = ", mutual_information(prob_density2d(dc6,dy6))
print "I(dY,dR) = ", mutual_information(prob_density2d(dr6,dy6))
print "I(dR,dC) = ", mutual_information(prob_density2d(dc6,dr6))

print "---"
print "H(dY|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc6,dy6,do6))
print "H(dY|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr6,dy6,do6))
print "H(dY|dC,dR) = ", conditional_entropy(prob_density3d(dc6,dy6,dr6))
print "H(dY|dC,dR,dlogOD) = ", conditional_entropy(prob_density4d(dc6,dy6,dr6,do6))
print "H(dR|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc6,dr6,do6))
print "H(dR|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy6,dr6,do6))
print "H(dR|dC,dY) = ", conditional_entropy(prob_density3d(dc6,dr6,dy6))
print "H(dR|dC,dY,dlogOD) = ", conditional_entropy(prob_density4d(dc6,dr6,dy6,do6))
print "H(dC|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy6,dc6,do6))
print "H(dC|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr6,dc6,do6))
print "H(dC|dY,dR) = ", conditional_entropy(prob_density3d(dy6,dc6,dr6))
print "H(dC|dY,dR,dlogOD) = ", conditional_entropy(prob_density4d(dy6,dc6,dr6,do6))

print "---"
print "H(dY|dC,dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density4d(dc6,dy6,dr6,do6))/entropy(prob_density(dy6))
print "H(dY|dC,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dc6,dy6,do6))/entropy(prob_density(dy6))
print "H(dY|dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dr6,dy6,do6))/entropy(prob_density(dy6))
print "H(dY|dlogOD) / H(dY) = ", conditional_entropy(prob_density2d(do6,dy6))/entropy(prob_density(dy6))
print "H(dR|dC,dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density4d(dc6,dr6,dy6,do6))/entropy(prob_density(dr6))
print "H(dR|dC,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dc6,dr6,do6))/entropy(prob_density(dr6))
print "H(dR|dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dy6,dr6,do6))/entropy(prob_density(dr6))
print "H(dR|dlogOD) / H(dR) = ", conditional_entropy(prob_density2d(do6,dr6))/entropy(prob_density(dr6))
print "H(dC|dR,dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density4d(dr6,dc6,dy6,do6))/entropy(prob_density(dc6))
print "H(dC|dR,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dr6,dc6,do6))/entropy(prob_density(dr6))
print "H(dC|dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dy6,dc6,do6))/entropy(prob_density(dr6))
print "H(dC|dlogOD) / H(dC) = ", conditional_entropy(prob_density2d(do6,dc6))/entropy(prob_density(dr6))

print "H(dY|dC)/ H(dY) = ", conditional_entropy(prob_density2d(dc6,dy6))/entropy(prob_density(dy6))
print "H(dY|dR)/ H(dY) = ", conditional_entropy(prob_density2d(dr6,dy6))/entropy(prob_density(dy6))
print "H(dR|dC)/ H(dR) = ", conditional_entropy(prob_density2d(dc6,dr6))/entropy(prob_density(dr6))
print "H(dR|dY)/ H(dR) = ", conditional_entropy(prob_density2d(dy6,dr6))/entropy(prob_density(dr6))
print "H(dC|dY)/ H(dC) = ", conditional_entropy(prob_density2d(dy6,dc6))/entropy(prob_density(dc6))
print "H(dC|dR)/ H(dC) = ", conditional_entropy(prob_density2d(dr6,dc6))/entropy(prob_density(dc6))
# Out:
# J23106-pLacI-J23101 Glicerol
# ---
# H(dY) =  3.78984
# H(dC) =  1.90678
# H(dR) =  3.381
# H(dlogOD) =  4.03727
# ---
# H(dY|dlogOD) =  2.55456
# H(dC|dlogOD) =  1.31945
# H(dR|dlogOD) =  2.41274
# H(dY|dC) =  3.07655
# H(dY|dR) =  1.71218
# H(dR|dC) =  2.80514
# H(dR|dY) =  1.30334
# H(dC|dY) =  1.19348
# H(dC|dR) =  1.33092
# ---
# I(dlogOD,dC) =  0.587324
# I(dlogOD,dY) =  1.23529
# I(dlogOD,dR) =  0.968264
# I(dY,dC) =  0.713292
# I(dY,dR) =  2.07766
# I(dR,dC) =  0.575856
# ---
# H(dY|dC,dlogOD) =  1.95249
# H(dY|dR,dlogOD) =  0.843141
# H(dY|dC,dR) =  1.37169
# H(dY|dC,dR,dlogOD) =  0.603469
# H(dR|dC,dlogOD) =  1.88895
# H(dR|dY,dlogOD) =  0.701319
# H(dR|dC,dY) =  1.10028
# H(dR|dC,dY,dlogOD) =  0.539936
# H(dC|dY,dlogOD) =  0.717381
# H(dC|dR,dlogOD) =  0.795669
# H(dC|dY,dR) =  0.99043
# H(dC|dY,dR,dlogOD) =  0.555997
# ---
# H(dY|dC,dR,dlogOD) / H(dY) =  0.159233
# H(dY|dC,dlogOD) / H(dY) =  0.515189
# H(dY|dR,dlogOD) / H(dY) =  0.222474
# ...

# %%
#Porcentajes respecto a entropía inicial
A11= (conditional_entropy(prob_density2d(dc6,dy6))/entropy(prob_density(dy6)))*100 #H(dY|dC)/ H(dY)
B11= (conditional_entropy(prob_density2d(dr6,dy6))/entropy(prob_density(dy6)))*100 #H(dY|dR)/ H(dY)
C11=(conditional_entropy(prob_density2d(do6,dy6))/entropy(prob_density(dy6)))*100 #H(dY|dlogOD) / H(dY)
D11=(conditional_entropy(prob_density3d(dr6,dy6,do6))/entropy(prob_density(dy6)))*100 #H(dY|dR,dlogOD) / H(dY)
E11=(conditional_entropy(prob_density3d(dc6,dy6,do6))/entropy(prob_density(dy6)))*100 #H(dY|dC,dlogOD) / H(dY)
F11=(conditional_entropy(prob_density3d(dc6,dy6,dr6))/entropy(prob_density(dy6)))*100#H(dY|dC,dR)/H(dY)
G11=(conditional_entropy(prob_density4d(dc6,dy6,dr6,do6))/entropy(prob_density(dy6)))*100 #H(dY|dC,dR,dlogOD) / H(dY)

ent_y11=[A11,B11,C11,D11,E11,F11,G11]

X = np.arange(8)
plt.figure()
plt.title('J23106-pLacI-J23101 Glicerol 0,2%')
plt.ylabel('Porcentaje respecto a H(dY)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y11[0],color='y',width=0.25,zorder=3)
plt.bar(X[1],ent_y11[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],ent_y11[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],ent_y11[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],ent_y11[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],ent_y11[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],ent_y11[6],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY|dC)/ H(dY)',"H(dY|dR)/ H(dY)",'H(dY|dlogOD) / H(dY)',"H(dY|dR,dlogOD) / H(dY)",'H(dY|dC,dlogOD) / H(dY)','H(dY|dC,dR) / H(dY)',"H(dY|dC,dR,dlogOD) / H(dY)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y11):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hy 106-plac gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

A12= (conditional_entropy(prob_density2d(dc6,dr6))/entropy(prob_density(dr6)))*100 #H(dR|dC)/ H(dR)
B12= (conditional_entropy(prob_density2d(dy6,dr6))/entropy(prob_density(dr6)))*100 #H(dR|dY)/ H(dR)
C12=(conditional_entropy(prob_density2d(do6,dr6))/entropy(prob_density(dr6)))*100 #H(dR|dlogOD) / H(dR)
D12=(conditional_entropy(prob_density3d(dy6,dr6,do6))/entropy(prob_density(dr6)))*100 #H(dR|dY,dlogOD) / H(dR)
E12=(conditional_entropy(prob_density3d(dc6,dr6,do6))/entropy(prob_density(dr6)))*100 #H(dR|dC,dlogOD) / H(dR)
F12=(conditional_entropy(prob_density3d(dc6,dr6,dy6))/entropy(prob_density(dr6)))*100 #H(dR|dC,dY)
G12= (conditional_entropy(prob_density4d(dc6,dr6,dy6,do6))/entropy(prob_density(dr6)))*100 #H(dR|dC,dY,dlogOD) / H(dR)

ent_y12=[A12,B12,C12,D12,E12,F12,G12]

X = np.arange(8)
plt.figure()
plt.title('J23106-pLacI-J23101 Glicerol 0,2%')
plt.ylabel('Porcentaje respecto a H(dR)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y12[0],color='r',width=0.25,zorder=3)
plt.bar(X[1],ent_y12[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],ent_y12[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],ent_y12[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],ent_y12[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],ent_y12[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],ent_y12[6],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR|dC)/ H(dR)',"H(dR|dY)/ H(dR)",'H(dR|dlogOD) / H(dR)',"H(dR|dY,dlogOD) / H(dR)",'H(dR|dC,dlogOD) / H(dR)','H(dR|dC,dY)/H(dR)',"H(dR|dC,dY,dlogOD) / H(dR)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y12):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hr 106-plac gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
#Porcentajes respecto a entropía inicial
hc6=entropy(prob_density(dc6))#H(dC)
ho6=entropy(prob_density(do6))#H(dlogOD)
hyo6=conditional_entropy(prob_density2d(do6,dy6))#H(dY|dlogOD)
hco6=conditional_entropy(prob_density2d(do6,dc6))#H(dC|dlogOD)
hro6=conditional_entropy(prob_density2d(do6,dr6))#H(dR|dlogOD)

hy6=entropy(prob_density(dy6))#H(dY)
hyc6=conditional_entropy(prob_density2d(dc6,dy6))#H(dY|dC)
hyr6=conditional_entropy(prob_density2d(dr6,dy6))#H(dY|dR)
hyco6=conditional_entropy(prob_density3d(dc6,dy6,do6))#H(dY|dC,dlogOD)
hyro6=conditional_entropy(prob_density3d(dr6,dy6,do6))#H(dY|dR,dlogOD)
hycr6= conditional_entropy(prob_density3d(dc6,dy6,dr6))#H(dY|dC,dR) 
hycro6=conditional_entropy(prob_density4d(dc6,dy6,dr6,do6))#H(dY|dC,dR,dlogOD)

hr6=entropy(prob_density(dr6))#H(dR)
hrc6= conditional_entropy(prob_density2d(dc6,dr6))#H(dR|dC)
hry6=conditional_entropy(prob_density2d(dy6,dr6))#H(dR|dY)
hrco6=conditional_entropy(prob_density3d(dc6,dr6,do6))#H(dR|dC,dlogOD)
hryo6=conditional_entropy(prob_density3d(dy6,dr6,do6))#H(dR|dY,dlogOD)
hrcy6= conditional_entropy(prob_density3d(dc6,dr6,dy6))#H(dR|dC,dY)
hrcyo6=conditional_entropy(prob_density4d(dc6,dr6,dy6,do6))#H(dR|dC,dY,dlogOD)

hc6=entropy(prob_density(dc6))#H(dC)
hcy6=conditional_entropy(prob_density2d(dy6,dc6))#H(dC|dY)
hcr6=conditional_entropy(prob_density2d(dr6,dc6))#H(dC|dR)
hcyo6=conditional_entropy(prob_density3d(dy6,dc6,do6))#H(dC|dY,dlogOD)
hcro6=conditional_entropy(prob_density3d(dr6,dc6,do6))#H(dC|dR,dlogOD)
hcyr6=conditional_entropy(prob_density3d(dy6,dc6,dr6))#H(dC|dY,dR)
hcyro6=conditional_entropy(prob_density4d(dy6,dc6,dr6,do6))#H(dC|dY,dR,dlogOD)
soloc6=[hc6,hcy6,hcr6,hcyo6,hcro6,hcyr6,hycro6]

soloh6=[hr6,hy6,hc6,ho6]
hod6=[hr6,hro6,hy6,hyo6,hc6,hco6]
soloy6=[hy6,hyc6,hyr6,hyo6,hyco6,hyr6,hycr6,hycro6]
solor6=[hr6,hrc6,hry6,hro6,hrco6,hryo6,hrcy6,hrcyo6]


X = np.arange(4)
plt.figure()
plt.title('J23106-pLacI-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloh6[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],soloh6[1],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[2],soloh6[2],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[3],soloh6[3],color='g',width=0.25,label='H(dlogOD)',zorder=3)
plt.xticks(X, ['H(dR)',"H(dY)",'H(dC)',"H(dlogOD)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloh6):
    plt.text(a-0.15,b+0.2,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='h 106-plac gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)


X = np.arange(7)
plt.figure()
plt.title('J23106-pLacI-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],hod6[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],hod6[1],color='coral',width=0.25,label='H(dR)|dlogOD',zorder=3)
plt.bar(X[2],hod6[2],color='gold',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[3],hod6[3],color='y',width=0.25,label='H(dY)|dlogOD',zorder=3)
plt.bar(X[4],hod6[4],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[5],hod6[5],color='skyblue',width=0.25,label='H(dC)|dlogOD',zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dlogOD)","H(dY)",'H(dY|dlogOD)','H(dC)',"H(dC|dlogOD) "],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,hod6):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='ho 106-plac gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
X = np.arange(9)
plt.figure()
plt.title('J23106-pLacI-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloy6[0],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[1],soloy6[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],soloy6[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],soloy6[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],soloy6[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],soloy6[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],soloy6[6],color='y',width=0.25,zorder=3)
plt.bar(X[7],soloy6[7],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY)',"H(dY|dC)",'H(dY|dR)','H(dY|dlogOD)',"H(dY|dC,dlogOD)",'H(dY|dR,dlogOD)',"H(dY|dC,dR)",'H(dY|dC,dR,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloy6):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hy 106-plac gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

X = np.arange(9)
plt.figure()
plt.title('J23106-pLacI-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],solor6[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],solor6[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],solor6[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],solor6[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],solor6[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],solor6[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],solor6[6],color='r',width=0.25,zorder=3)
plt.bar(X[7],solor6[7],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dC)",'H(dR|dY)','H(dR|dlogOD)',"H(dR|dC,dlogOD)",'H(dR|dY,dlogOD)',"H(dR|dC,dY)",'H(dR|dC,dY,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,solor6):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hr 106-plac gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
print "J23106-pLas81-J23101 Glucosa"
print "---"
print "H(dY) = ", entropy(prob_density(dy7))
print "H(dC) = ", entropy(prob_density(dc7))
print "H(dR) = ", entropy(prob_density(dr7))
print "H(dlogOD) = ", entropy(prob_density(do7))

print "---"
print "H(dY|dlogOD) = ", conditional_entropy(prob_density2d(do7,dy7))
print "H(dC|dlogOD) = ", conditional_entropy(prob_density2d(do7,dc7))
print "H(dR|dlogOD) = ", conditional_entropy(prob_density2d(do7,dr7))
print "H(dY|dC) = ", conditional_entropy(prob_density2d(dc7,dy7))
print "H(dY|dR) = ", conditional_entropy(prob_density2d(dr7,dy7))
print "H(dR|dC) = ", conditional_entropy(prob_density2d(dc7,dr7))
print "H(dR|dY) = ", conditional_entropy(prob_density2d(dy7,dr7))
print "H(dC|dY) = ", conditional_entropy(prob_density2d(dy7,dc7))
print "H(dC|dR) = ", conditional_entropy(prob_density2d(dr7,dc7))

print "---"
print "I(dlogOD,dC) = ", mutual_information(prob_density2d(do7,dc7))
print "I(dlogOD,dY) = ", mutual_information(prob_density2d(do7,dy7))
print "I(dlogOD,dR) = ", mutual_information(prob_density2d(do7,dr7))
print "I(dY,dC) = ", mutual_information(prob_density2d(dc7,dy7))
print "I(dY,dR) = ", mutual_information(prob_density2d(dr7,dy7))
print "I(dR,dC) = ", mutual_information(prob_density2d(dc7,dr7))


print "---"
print "H(dY|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc7,dy7,do7))
print "H(dY|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr7,dy7,do7))
print "H(dY|dC,dR) = ", conditional_entropy(prob_density3d(dc7,dy7,dr7))
print "H(dY|dC,dR,dlogOD) = ", conditional_entropy(prob_density4d(dc7,dy7,dr7,do7))
print "H(dR|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc7,dr7,do7))
print "H(dR|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy7,dr7,do7))
print "H(dR|dC,dY) = ", conditional_entropy(prob_density3d(dc7,dr7,dy7))
print "H(dR|dC,dY,dlogOD) = ", conditional_entropy(prob_density4d(dc7,dr7,dy7,do7))
print "H(dC|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy7,dc7,do7))
print "H(dC|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr7,dc7,do7))
print "H(dC|dY,dR) = ", conditional_entropy(prob_density3d(dy7,dc7,dr7))
print "H(dC|dY,dR,dlogOD) = ", conditional_entropy(prob_density4d(dy7,dc7,dr7,do7))

print "---"
print "H(dY|dC,dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density4d(dc7,dy7,dr7,do7))/entropy(prob_density(dy7))
print "H(dY|dC,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dc7,dy7,do7))/entropy(prob_density(dy7))
print "H(dY|dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dr7,dy7,do7))/entropy(prob_density(dy7))
print "H(dY|dlogOD) / H(dY) = ", conditional_entropy(prob_density2d(do7,dy7))/entropy(prob_density(dy7))
print "H(dR|dC,dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density4d(dc7,dr7,dy7,do7))/entropy(prob_density(dr7))
print "H(dR|dC,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dc7,dr7,do7))/entropy(prob_density(dr7))
print "H(dR|dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dy7,dr7,do7))/entropy(prob_density(dr7))
print "H(dR|dlogOD) / H(dR) = ", conditional_entropy(prob_density2d(do7,dr7))/entropy(prob_density(dr7))
print "H(dC|dR,dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density4d(dr7,dc7,dy7,do7))/entropy(prob_density(dc7))
print "H(dC|dR,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dr7,dc7,do7))/entropy(prob_density(dr7))
print "H(dC|dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dy7,dc7,do7))/entropy(prob_density(dr7))
print "H(dC|dlogOD) / H(dC) = ", conditional_entropy(prob_density2d(do7,dc7))/entropy(prob_density(dr7))

print "H(dY|dC)/ H(dY) = ", conditional_entropy(prob_density2d(dc7,dy7))/entropy(prob_density(dy7))
print "H(dY|dR)/ H(dY) = ", conditional_entropy(prob_density2d(dr7,dy7))/entropy(prob_density(dy7))
print "H(dR|dC)/ H(dR) = ", conditional_entropy(prob_density2d(dc7,dr7))/entropy(prob_density(dr7))
print "H(dR|dY)/ H(dR) = ", conditional_entropy(prob_density2d(dy7,dr7))/entropy(prob_density(dr7))
print "H(dC|dY)/ H(dC) = ", conditional_entropy(prob_density2d(dy7,dc7))/entropy(prob_density(dc7))
print "H(dC|dR)/ H(dC) = ", conditional_entropy(prob_density2d(dr7,dc7))/entropy(prob_density(dc7))
# Out:
# J23106-pLas81-J23101 Glucosa
# ---
# H(dY) =  3.23901
# H(dC) =  3.1657
# H(dR) =  3.51897
# H(dlogOD) =  3.8616
# ---
# H(dY|dlogOD) =  2.4999
# H(dC|dlogOD) =  2.32717
# H(dR|dlogOD) =  2.75726
# H(dY|dC) =  1.84949
# H(dY|dR) =  1.76366
# H(dR|dC) =  2.19188
# H(dR|dY) =  2.04362
# H(dC|dY) =  1.77618
# H(dC|dR) =  1.83861
# ---
# I(dlogOD,dC) =  0.83853
# I(dlogOD,dY) =  0.739111
# I(dlogOD,dR) =  0.761706
# I(dY,dC) =  1.38952
# I(dY,dR) =  1.47535
# I(dR,dC) =  1.32709
# ---
# H(dY|dC,dlogOD) =  1.25207
# H(dY|dR,dlogOD) =  1.12315
# H(dY|dC,dR) =  1.24297
# H(dY|dC,dR,dlogOD) =  0.722796
# H(dR|dC,dlogOD) =  1.451
# H(dR|dY,dlogOD) =  1.38051
# H(dR|dC,dY) =  1.58537
# H(dR|dC,dY,dlogOD) =  0.921721
# H(dC|dY,dlogOD) =  1.07934
# H(dC|dR,dlogOD) =  1.0209
# H(dC|dY,dR) =  1.31793
# H(dC|dY,dR,dlogOD) =  0.620549
# ---
# H(dY|dC,dR,dlogOD) / H(dY) =  0.223154
# H(dY|dC,dlogOD) / H(dY) =  0.38656
# H(dY|dR,dlogOD) / H(dY) =  0.346756
# H(dY|dlogOD) / H(dY) =  0.771809
# ...

# %%
#Porcentajes respecto a entropía inicial
A13= (conditional_entropy(prob_density2d(dc7,dy7))/entropy(prob_density(dy7)))*100 #H(dY|dC)/ H(dY)
B13= (conditional_entropy(prob_density2d(dr7,dy7))/entropy(prob_density(dy7)))*100 #H(dY|dR)/ H(dY)
C13=(conditional_entropy(prob_density2d(do7,dy7))/entropy(prob_density(dy7)))*100 #H(dY|dlogOD) / H(dY)
D13=(conditional_entropy(prob_density3d(dr7,dy7,do7))/entropy(prob_density(dy7)))*100 #H(dY|dR,dlogOD) / H(dY)
E13=(conditional_entropy(prob_density3d(dc7,dy7,do7))/entropy(prob_density(dy7)))*100 #H(dY|dC,dlogOD) / H(dY)
F13=(conditional_entropy(prob_density3d(dc7,dy7,dr7))/entropy(prob_density(dy7)))*100#H(dY|dC,dR)/H(dY)
G13= (conditional_entropy(prob_density4d(dc7,dy7,dr7,do7))/entropy(prob_density(dy7)))*100 #H(dY|dC,dR,dlogOD) / H(dY)

ent_y13=[A13,B13,C13,D13,E13,F13,G13]

X = np.arange(8)
plt.figure()
plt.title('J23106-pLas81-J23101 Glucosa 0,4%')
plt.ylabel('Porcentaje respecto a H(dY)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y13[0],color='y',width=0.25,zorder=3)
plt.bar(X[1],ent_y13[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],ent_y13[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],ent_y13[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],ent_y13[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],ent_y13[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],ent_y13[6],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY|dC)/ H(dY)',"H(dY|dR)/ H(dY)",'H(dY|dlogOD) / H(dY)',"H(dY|dR,dlogOD) / H(dY)",'H(dY|dC,dlogOD) / H(dY)','H(dY|dC,dR) / H(dY)',"H(dY|dC,dR,dlogOD) / H(dY)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y13):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hy 106-plas glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

A14= (conditional_entropy(prob_density2d(dc7,dr7))/entropy(prob_density(dr7)))*100 #H(dR|dC)/ H(dR)
B14= (conditional_entropy(prob_density2d(dy7,dr7))/entropy(prob_density(dr7)))*100 #H(dR|dY)/ H(dR)
C14=(conditional_entropy(prob_density2d(do7,dr7))/entropy(prob_density(dr7)))*100 #H(dR|dlogOD) / H(dR)
D14=(conditional_entropy(prob_density3d(dy7,dr7,do7))/entropy(prob_density(dr7)))*100 #H(dR|dY,dlogOD) / H(dR)
E14=(conditional_entropy(prob_density3d(dc7,dr7,do7))/entropy(prob_density(dr7)))*100 #H(dR|dC,dlogOD) / H(dR)
F14=(conditional_entropy(prob_density3d(dc7,dr7,dy7))/entropy(prob_density(dr7)))*100 #H(dR|dC,dY)
G14= (conditional_entropy(prob_density4d(dc7,dr7,dy7,do7))/entropy(prob_density(dr7)))*100 #H(dR|dC,dY,dlogOD) / H(dR)

ent_y14=[A14,B14,C14,D14,E14,F14,G14]

X = np.arange(8)
plt.figure()
plt.title('J23106-pLasI-J23101 Glucosa 0,4%')
plt.ylabel('Porcentaje respecto a H(dR)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y14[0],color='r',width=0.25,zorder=3)
plt.bar(X[1],ent_y14[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],ent_y14[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],ent_y14[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],ent_y14[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],ent_y14[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],ent_y14[6],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR|dC)/ H(dR)',"H(dR|dY)/ H(dR)",'H(dR|dlogOD) / H(dR)',"H(dR|dY,dlogOD) / H(dR)",'H(dR|dC,dlogOD) / H(dR)','H(dR|dC,dY)/H(dR)',"H(dR|dC,dY,dlogOD) / H(dR)"],rotation=75)
lt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y14):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hr 106-plas glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
#Porcentajes respecto a entropía inicial
hc7=entropy(prob_density(dc7))#H(dC)
ho7=entropy(prob_density(do7))#H(dlogOD)
hyo7=conditional_entropy(prob_density2d(do7,dy7))#H(dY|dlogOD)
hco7=conditional_entropy(prob_density2d(do7,dc7))#H(dC|dlogOD)
hro7=conditional_entropy(prob_density2d(do7,dr7))#H(dR|dlogOD)

hy7=entropy(prob_density(dy7))#H(dY)
hyc7=conditional_entropy(prob_density2d(dc7,dy7))#H(dY|dC)
hyr7=conditional_entropy(prob_density2d(dr7,dy7))#H(dY|dR)
hyco7=conditional_entropy(prob_density3d(dc7,dy7,do7))#H(dY|dC,dlogOD)
hyro7=conditional_entropy(prob_density3d(dr7,dy7,do7))#H(dY|dR,dlogOD)
hycr7= conditional_entropy(prob_density3d(dc7,dy7,dr7))#H(dY|dC,dR) 
hycro7=conditional_entropy(prob_density4d(dc7,dy7,dr7,do7))#H(dY|dC,dR,dlogOD)

hr7=entropy(prob_density(dr7))#H(dR)
hrc7= conditional_entropy(prob_density2d(dc7,dr7))#H(dR|dC)
hry7=conditional_entropy(prob_density2d(dy7,dr7))#H(dR|dY)
hrco7=conditional_entropy(prob_density3d(dc7,dr7,do7))#H(dR|dC,dlogOD)
hryo7=conditional_entropy(prob_density3d(dy7,dr7,do7))#H(dR|dY,dlogOD)
hrcy7= conditional_entropy(prob_density3d(dc7,dr7,dy7))#H(dR|dC,dY)
hrcyo7=conditional_entropy(prob_density4d(dc7,dr7,dy7,do7))#H(dR|dC,dY,dlogOD)

hc7=entropy(prob_density(dc7))#H(dC)
hcy7=conditional_entropy(prob_density2d(dy7,dc7))#H(dC|dY)
hcr7=conditional_entropy(prob_density2d(dr7,dc7))#H(dC|dR)
hcyo7=conditional_entropy(prob_density3d(dy7,dc7,do7))#H(dC|dY,dlogOD)
hcro7=conditional_entropy(prob_density3d(dr7,dc7,do7))#H(dC|dR,dlogOD)
hcyr7=conditional_entropy(prob_density3d(dy7,dc7,dr7))#H(dC|dY,dR)
hcyro7=conditional_entropy(prob_density4d(dy7,dc7,dr7,do7))#H(dC|dY,dR,dlogOD)
soloc7=[hc7,hcy7,hcr7,hcyo7,hcro7,hcyr7,hycro7]


soloh7=[hr7,hy7,hc7,ho7]
hod7=[hr7,hro7,hy7,hyo7,hc7,hco7]
soloy7=[hy7,hyc7,hyr7,hyo7,hyco7,hyro7,hycr7,hycro7]
solor7=[hr7,hrc7,hry7,hro7,hrco7,hryo7,hrcy7,hrcyo7]


X = np.arange(4)
plt.figure()
plt.title('J23106-pLas81-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloh7[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],soloh7[1],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[2],soloh7[2],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[3],soloh7[3],color='g',width=0.25,label='H(dlogOD)',zorder=3)
plt.xticks(X, ['H(dR)',"H(dY)",'H(dC)',"H(dlogOD)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloh7):
    plt.text(a-0.15,b+0.2,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='h 106-plas glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)


X = np.arange(7)
plt.figure()
plt.title('J23106-pLas81-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],hod7[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],hod7[1],color='coral',width=0.25,label='H(dR)|dlogOD',zorder=3)
plt.bar(X[2],hod7[2],color='gold',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[3],hod7[3],color='y',width=0.25,label='H(dY)|dlogOD',zorder=3)
plt.bar(X[4],hod7[4],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[5],hod7[5],color='skyblue',width=0.25,label='H(dC)|dlogOD',zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dlogOD)","H(dY)",'H(dY|dlogOD)','H(dC)',"H(dC|dlogOD) "],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,hod7):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='ho 106-plas glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
X = np.arange(9)
plt.figure()
plt.title('J23106-pLas81-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloy7[0],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[1],soloy7[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],soloy7[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],soloy7[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],soloy7[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],soloy7[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],soloy7[6],color='y',width=0.25,zorder=3)
plt.bar(X[7],soloy7[7],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY)',"H(dY|dC)",'H(dY|dR)','H(dY|dlogOD)',"H(dY|dC,dlogOD)",'H(dY|dR,dlogOD)',"H(dY|dC,dR)",'H(dY|dC,dR,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloy7):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hy 106-plas glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

X = np.arange(9)
plt.figure()
plt.title('J23106-pLas81-J23101 Glucosa 0,4%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],solor7[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],solor7[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],solor7[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],solor7[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],solor7[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],solor7[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],solor7[6],color='r',width=0.25,zorder=3)
plt.bar(X[7],solor7[7],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dC)",'H(dR|dY)','H(dR|dlogOD)',"H(dR|dC,dlogOD)",'H(dR|dY,dlogOD)',"H(dR|dC,dY)",'H(dR|dC,dY,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,solor7):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hr 106-plas glu.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
print "J23106-pLas81-J23101 Glicerol"
print "---"
print "H(dY) = ", entropy(prob_density(dy8))
print "H(dC) = ", entropy(prob_density(dc8))
print "H(dR) = ", entropy(prob_density(dr8))
print "H(dlogOD) = ", entropy(prob_density(do8))

print "---"
print "H(dY|dlogOD) = ", conditional_entropy(prob_density2d(do8,dy8))
print "H(dC|dlogOD) = ", conditional_entropy(prob_density2d(do8,dc8))
print "H(dR|dlogOD) = ", conditional_entropy(prob_density2d(do8,dr8))
print "H(dY|dC) = ", conditional_entropy(prob_density2d(dc8,dy8))
print "H(dY|dR) = ", conditional_entropy(prob_density2d(dr8,dy8))
print "H(dR|dC) = ", conditional_entropy(prob_density2d(dc8,dr8))
print "H(dR|dY) = ", conditional_entropy(prob_density2d(dy8,dr8))

print "H(dC|dY) = ", conditional_entropy(prob_density2d(dy8,dc8))
print "H(dC|dR) = ", conditional_entropy(prob_density2d(dr8,dc8))

print "---"
print "I(dlogOD,dC) = ", mutual_information(prob_density2d(do8,dc8))
print "I(dlogOD,dY) = ", mutual_information(prob_density2d(do8,dy8))
print "I(dlogOD,dR) = ", mutual_information(prob_density2d(do8,dr8))
print "I(dY,dC) = ", mutual_information(prob_density2d(dc8,dy8))
print "I(dY,dR) = ", mutual_information(prob_density2d(dr8,dy8))
print "I(dR,dC) = ", mutual_information(prob_density2d(dc8,dr8))

print "---"
print "H(dY|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc8,dy8,do8))
print "H(dY|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr8,dy8,do8))
print "H(dY|dC,dR) = ", conditional_entropy(prob_density3d(dc8,dy8,dr8))
print "H(dY|dC,dR,dlogOD) = ", conditional_entropy(prob_density4d(dc8,dy8,dr8,do8))
print "H(dR|dC,dlogOD) = ", conditional_entropy(prob_density3d(dc8,dr8,do8))
print "H(dR|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy8,dr8,do8))
print "H(dR|dC,dY) = ", conditional_entropy(prob_density3d(dc8,dr8,dy8))
print "H(dR|dC,dY,dlogOD) = ", conditional_entropy(prob_density4d(dc8,dr8,dy8,do8))

print "H(dC|dY,dlogOD) = ", conditional_entropy(prob_density3d(dy8,dc8,do8))
print "H(dC|dR,dlogOD) = ", conditional_entropy(prob_density3d(dr8,dc8,do8))
print "H(dC|dY,dR) = ", conditional_entropy(prob_density3d(dy8,dc8,dr8))
print "H(dC|dY,dR,dlogOD) = ", conditional_entropy(prob_density4d(dy8,dc8,dr8,do8))

print "---"
print "H(dY|dC,dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density4d(dc8,dy8,dr8,do8))/entropy(prob_density(dy8))
print "H(dY|dC,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dc8,dy8,do8))/entropy(prob_density(dy8))
print "H(dY|dR,dlogOD) / H(dY) = ", conditional_entropy(prob_density3d(dr8,dy8,do8))/entropy(prob_density(dy8))
print "H(dY|dlogOD) / H(dY) = ", conditional_entropy(prob_density2d(do8,dy8))/entropy(prob_density(dy8))
print "H(dR|dC,dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density4d(dc8,dr8,dy8,do8))/entropy(prob_density(dr8))
print "H(dR|dC,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dc8,dr8,do8))/entropy(prob_density(dr8))
print "H(dR|dY,dlogOD) / H(dR) = ", conditional_entropy(prob_density3d(dy8,dr8,do8))/entropy(prob_density(dr8))
print "H(dR|dlogOD) / H(dR) = ", conditional_entropy(prob_density2d(do8,dr8))/entropy(prob_density(dr8))

print "H(dC|dR,dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density4d(dr8,dc8,dy8,do8))/entropy(prob_density(dc8))
print "H(dC|dR,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dr8,dc8,do8))/entropy(prob_density(dr8))
print "H(dC|dY,dlogOD) / H(dC) = ", conditional_entropy(prob_density3d(dy8,dc8,do8))/entropy(prob_density(dr8))
print "H(dC|dlogOD) / H(dC) = ", conditional_entropy(prob_density2d(do8,dc8))/entropy(prob_density(dr8))

print "H(dY|dC)/ H(dY) = ", conditional_entropy(prob_density2d(dc8,dy8))/entropy(prob_density(dy8))
print "H(dY|dR)/ H(dY) = ", conditional_entropy(prob_density2d(dr8,dy8))/entropy(prob_density(dy8))
print "H(dR|dC)/ H(dR) = ", conditional_entropy(prob_density2d(dc8,dr8))/entropy(prob_density(dr8))
print "H(dR|dY)/ H(dR) = ", conditional_entropy(prob_density2d(dy8,dr8))/entropy(prob_density(dr8))

print "H(dC|dY)/ H(dC) = ", conditional_entropy(prob_density2d(dy8,dc8))/entropy(prob_density(dc8))
print "H(dC|dR)/ H(dC) = ", conditional_entropy(prob_density2d(dr8,dc8))/entropy(prob_density(dc8))
# Out:
# J23106-pLas81-J23101 Glicerol
# ---
# H(dY) =  3.61517
# H(dC) =  3.08364
# H(dR) =  3.24741
# H(dlogOD) =  3.46024
# ---
# H(dY|dlogOD) =  2.95137
# H(dC|dlogOD) =  2.54134
# H(dR|dlogOD) =  2.77289
# H(dY|dC) =  2.27748
# H(dY|dR) =  1.90947
# H(dR|dC) =  2.26495
# H(dR|dY) =  1.54172
# H(dC|dY) =  1.74596
# H(dC|dR) =  2.10118
# ---
# I(dlogOD,dC) =  0.542304
# I(dlogOD,dY) =  0.663801
# I(dlogOD,dR) =  0.474529
# I(dY,dC) =  1.33768
# I(dY,dR) =  1.70569
# I(dR,dC) =  0.982462
# ---
# H(dY|dC,dlogOD) =  1.42062
# H(dY|dR,dlogOD) =  1.14869
# H(dY|dC,dR) =  1.06345
# H(dY|dC,dR,dlogOD) =  0.52026
# H(dR|dC,dlogOD) =  1.51858
# H(dR|dY,dlogOD) =  0.970214
# H(dR|dC,dY) =  1.05092
# H(dR|dC,dY,dlogOD) =  0.618221
# H(dC|dY,dlogOD) =  1.01059
# H(dC|dR,dlogOD) =  1.28703
# H(dC|dY,dR) =  1.25516
# H(dC|dY,dR,dlogOD) =  0.658596
# ---
# H(dY|dC,dR,dlogOD) / H(dY) =  0.14391
# H(dY|dC,dlogOD) / H(dY) =  0.39296
# H(dY|dR,dlogOD) / H(dY) =  0.317743
# H(dY|dlogOD) / H(dY) =  0.816385
# ...

# %%
#Porcentajes respecto a entropía inicial
A15= (conditional_entropy(prob_density2d(dc8,dy8))/entropy(prob_density(dy8)))*100 #H(dY|dC)/ H(dY)
B15= (conditional_entropy(prob_density2d(dr8,dy8))/entropy(prob_density(dy8)))*100 #H(dY|dR)/ H(dY)
C15=(conditional_entropy(prob_density2d(do8,dy8))/entropy(prob_density(dy8)))*100 #H(dY|dlogOD) / H(dY)
D15=(conditional_entropy(prob_density3d(dr8,dy8,do8))/entropy(prob_density(dy8)))*100 #H(dY|dR,dlogOD) / H(dY)
E15=(conditional_entropy(prob_density3d(dc8,dy8,do8))/entropy(prob_density(dy8)))*100 #H(dY|dC,dlogOD) / H(dY)
F15=(conditional_entropy(prob_density3d(dc8,dy8,dr8))/entropy(prob_density(dy8)))*100#H(dY|dC,dR)/H(dY)
G15=(conditional_entropy(prob_density4d(dc8,dy8,dr8,do8))/entropy(prob_density(dy8)))*100 #H(dY|dC,dR,dlogOD) / H(dY)

ent_y15=[A15,B15,C15,D15,E15,F15,G15]

X = np.arange(8)
plt.figure()
plt.title('J23106-pLas81-J23101 Glicerol 0,2%')
plt.ylabel('Porcentaje respecto a H(dY)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y15[0],color='y',width=0.25,zorder=3)
plt.bar(X[1],ent_y15[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],ent_y15[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],ent_y15[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],ent_y15[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],ent_y15[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],ent_y15[6],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY|dC)/ H(dY)',"H(dY|dR)/ H(dY)",'H(dY|dlogOD) / H(dY)',"H(dY|dR,dlogOD) / H(dY)",'H(dY|dC,dlogOD) / H(dY)','H(dY|dC,dR) / H(dY)',"H(dY|dC,dR,dlogOD) / H(dY)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y15):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hy 106-plas gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

A16= (conditional_entropy(prob_density2d(dc8,dr8))/entropy(prob_density(dr8)))*100 #H(dR|dC)/ H(dR)
B16= (conditional_entropy(prob_density2d(dy8,dr8))/entropy(prob_density(dr8)))*100 #H(dR|dY)/ H(dR)
C16=(conditional_entropy(prob_density2d(do8,dr8))/entropy(prob_density(dr8)))*100 #H(dR|dlogOD) / H(dR)
D16=(conditional_entropy(prob_density3d(dy8,dr8,do8))/entropy(prob_density(dr8)))*100 #H(dR|dY,dlogOD) / H(dR)
E16=(conditional_entropy(prob_density3d(dc8,dr8,do8))/entropy(prob_density(dr8)))*100 #H(dR|dC,dlogOD) / H(dR)
F16=(conditional_entropy(prob_density3d(dc8,dr8,dy8))/entropy(prob_density(dr8)))*100 #H(dR|dC,dY)
G16= (conditional_entropy(prob_density4d(dc8,dr8,dy8,do8))/entropy(prob_density(dr8)))*100 #H(dR|dC,dY,dlogOD) / H(dR)

ent_y16=[A16,B16,C16,D16,E16,F16,G16]

X = np.arange(8)
plt.figure()
plt.title('J23106-pLas81-J23101 Glicerol 0,2%')
plt.ylabel('Porcentaje respecto a H(dR)')
plt.ylim(ymax = 100)
plt.bar(X[0],ent_y16[0],color='r',width=0.25,zorder=3)
plt.bar(X[1],ent_y16[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],ent_y16[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],ent_y16[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],ent_y16[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],ent_y16[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],ent_y16[6],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR|dC)/ H(dR)',"H(dR|dY)/ H(dR)",'H(dR|dlogOD) / H(dR)',"H(dR|dY,dlogOD) / H(dR)",'H(dR|dC,dlogOD) / H(dR)','H(dR|dC,dY)/H(dR)',"H(dR|dC,dY,dlogOD) / H(dR)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,ent_y16):
    plt.text(a-0.25,b+0.5,str(np.round(b,2))+'%',fontsize=10.0, color='k')
plt.savefig(fname='porcentajes hr 106-plas gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
#Porcentajes respecto a entropía inicial
hc8=entropy(prob_density(dc8))#H(dC)
ho8=entropy(prob_density(do8))#H(dlogOD)
hyo8=conditional_entropy(prob_density2d(do8,dy8))#H(dY|dlogOD)
hco8=conditional_entropy(prob_density2d(do8,dc8))#H(dC|dlogOD)
hro8=conditional_entropy(prob_density2d(do8,dr8))#H(dR|dlogOD)

hy8=entropy(prob_density(dy8))#H(dY)
hyc8=conditional_entropy(prob_density2d(dc8,dy8))#H(dY|dC)
hyr8=conditional_entropy(prob_density2d(dr8,dy8))#H(dY|dR)
hyco8=conditional_entropy(prob_density3d(dc8,dy8,do8))#H(dY|dC,dlogOD)
hyro8=conditional_entropy(prob_density3d(dr8,dy8,do8))#H(dY|dR,dlogOD)
hycr8= conditional_entropy(prob_density3d(dc8,dy8,dr8))#H(dY|dC,dR) 
hycro8=conditional_entropy(prob_density4d(dc8,dy8,dr8,do8))#H(dY|dC,dR,dlogOD)

hr8=entropy(prob_density(dr8))#H(dR)
hrc8= conditional_entropy(prob_density2d(dc8,dr8))#H(dR|dC)
hry8=conditional_entropy(prob_density2d(dy8,dr8))#H(dR|dY)
hrco8=conditional_entropy(prob_density3d(dc8,dr8,do8))#H(dR|dC,dlogOD)
hryo8=conditional_entropy(prob_density3d(dy8,dr8,do8))#H(dR|dY,dlogOD)
hrcy8= conditional_entropy(prob_density3d(dc8,dr8,dy8))#H(dR|dC,dY)
hrcyo8=conditional_entropy(prob_density4d(dc8,dr8,dy8,do8))#H(dR|dC,dY,dlogOD)

hc8=entropy(prob_density(dc8))#H(dC)
hcy8=conditional_entropy(prob_density2d(dy8,dc8))#H(dC|dY)
hcr8=conditional_entropy(prob_density2d(dr8,dc8))#H(dC|dR)
hcyo8=conditional_entropy(prob_density3d(dy8,dc8,do8))#H(dC|dY,dlogOD)
hcro8=conditional_entropy(prob_density3d(dr8,dc8,do8))#H(dC|dR,dlogOD)
hcyr8=conditional_entropy(prob_density3d(dy8,dc8,dr8))#H(dC|dY,dR)
hcyro8=conditional_entropy(prob_density4d(dy8,dc8,dr8,do8))#H(dC|dY,dR,dlogOD)
soloc8=[hc8,hcy8,hcr8,hcyo8,hcro8,hcyr8,hycro8]

soloh8=[hr8,hy8,hc8,ho8]
hod8=[hr8,hro8,hy8,hyo8,hc8,hco8]
soloy8=[hy8,hyc8,hyr8,hyo8,hyco8,hyr8,hycr8,hycro8]
solor8=[hr8,hrc8,hry8,hro8,hrco8,hryo8,hrcy8,hrcyo8]


X = np.arange(4)
plt.figure()
plt.title('J23106-pLas81-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloh8[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],soloh8[1],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[2],soloh8[2],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[3],soloh8[3],color='g',width=0.25,label='H(dlogOD)',zorder=3)
plt.xticks(X, ['H(dR)',"H(dY)",'H(dC)',"H(dlogOD)"],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloh8):
    plt.text(a-0.15,b+0.2,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='h 106-plas gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)


X = np.arange(7)
plt.figure()
plt.title('J23106-pLas81-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],hod8[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],hod8[1],color='coral',width=0.25,label='H(dR)|dlogOD',zorder=3)
plt.bar(X[2],hod8[2],color='gold',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[3],hod8[3],color='y',width=0.25,label='H(dY)|dlogOD',zorder=3)
plt.bar(X[4],hod8[4],color='c',width=0.25,label='H(dC)',zorder=3)
plt.bar(X[5],hod8[5],color='skyblue',width=0.25,label='H(dC)|dlogOD',zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dlogOD)","H(dY)",'H(dY|dlogOD)','H(dC)',"H(dC|dlogOD) "],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,hod8):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='ho 106-plas gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
X = np.arange(9)
plt.figure()
plt.title('J23106-pLas81-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],soloy8[0],color='y',width=0.25,label='H(dY)',zorder=3)
plt.bar(X[1],soloy8[1],color='y',width=0.25,zorder=3)
plt.bar(X[2],soloy8[2],color='y',width=0.25,zorder=3)
plt.bar(X[3],soloy8[3],color='y',width=0.25,zorder=3)
plt.bar(X[4],soloy8[4],color='y',width=0.25,zorder=3)
plt.bar(X[5],soloy8[5],color='y',width=0.25,zorder=3)
plt.bar(X[6],soloy8[6],color='y',width=0.25,zorder=3)
plt.bar(X[7],soloy8[7],color='y',width=0.25,zorder=3)
plt.xticks(X, ['H(dY)',"H(dY|dC)",'H(dY|dR)','H(dY|dlogOD)',"H(dY|dC,dlogOD)",'H(dY|dR,dlogOD)',"H(dY|dC,dR)",'H(dY|dC,dR,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,soloy8):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hy 106-plas gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

X = np.arange(9)
plt.figure()
plt.title('J23106-pLlas81-J23101 Glicerol 0,2%')
plt.ylabel('H(x)')
plt.ylim(ymax = 5)
plt.bar(X[0],solor8[0],color='r',width=0.25,label='H(dR)',zorder=3)
plt.bar(X[1],solor8[1],color='r',width=0.25,zorder=3)
plt.bar(X[2],solor8[2],color='r',width=0.25,zorder=3)
plt.bar(X[3],solor8[3],color='r',width=0.25,zorder=3)
plt.bar(X[4],solor8[4],color='r',width=0.25,zorder=3)
plt.bar(X[5],solor8[5],color='r',width=0.25,zorder=3)
plt.bar(X[6],solor8[6],color='r',width=0.25,zorder=3)
plt.bar(X[7],solor8[7],color='r',width=0.25,zorder=3)
plt.xticks(X, ['H(dR)',"H(dR|dC)",'H(dR|dY)','H(dR|dlogOD)',"H(dR|dC,dlogOD)",'H(dR|dY,dlogOD)',"H(dR|dC,dY)",'H(dR|dC,dY,dlogOD)'],rotation=75)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5,zorder=0)
for a,b in zip(X,solor8):
    plt.text(a-0.25,b+0.5,str(np.round(b,2)),fontsize=10.0, color='k')
plt.legend(loc=(1.01,0.0))
plt.savefig(fname='hr 106-plas gli.png',dpi=1200,facecolor='w',edgecolor='w',bbox_inches='tight',pad_inches=0.2)

# %%
#Entropías condicionales de YFP
HY=[hy1,hy2,hy3,hy4,hy5,hy6,hy7,hy8]
HYO=[hyo1/hy1,hyo2/hy2,hyo3/hy3,hyo4/hy4,hyo5/hy5,hyo6/hy6,hyo7/hy7,hyo8/hy8]
HYC=[hyc1/hy1,hyc2/hy2,hyc3/hy3,hyc4/hy4,hyc5/hy5,hyc6/hy6,hyc7/hy7,hyc8/hy8]
HYR=[hyr1/hy1,hyr2/hy2,hyr3/hy3,hyr4/hy4,hyr5/hy5,hyr6/hy6,hyr7/hy7,hyr8/hy8]
HYCO=[hyco1/hy1,hyco2/hy2,hyco3/hy3,hyco4/hy4,hyco5/hy5,hyco6/hy6,hyco7/hy7,hyco8/hy8]
HYRO=[hyro1/hy1,hyro2/hy2,hyro3/hy3,hyro4/hy4,hyro5/hy5,hyro6/hy6,hyro7/hy7,hyro8/hy8]
HYCR=[hycr1/hy1,hycr2/hy2,hycr3/hy3,hycr4/hy4,hycr5/hy5,hycr6/hy6,hycr7/hy7,hycr8/hy8]
HYCRO=[hycro1/hy1,hycro2/hy2,hycro3/hy3,hycro4/hy4,hycro5/hy5,hycro6/hy6,hycro7/hy7,hycro8/hy8]


print "H(dY) = ", HY
print "H(dY|dlogOD) = ", HYO
print "H(dY|dC) = ", HYC
print "H(dY|dR) = ", HYR
print "H(dY|dC,dlogOD) = ", HYCO
print "H(dY|dR,dlogOD) = ", HYRO
print "H(dY|dC,dR) = ", HYCR
print "H(dY|dC,dR,dlogOD) = ", HYCRO
# Out:
# H(dY) =  [3.6257074, 3.2830191, 3.38006, 3.8548996, 3.4728532, 3.7898448, 3.2390075, 3.6151679]
# H(dY|dlogOD) =  [0.69904566, 0.6558162, 0.77578789, 0.77619398, 0.76212126, 0.67405319, 0.77180946, 0.81638455]
# H(dY|dC) =  [0.56375986, 0.71479565, 0.61121047, 0.63442224, 0.63699734, 0.81178874, 0.57100552, 0.62998021]
# H(dY|dR) =  [0.39046922, 0.45050648, 0.44194084, 0.49097952, 0.55071801, 0.45178157, 0.54450482, 0.52818394]
# H(dY|dC,dlogOD) =  [0.35226959, 0.33850476, 0.3678529, 0.40725118, 0.37023351, 0.51518905, 0.38656035, 0.39296007]
# H(dY|dR,dlogOD) =  [0.23436439, 0.25619093, 0.26910928, 0.29670149, 0.30256301, 0.22247365, 0.3467561, 0.31774318]
# H(dY|dC,dR) =  [0.2837418, 0.26790264, 0.33276394, 0.30135247, 0.41965076, 0.36193925, 0.38375115, 0.29416439]
# H(dY|dC,dR,dlogOD) =  [0.1505817, 0.12029546, 0.17218482, 0.16876641, 0.19390312, 0.15923314, 0.22315368, 0.14391029]

# %%
#Entropías condicionales de RFP
HR=[hr1,hr2,hr3,hr4,hr5,hr6,hr7,hr8]
HRO=[hro1/hr1,hro2/hr2,hro3/hr3,hro4/hr4,hro5/hr5,hro6/hr6,hro7/hr7,hro8/hr8]
HRC=[hrc1/hr1,hrc2/hr2,hrc3/hr3,hrc4/hr4,hrc5/hr5,hrc6/hr6,hrc7/hr7,hrc8/hr8]
HRY=[hry1/hr1,hry2/hr2,hry3/hr3,hry4/hr4,hry5/hr5,hry6/hr6,hry7/hr7,hry8/hr8]
HRCO=[hrco1/hr1,hrco2/hr2,hrco3/hr3,hrco4/hr4,hrco5/hr5,hrco6/hr6,hrco7/hr7,hrco8/hr8]
HRYO=[hryo1/hr1,hryo2/hr2,hryo3/hr3,hryo4/hr4,hryo5/hr5,hryo6/hr6,hryo7/hr7,hryo8/hr8]
HRCY=[hrcy1/hr1,hrcy2/hr2,hrcy3/hr3,hrcy4/hr4,hrcy5/hr5,hrcy6/hr6,hrcy7/hr7,hrcy8/hr8]
HRCYO=[hrcyo1/hr1,hrcyo2/hr2,hrcyo3/hr3,hrcyo4/hr4,hrcyo5/hr5,hrcyo6/hr6,hrcyo7/hr7,hrcyo8/hr8]

print "H(dR) = ", HR
print "H(dR|dlogOD) = ", HRO
print "H(dR|dC) = ", HRC
print "H(dR|dY) = ", HRY
print "H(dR|dC,dlogOD) = ", HRCO
print "H(dR|dY,dlogOD) = ", HRYO
print "H(dR|dC,dY) = ", HRCY
print "H(dR|dC,dY,dlogOD) = ", HRCYO
# Out:
# H(dR) =  [3.6678772, 3.110673, 3.6086545, 3.4262199, 3.6559224, 3.381, 3.51897, 3.2474144]
# H(dR|dlogOD) =  [0.69284821, 0.67791271, 0.76026338, 0.76136541, 0.77353001, 0.71361607, 0.78354281, 0.85387504]
# H(dR|dC) =  [0.5609436, 0.74466252, 0.60100794, 0.64768362, 0.53990406, 0.82967871, 0.62287652, 0.69746345]
# H(dR|dY) =  [0.39747691, 0.42006212, 0.47729164, 0.42729214, 0.57321596, 0.38548878, 0.58074313, 0.47475329]
# H(dR|dC,dlogOD) =  [0.34090137, 0.38491946, 0.36462957, 0.39735436, 0.34129456, 0.55869657, 0.41233554, 0.46762654]
# H(dR|dY,dlogOD) =  [0.23350957, 0.25614625, 0.28568095, 0.22187996, 0.33698404, 0.20742951, 0.39230591, 0.29876518]
# H(dR|dC,dY) =  [0.28414491, 0.27300963, 0.34019992, 0.27294084, 0.33344108, 0.3254317, 0.45051983, 0.3236182]
# H(dR|dC,dY,dlogOD) =  [0.1415323, 0.15462032, 0.18135606, 0.12903087, 0.17379388, 0.15969701, 0.26192906, 0.19037339]

# %%
#Entropías condicionales de CFP
HC=[hc1,hc2,hc3,hc4,hc5,hc6,hc7,hc8]
HCO=[hco1/hc1,hco2/hc2,hco3/hc3,hco4/hc4,hco5/hc5,hco6/hc6,hco7/hc7,hco8/hc8]
HCR=[hcr1/hc1,hcr2/hc2,hcr3/hc3,hcr4/hc4,hcr5/hc5,hcr6/hc6,hcr7/hc7,hcr8/hc8]
HCY=[hcy1/hc1,hcy2/hc2,hcy3/hc3,hcy4/hc4,hcy5/hc5,hcy6/hc6,hcy7/hc7,hcy8/hc8]
HCYO=[hcyo1/hc1,hcyo2/hc2,hcyo3/hc3,hcyo4/hc4,hcyo5/hc5,hcyo6/hc6,hcyo7/hc7,hcyo8/hc8]
HCRO=[hcro1/hc1,hcro2/hc2,hcro3/hc3,hcro4/hc4,hcro5/hc5,hcro6/hc6,hcro7/hc7,hcro8/hc8]
HCYR=[hcyr1/hc1,hcyr2/hc2,hcyr3/hc3,hcyr4/hc4,hcyr5/hc5,hcyr6/hc6,hcyr7/hc7,hcyr8/hc8]
HCYRO=[hcyro1/hc1,hcyro2/hc2,hcyro3/hc3,hcyro4/hc4,hcyro5/hc5,hcyro6/hc6,hcyro7/hc7,hcyro8/hc8]


print "H(dC) = ", HC
print "H(dC|dlogOD) = ", HCO
print "H(dC|dR) = ", HCR
print "H(dC|dY) = ", HCY
print "H(dC|dY,dlogOD) = ", HCYO
print "H(dC|dR,dlogOD) = ", HCRO
print "H(dC|dY,dR) = ", HCYR
print "H(dC|dY,dR,dlogOD) = ", HCYRO
# Out:
# H(dC) =  [3.5327115, 2.9891796, 3.2575974, 3.4091365, 3.3283896, 1.9067755, 3.1656966, 3.0836437]
# H(dC|dlogOD) =  [0.67614526, 0.74287146, 0.72472161, 0.71645457, 0.75810611, 0.69198072, 0.73512006, 0.82413536]
# H(dC|dR) =  [0.54414463, 0.73428446, 0.55801034, 0.64591813, 0.4946281, 0.69799501, 0.58079165, 0.68139613]
# H(dC|dY) =  [0.55227619, 0.68675989, 0.59659457, 0.58662099, 0.62124181, 0.62591761, 0.56107068, 0.56620032]
# H(dC|dY,dlogOD) =  [0.32024074, 0.39436802, 0.30145103, 0.29927039, 0.34920925, 0.37622732, 0.34094939, 0.32772565]
# H(dC|dR,dlogOD) =  [0.31073275, 0.43796942, 0.28645179, 0.35061961, 0.28333634, 0.41728491, 0.32248819, 0.41737351]
# H(dC|dY,dR) =  [0.4346081, 0.53373039, 0.44472915, 0.43149629, 0.3578718, 0.51942658, 0.41631511, 0.40703851]
# H(dC|dY,dR,dlogOD) =  [0.22474442, 0.2887156, 0.18588379, 0.20595603, 0.16996023, 0.29159036, 0.19602296, 0.21357723]

# %%
ioc1=mutual_information(prob_density2d(do1,dc1))#I(dlogOD,dC)
ioy1=mutual_information(prob_density2d(do1,dy1))#I(dlogOD,dY)
ior1=mutual_information(prob_density2d(do1,dr1))#I(dlogOD,dR)
iyc1=mutual_information(prob_density2d(dc1,dy1))#I(dY,dC)
iyr1=mutual_information(prob_density2d(dr1,dy1))#I(dY,dR)
irc1=mutual_information(prob_density2d(dc1,dr1))#I(dR,dC)

ioc2=mutual_information(prob_density2d(do2,dc2))#I(dlogOD,dC)
ioy2=mutual_information(prob_density2d(do2,dy2))#I(dlogOD,dY)
ior2=mutual_information(prob_density2d(do2,dr2))#I(dlogOD,dR)
iyc2=mutual_information(prob_density2d(dc2,dy2))#I(dY,dC)
iyr2=mutual_information(prob_density2d(dr2,dy2))#I(dY,dR)
irc2=mutual_information(prob_density2d(dc2,dr2))#I(dR,dC) 

ioc3=mutual_information(prob_density2d(do3,dc3))#I(dlogOD,dC)
ioy3=mutual_information(prob_density2d(do3,dy3))#I(dlogOD,dY)
ior3=mutual_information(prob_density2d(do3,dr3))#I(dlogOD,dR)
iyc3=mutual_information(prob_density2d(dc3,dy3))#I(dY,dC)
iyr3=mutual_information(prob_density2d(dr3,dy3))#I(dY,dR)
irc3=mutual_information(prob_density2d(dc3,dr3))#I(dR,dC) 

ioc4=mutual_information(prob_density2d(do4,dc4))#I(dlogOD,dC)
ioy4=mutual_information(prob_density2d(do4,dy4))#I(dlogOD,dY)
ior4=mutual_information(prob_density2d(do4,dr4))#I(dlogOD,dR)
iyc4=mutual_information(prob_density2d(dc4,dy4))#I(dY,dC)
iyr4=mutual_information(prob_density2d(dr4,dy4))#I(dY,dR)
irc4=mutual_information(prob_density2d(dc4,dr4))#I(dR,dC) 

ioc5=mutual_information(prob_density2d(do5,dc5))#I(dlogOD,dC)
ioy5=mutual_information(prob_density2d(do5,dy5))#I(dlogOD,dY)
ior5=mutual_information(prob_density2d(do5,dr5))#I(dlogOD,dR)
iyc5=mutual_information(prob_density2d(dc5,dy5))#I(dY,dC)
iyr5=mutual_information(prob_density2d(dr5,dy5))#I(dY,dR)
irc5=mutual_information(prob_density2d(dc5,dr5))#I(dR,dC) 

ioc6=mutual_information(prob_density2d(do6,dc6))#I(dlogOD,dC)
ioy6=mutual_information(prob_density2d(do6,dy6))#I(dlogOD,dY)
ior6=mutual_information(prob_density2d(do6,dr6))#I(dlogOD,dR)
iyc6=mutual_information(prob_density2d(dc6,dy6))#I(dY,dC)
iyr6=mutual_information(prob_density2d(dr6,dy6))#I(dY,dR)
irc6=mutual_information(prob_density2d(dc6,dr6))#I(dR,dC) 

ioc7=mutual_information(prob_density2d(do7,dc7))#I(dlogOD,dC)
ioy7=mutual_information(prob_density2d(do7,dy7))#I(dlogOD,dY)
ior7=mutual_information(prob_density2d(do7,dr7))#I(dlogOD,dR)
iyc7=mutual_information(prob_density2d(dc7,dy7))#I(dY,dC)
iyr7=mutual_information(prob_density2d(dr7,dy7))#I(dY,dR)
irc7=mutual_information(prob_density2d(dc7,dr7))#I(dR,dC) 

ioc8=mutual_information(prob_density2d(do8,dc8))#I(dlogOD,dC)
ioy8=mutual_information(prob_density2d(do8,dy8))#I(dlogOD,dY)
ior8=mutual_information(prob_density2d(do8,dr8))#I(dlogOD,dR)
iyc8=mutual_information(prob_density2d(dc8,dy8))#I(dY,dC)
iyr8=mutual_information(prob_density2d(dr8,dy8))#I(dY,dR)
irc8=mutual_information(prob_density2d(dc8,dr8))#I(dR,dC) 

IOC=[ioc1,ioc2,ioc3,ioc4,ioc5,ioc6,ioc7,ioc8]
IOY=[ioy1,ioy2,ioy3,ioy4,ioy5,ioy6,ioy7,ioy8]
IOR=[ior1,ior2,ior3,ior4,ior5,ior6,ior7,ior8]
IYC=[iyc1,iyc2,iyc3,iyc4,iyc5,iyc6,iyc7,iyc8]
IYR=[iyr1,iyr2,iyr3,iyr4,iyr5,iyr6,iyr7,iyr8]
IRC=[irc1,irc2,irc3,irc4,irc5,irc6,irc7,irc8]

print "I(dlogOD,dC) = ", IOC
print "I(dlogOD,dY) = ", IOY 
print "I(dlogOD,dR) = ", IOR
print "I(dY,dC) = ", IYC
print "I(dY,dR) = ", IYR
print "I(dR,dC)  = ", IRC
# Out:
# I(dlogOD,dC) =  [1.1440854, 0.76860332, 0.89674616, 0.966645, 0.80511737, 0.58732355, 0.83852959, 0.5423038]
# I(dlogOD,dY) =  [1.0911725, 1.129962, 0.75785065, 0.86275005, 0.82611823, 1.2352881, 0.73911119, 0.66380072]
# I(dlogOD,dR) =  [1.1265955, 1.0019081, 0.86512661, 0.81761456, 0.82795691, 0.9682641, 0.76170635, 0.47452855]
# I(dY,dC) =  [1.5816791, 0.93633127, 1.314132, 1.4092658, 1.2606549, 0.71329165, 1.3895166, 1.3376837]
# I(dY,dR) =  [2.2099802, 1.8039978, 1.8862734, 1.9622231, 1.5602906, 2.0776627, 1.4753523, 1.7056942]
# I(dR,dC)  =  [1.6104052, 0.79427147, 1.4398246, 1.2071135, 1.6820753, 0.57585621, 1.3270862, 0.98246193]
